# %%
import pickle
import nltk
nltk.download('punkt')

from gpt_ner_api_codes.prompts_all import *
from gpt_ner_api_codes.demonstration_samples_generation import *
# %reload_ext autoreload
# %autoreload 2

import tqdm
def nop(it, *a, **k):
    return it
tqdm.tqdm = nop
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def process_response(response):    
    processed_response = []
    for item in response:
        dem = item[0]["generated_text"]
        dem = dem.replace("* ", "")
        dem = dem.split("Note: ")[0]
        dem = dem.split("\n\n")[0] + "\n"
        dem_new = ""
        for row in dem.split("\n"):
            if len(row.split(". ") ) > 1:
                dem_new = row.split(". ")[1]
        print(dem)        
        processed_response.append ( dem)
        #print(len(processed_response))
    return processed_response

# %% [markdown]
# # Thin film head technology dataset

# %%
with open("data/immutable_data_formal/sen_thf_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### Zero-shot

# %%
def process_response_zero_shot(response):
    processed_response = []
    for demonstrations_one_sentence in response:
        rows_list = demonstrations_one_sentence.split("\n")

        processed_demonstrations_one_sentence = ""
        for row in rows_list:
            entity_one_row = row.split(": ")[0].split(".")[0]
            if len(row.split(": ")) > 1:
                extracted_words_list = row.split(": ")[1].split(", ")    
            else:
                extracted_words_list = row.split(": ")[0].split(", ")    
            processed_demonstrations_one_row = ""
            for extracted_word in extracted_words_list:
                processed_demonstrations_one_row = processed_demonstrations_one_row + extracted_word + ": " + entity_one_row + '\n'
            processed_demonstrations_one_sentence = processed_demonstrations_one_sentence + processed_demonstrations_one_row 

        processed_response.append(processed_demonstrations_one_sentence)    
    
    return processed_response

# %%
def process_response_zero_shot(response):
    processed_response = []
    for item in response:
        dem = item[0]["generated_text"]
        #dem = dem.replace("* ", "")
        #dem = dem.split("Note: ")[0]
        dem = dem.split("\n\n")[0] + "\n"
        dem_new = ""
        for row in dem.split("\n"):
            row_new = ""
            if len(row.split(". ") ) > 1:
                row_new = row.split(". ")[1]
                dem_new = dem_new + row_new + "\n"  
            else:
                row_new = row
                dem_new = dem_new + row_new + "\n"
                
        processed_response.append ( dem_new )
        
        #print(len(processed_response))
    return processed_response

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(response[5:10])
response = process_response_zero_shot(response) 
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Attribution', 'Function', 'ScientificConcept', 'EnergyFlow', 'Value', 'Component', 'Shape', 'Location', 'Material', 'Effect', 'Measure', 'Consequence', 'AnnotatorNotes', 'PhysicsFlow', 'State', 'InfoFlow', 'System']
#                entity  precision     recall  F1 score  support
# 0         Attribution        0.0        0.0       0.0    372.0
# 1            Function    9.72973  11.464968  0.105263    314.0
# 2   ScientificConcept   2.380952   0.549451  0.008929    182.0
# 3          EnergyFlow       10.0   2.356021  0.038136    382.0
# 4               Value   6.993007  16.666667  0.098522     60.0
# 5           Component  29.834254   7.363636  0.118119   2200.0
# 6               Shape   9.756098   2.094241  0.034483    191.0
# 7            Location   9.012876    4.43038  0.059406    474.0
# 8            Material  23.899371  12.025316      0.16    316.0
# 9              Effect  10.344828   1.149425   0.02069    261.0
# 10            Measure        0.0        0.0       0.0     38.0
# 11        Consequence        0.0        0.0       0.0     22.0
# 12     AnnotatorNotes        0.0        0.0       0.0      3.0
# 13        PhysicsFlow        0.0        0.0       0.0     28.0
# 14              State        0.0        0.0       0.0      6.0
# 15           InfoFlow        0.0        0.0       0.0     89.0
# 16             System   7.228916   2.469136   0.03681    243.0
# 0            accuracy          -          -  5.597375   5181.0
# 1           macro avg    7.01059   3.562897  0.040021   5181.0
# 2        weighted avg   17.66218   5.597375  0.080036   5181.0

# %% [markdown]
# ### not stratified, random

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_1_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['InfoFlow', 'Material', 'Measure', 'AnnotatorNotes', 'Value', 'State', 'System', 'ScientificConcept', 'Component', 'Attribution', 'EnergyFlow', 'Consequence', 'Function', 'Location', 'Shape', 'PhysicsFlow', 'Effect']
#                entity  precision     recall   F1 score  support
# 0            InfoFlow        0.0        0.0        0.0     89.0
# 1            Material  60.606061  18.987342   0.289157    316.0
# 2             Measure        0.0        0.0        0.0     38.0
# 3      AnnotatorNotes        0.0        0.0        0.0      3.0
# 4               Value  19.875776  53.333333   0.289593     60.0
# 5               State       40.0  33.333333   0.363636      6.0
# 6              System  14.666667  27.160494   0.190476    243.0
# 7   ScientificConcept        0.0        0.0        0.0    182.0
# 8           Component  57.180451  69.136364   0.625926   2200.0
# 9         Attribution  24.439462  29.301075   0.266504    372.0
# 10         EnergyFlow  59.130435  17.801047   0.273642    382.0
# 11        Consequence   9.302326  18.181818   0.123077     22.0
# 12           Function  21.502209  46.496815   0.294058    314.0
# 13           Location  28.804348  22.362869   0.251781    474.0
# 14              Shape  17.948718   7.329843   0.104089    191.0
# 15        PhysicsFlow        0.0        0.0        0.0     28.0
# 16             Effect   6.666667   1.149425   0.019608    261.0
# 0            accuracy          -          -  41.131056   5181.0
# 1           macro avg  21.183713  20.269045   0.181856   5181.0
# 2        weighted avg  40.031301  41.131056   0.381646   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_3_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['InfoFlow', 'Material', 'Measure', 'AnnotatorNotes', 'Value', 'State', 'System', 'ScientificConcept', 'Component', 'Attribution', 'EnergyFlow', 'Consequence', 'Function', 'Location', 'Shape', 'PhysicsFlow', 'Effect']
#                entity  precision     recall   F1 score  support
# 0            InfoFlow       50.0   6.741573   0.118812     89.0
# 1            Material  52.212389  56.012658   0.540458    316.0
# 2             Measure        0.0        0.0        0.0     38.0
# 3      AnnotatorNotes        0.0        0.0        0.0      3.0
# 4               Value  10.703364  58.333333   0.180879     60.0
# 5               State      100.0  33.333333        0.5      6.0
# 6              System  18.796992  10.288066   0.132979    243.0
# 7   ScientificConcept  10.958904   8.791209   0.097561    182.0
# 8           Component  67.514248       70.0   0.687347   2200.0
# 9         Attribution  15.892054  28.494624   0.204042    372.0
# 10         EnergyFlow  36.637931  22.251309   0.276873    382.0
# 11        Consequence   5.882353   4.545455   0.051282     22.0
# 12           Function  19.578947  29.617834   0.235741    314.0
# 13           Location  24.876847  21.308017   0.229545    474.0
# 14              Shape  24.484536   49.73822   0.328152    191.0
# 15        PhysicsFlow        0.0        0.0        0.0     28.0
# 16             Effect       20.0   1.149425   0.021739    261.0
# 0            accuracy          -          -  44.103455   5181.0
# 1           macro avg  26.914033  23.565003   0.212083   5181.0
# 2        weighted avg  43.458359  44.103455   0.422972   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  21.052632   3.292181    0.05694    243.0
# 1            Material  42.009132  58.227848   0.488064    316.0
# 2         Attribution  22.675367  37.365591   0.282234    372.0
# 3               Value  21.341463  58.333333     0.3125     60.0
# 4         Consequence  27.272727  13.636364   0.181818     22.0
# 5            Location  33.333333  41.772152   0.370787    474.0
# 6          EnergyFlow  38.652482  28.534031   0.328313    382.0
# 7             Measure        0.0        0.0        0.0     38.0
# 8            Function  12.903226   2.547771   0.042553    314.0
# 9           Component  64.346655  65.136364   0.647391   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  42.028986  30.366492   0.352584    191.0
# 12              State        0.0        0.0        0.0      6.0
# 13             Effect  27.826087  49.042146   0.355062    261.0
# 14        PhysicsFlow    1.06383   3.571429   0.016393     28.0
# 15  ScientificConcept  10.243902  11.538462   0.108527    182.0
# 16           InfoFlow  16.666667   1.123596   0.021053     89.0
# 0            accuracy          -          -  44.894808   5181.0
# 1           macro avg  22.436264  23.793398    0.20966   5181.0
# 2        weighted avg  43.148727  44.894808   0.427851   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall  F1 score  support
# 0              System  27.368421  21.399177  0.240185    243.0
# 1            Material  42.430279  67.405063  0.520782    316.0
# 2         Attribution  27.468582  41.129032  0.329386    372.0
# 3               Value  25.757576  56.666667  0.354167     60.0
# 4         Consequence       20.0  13.636364  0.162162     22.0
# 5            Location  39.432177  52.742616  0.451264    474.0
# 6          EnergyFlow  67.777778  31.937173  0.434164    382.0
# 7             Measure  13.043478   7.894737  0.098361     38.0
# 8            Function  34.983498  33.757962  0.343598    314.0
# 9           Component  64.599589       71.5  0.678749   2200.0
# 10     AnnotatorNotes        0.0        0.0       0.0      3.0
# 11              Shape  40.566038  22.513089  0.289562    191.0
# 12              State      100.0  33.333333       0.5      6.0
# 13             Effect  35.064935  51.724138  0.417957    261.0
# 14        PhysicsFlow   4.444444   7.142857  0.054795     28.0
# 15  ScientificConcept  35.384615  12.637363  0.186235    182.0
# 16           InfoFlow      100.0   8.988764  0.164948     89.0
# 0            accuracy          -          -  52.53812   5181.0
# 1           macro avg  39.901259  31.435784   0.30743   5181.0
# 2        weighted avg  50.841208   52.53812  0.496508   5181.0

# %% [markdown]
# ### stratified, random

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(response, response[28])        
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  18.867925  16.460905   0.175824    243.0
# 1            Material  31.490015  64.873418   0.423992    316.0
# 2         Attribution  17.241379  29.569892   0.217822    372.0
# 3               Value       20.0  51.666667   0.288372     60.0
# 4         Consequence        0.0        0.0        0.0     22.0
# 5            Location      33.75  39.873418   0.365571    474.0
# 6          EnergyFlow  23.809524  35.340314    0.28451    382.0
# 7             Measure        0.0        0.0        0.0     38.0
# 8            Function  39.583333   6.050955   0.104972    314.0
# 9           Component  67.961165  60.454545   0.639885   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  36.551724  27.748691   0.315476    191.0
# 12              State        0.0        0.0        0.0      6.0
# 13             Effect   21.89441  54.022989   0.311602    261.0
# 14        PhysicsFlow   3.921569   7.142857   0.050633     28.0
# 15  ScientificConcept        0.0        0.0        0.0    182.0
# 16           InfoFlow        0.0        0.0        0.0     89.0
# 0            accuracy          -          -  43.524416   5181.0
# 1           macro avg  18.533591  23.129685    0.18698   5181.0
# 2        weighted avg  42.847256  43.524416   0.413185   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  19.555556  18.106996   0.188034    243.0
# 1            Material   40.92827  61.392405   0.491139    316.0
# 2         Attribution  17.254902  59.139785   0.267152    372.0
# 3               Value  38.888889  58.333333   0.466667     60.0
# 4         Consequence        0.0        0.0        0.0     22.0
# 5            Location  45.253165  30.168776   0.362025    474.0
# 6          EnergyFlow  44.295302  34.554974   0.388235    382.0
# 7             Measure        0.0        0.0        0.0     38.0
# 8            Function  32.246377  28.343949   0.301695    314.0
# 9           Component  65.056571  67.954545    0.66474   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  36.866359  41.884817   0.392157    191.0
# 12              State        0.0        0.0        0.0      6.0
# 13             Effect  29.459459  41.762452   0.345483    261.0
# 14        PhysicsFlow   6.060606   7.142857   0.065574     28.0
# 15  ScientificConcept  14.285714   3.846154   0.060606    182.0
# 16           InfoFlow        0.0        0.0        0.0     89.0
# 0            accuracy          -          -  49.218298   5181.0
# 1           macro avg  22.950069  26.625356   0.234912   5181.0
# 2        weighted avg   45.46578  49.218298   0.460004   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall  F1 score  support
# 0              System  22.705314  19.341564  0.208889    243.0
# 1            Material  44.255319  65.822785  0.529262    316.0
# 2         Attribution  14.649123  44.892473  0.220899    372.0
# 3               Value  28.421053       45.0  0.348387     60.0
# 4         Consequence        0.0        0.0       0.0     22.0
# 5            Location  45.454545  36.919831  0.407451    474.0
# 6          EnergyFlow   36.00823  45.811518  0.403226    382.0
# 7             Measure        0.0        0.0       0.0     38.0
# 8            Function       22.4   8.917197  0.127563    314.0
# 9           Component  64.620631  68.909091   0.66696   2200.0
# 10     AnnotatorNotes        0.0        0.0       0.0      3.0
# 11              Shape  30.091185  51.832461  0.380769    191.0
# 12              State        0.0        0.0       0.0      6.0
# 13             Effect   34.52381  44.444444   0.38861    261.0
# 14        PhysicsFlow   1.923077   3.571429     0.025     28.0
# 15  ScientificConcept  13.636364   3.296703  0.053097    182.0
# 16           InfoFlow  33.333333   2.247191  0.042105     89.0
# 0            accuracy          -          -  49.54642   5181.0
# 1           macro avg  23.060117   25.94157   0.22366   5181.0
# 2        weighted avg  44.666446   49.54642  0.456259   5181.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_1_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['InfoFlow', 'Material', 'Measure', 'AnnotatorNotes', 'Value', 'State', 'System', 'ScientificConcept', 'Component', 'Attribution', 'EnergyFlow', 'Consequence', 'Function', 'Location', 'Shape', 'PhysicsFlow', 'Effect']
#                entity  precision     recall  F1 score  support
# 0            InfoFlow  58.823529   22.47191  0.325203     89.0
# 1            Material   53.62776  53.797468  0.537125    316.0
# 2             Measure      18.75   7.894737  0.111111     38.0
# 3      AnnotatorNotes        4.0  33.333333  0.071429      3.0
# 4               Value   10.11236       30.0  0.151261     60.0
# 5               State       50.0  33.333333       0.4      6.0
# 6              System  19.075145  13.580247  0.158654    243.0
# 7   ScientificConcept   24.81203  18.131868  0.209524    182.0
# 8           Component  67.539805  59.772727  0.634193   2200.0
# 9         Attribution  26.315789  17.473118  0.210016    372.0
# 10         EnergyFlow  43.846154  29.842932   0.35514    382.0
# 11        Consequence   6.451613  18.181818  0.095238     22.0
# 12           Function  29.245283  29.617834  0.294304    314.0
# 13           Location  31.435644  26.793249  0.289294    474.0
# 14              Shape  30.821918  23.560209  0.267062    191.0
# 15        PhysicsFlow  10.769231       25.0  0.150538     28.0
# 16             Effect  42.361111  23.371648  0.301235    261.0
# 0            accuracy          -          -  40.74503   5181.0
# 1           macro avg  31.058081  27.420967  0.268313   5181.0
# 2        weighted avg  48.168395   40.74503  0.437322   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  28.977273  20.987654   0.243437    243.0
# 1            Material  61.031519  67.405063   0.640602    316.0
# 2         Attribution  36.363636  38.709677      0.375    372.0
# 3               Value  20.731707  28.333333   0.239437     60.0
# 4         Consequence  15.686275  36.363636   0.219178     22.0
# 5            Location  42.404007  53.586498   0.473439    474.0
# 6          EnergyFlow  54.907975  46.858639    0.50565    382.0
# 7             Measure  20.408163  26.315789   0.229885     38.0
# 8            Function  35.446686  39.171975   0.372163    314.0
# 9           Component  73.851751  73.818182    0.73835   2200.0
# 10     AnnotatorNotes   3.846154  33.333333   0.068966      3.0
# 11              Shape   44.91018  39.267016   0.418994    191.0
# 12              State  22.222222  33.333333   0.266667      6.0
# 13             Effect  50.925926  42.145594   0.461216    261.0
# 14        PhysicsFlow  19.565217  32.142857   0.243243     28.0
# 15  ScientificConcept  30.472103  39.010989   0.342169    182.0
# 16           InfoFlow  76.363636  47.191011   0.583333     89.0
# 0            accuracy          -          -  56.610693   5181.0
# 1           macro avg  37.536143  41.057328   0.377749   5181.0
# 2        weighted avg  56.321593  56.610693   0.561865   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  45.238095   31.27572    0.36983    243.0
# 1            Material  60.629921  73.101266   0.662841    316.0
# 2         Attribution  37.860082  49.462366   0.428904    372.0
# 3               Value  30.927835       50.0   0.382166     60.0
# 4         Consequence   19.69697  59.090909   0.295455     22.0
# 5            Location  48.244275  66.666667   0.559787    474.0
# 6          EnergyFlow  56.395349   50.78534   0.534435    382.0
# 7             Measure  35.135135  34.210526   0.346667     38.0
# 8            Function  40.114613  44.585987   0.422323    314.0
# 9           Component  73.579921  75.954545   0.747484   2200.0
# 10     AnnotatorNotes   2.702703  33.333333       0.05      3.0
# 11              Shape   46.40884  43.979058   0.451613    191.0
# 12              State  66.666667  33.333333   0.444444      6.0
# 13             Effect  55.932203  50.574713   0.531187    261.0
# 14        PhysicsFlow  23.076923  42.857143        0.3     28.0
# 15  ScientificConcept  28.787879  31.318681        0.3    182.0
# 16           InfoFlow  77.586207  50.561798   0.612245     89.0
# 0            accuracy          -          -  61.783439   5181.0
# 1           macro avg   44.05786  48.299493   0.437611   5181.0
# 2        weighted avg  58.560866  61.783439   0.597038   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  39.285714  31.687243   0.350797    243.0
# 1            Material  62.102689  80.379747    0.70069    316.0
# 2         Attribution  38.069217  56.182796   0.453855    372.0
# 3               Value  30.107527  46.666667   0.366013     60.0
# 4         Consequence  28.947368       50.0   0.366667     22.0
# 5            Location  46.974063  68.776371   0.558219    474.0
# 6          EnergyFlow  62.080537  48.429319   0.544118    382.0
# 7             Measure  22.222222  31.578947    0.26087     38.0
# 8            Function  44.816054  42.675159   0.437194    314.0
# 9           Component  74.620874  76.045455   0.753264   2200.0
# 10     AnnotatorNotes   2.777778  33.333333   0.051282      3.0
# 11              Shape  53.896104  43.455497   0.481159    191.0
# 12              State       50.0  33.333333        0.4      6.0
# 13             Effect  51.865672  53.256705    0.52552    261.0
# 14        PhysicsFlow  23.636364  46.428571   0.313253     28.0
# 15  ScientificConcept  28.723404   29.67033   0.291892    182.0
# 16           InfoFlow  74.545455  46.067416   0.569444     89.0
# 0            accuracy          -          -  62.574793   5181.0
# 1           macro avg  43.215944  48.115699    0.43672   5181.0
# 2        weighted avg   59.35195  62.574793   0.603462   5181.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  13.461538   5.761317   0.080692    243.0
# 1            Material  40.160643  63.291139     0.4914    316.0
# 2         Attribution  18.491484  20.430108   0.194125    372.0
# 3               Value  23.493976       65.0   0.345133     60.0
# 4         Consequence        0.0        0.0        0.0     22.0
# 5            Location   30.90379  44.725738   0.365517    474.0
# 6          EnergyFlow   41.64859   50.26178   0.455516    382.0
# 7             Measure   9.756098  21.052632   0.133333     38.0
# 8            Function  37.025316  37.261146   0.371429    314.0
# 9           Component  68.493761  69.863636   0.691719   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  37.810945  39.790576   0.387755    191.0
# 12              State        0.0        0.0        0.0      6.0
# 13             Effect   33.58209  34.482759   0.340265    261.0
# 14        PhysicsFlow  13.793103  14.285714   0.140351     28.0
# 15  ScientificConcept  16.071429  14.835165   0.154286    182.0
# 16           InfoFlow  68.571429  26.966292   0.387097     89.0
# 0            accuracy          -          -  50.492183   5181.0
# 1           macro avg    26.6626  29.882824   0.266977   5181.0
# 2        weighted avg  46.881371  50.492183   0.480194   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  22.758621  13.580247   0.170103    243.0
# 1            Material  55.163043  64.240506   0.593567    316.0
# 2         Attribution  24.625268  30.913978   0.274136    372.0
# 3               Value  24.576271  48.333333   0.325843     60.0
# 4         Consequence  26.666667  18.181818   0.216216     22.0
# 5            Location  37.774295  50.843882   0.433453    474.0
# 6          EnergyFlow   46.17284   48.95288   0.475222    382.0
# 7             Measure  11.111111  26.315789    0.15625     38.0
# 8            Function  37.328767  34.713376   0.359736    314.0
# 9           Component  68.573868       73.0   0.707177   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  35.897436  43.979058   0.395294    191.0
# 12              State        0.0        0.0        0.0      6.0
# 13             Effect  35.144928  37.164751   0.361266    261.0
# 14        PhysicsFlow  18.181818  28.571429   0.222222     28.0
# 15  ScientificConcept  19.760479  18.131868   0.189112    182.0
# 16           InfoFlow  61.111111  37.078652   0.461538     89.0
# 0            accuracy          -          -  53.889211   5181.0
# 1           macro avg  30.873325  33.764798   0.314185   5181.0
# 2        weighted avg  49.856464  53.889211   0.515031   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  26.724138  12.757202   0.172702    243.0
# 1            Material  55.216285  68.670886    0.61213    316.0
# 2         Attribution  26.872964  44.354839   0.334686    372.0
# 3               Value  25.961538       45.0   0.329268     60.0
# 4         Consequence       20.0   9.090909      0.125     22.0
# 5            Location  46.037736  51.476793   0.486056    474.0
# 6          EnergyFlow  48.507463   51.04712   0.497449    382.0
# 7             Measure  12.121212  21.052632   0.153846     38.0
# 8            Function  38.216561  38.216561   0.382166    314.0
# 9           Component  68.090452  73.909091   0.708806   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  39.004149   49.21466   0.435185    191.0
# 12              State  15.384615  33.333333   0.210526      6.0
# 13             Effect  41.767068  39.846743   0.407843    261.0
# 14        PhysicsFlow   9.677419  10.714286   0.101695     28.0
# 15  ScientificConcept  28.313253  25.824176   0.270115    182.0
# 16           InfoFlow       62.5  28.089888   0.387597     89.0
# 0            accuracy          -          -  56.166763   5181.0
# 1           macro avg  33.199697  35.447007   0.330298   5181.0
# 2        weighted avg  51.723194  56.166763   0.533754   5181.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_1_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['InfoFlow', 'Material', 'Measure', 'AnnotatorNotes', 'Value', 'State', 'System', 'ScientificConcept', 'Component', 'Attribution', 'EnergyFlow', 'Consequence', 'Function', 'Location', 'Shape', 'PhysicsFlow', 'Effect']
#                entity  precision     recall  F1 score  support
# 0            InfoFlow     65.625  23.595506  0.347107     89.0
# 1            Material  50.265957  59.810127  0.546243    316.0
# 2             Measure       25.0  15.789474  0.193548     38.0
# 3      AnnotatorNotes        5.0  33.333333  0.086957      3.0
# 4               Value   10.27027  31.666667  0.155102     60.0
# 5               State       20.0  33.333333      0.25      6.0
# 6              System  13.733906  13.168724  0.134454    243.0
# 7   ScientificConcept  20.100503  21.978022  0.209974    182.0
# 8           Component  68.359375  55.681818  0.613727   2200.0
# 9         Attribution  26.950355  20.430108  0.232416    372.0
# 10         EnergyFlow  47.486034  22.251309   0.30303    382.0
# 11        Consequence   8.333333  13.636364  0.103448     22.0
# 12           Function  31.271478  28.980892  0.300826    314.0
# 13           Location  32.665331  34.388186  0.335046    474.0
# 14              Shape  33.333333  21.465969  0.261146    191.0
# 15        PhysicsFlow  14.285714  28.571429  0.190476     28.0
# 16             Effect  46.323529  24.137931   0.31738    261.0
# 0            accuracy          -          -  39.85717   5181.0
# 1           macro avg  30.529654  28.365835  0.269464   5181.0
# 2        weighted avg  48.894111   39.85717  0.432123   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  25.769231  27.572016   0.266402    243.0
# 1            Material  52.094241  62.974684   0.570201    316.0
# 2         Attribution  36.202532   38.44086   0.372881    372.0
# 3               Value  24.742268       40.0   0.305732     60.0
# 4         Consequence  19.047619  54.545455   0.282353     22.0
# 5            Location  47.841105  58.438819   0.526116    474.0
# 6          EnergyFlow     59.375  39.790576   0.476489    382.0
# 7             Measure  14.583333  18.421053   0.162791     38.0
# 8            Function  37.662338  36.942675    0.37299    314.0
# 9           Component  73.200389  68.409091   0.707237   2200.0
# 10     AnnotatorNotes   6.666667      100.0      0.125      3.0
# 11              Shape  50.909091  43.979058    0.47191    191.0
# 12              State  16.666667  33.333333   0.222222      6.0
# 13             Effect  50.666667  43.678161   0.469136    261.0
# 14        PhysicsFlow  22.727273  35.714286   0.277778     28.0
# 15  ScientificConcept  29.482072  40.659341   0.341801    182.0
# 16           InfoFlow  77.966102  51.685393   0.621622     89.0
# 0            accuracy          -          -  54.719166   5181.0
# 1           macro avg  37.976623  46.740282   0.386627   5181.0
# 2        weighted avg  56.530067  54.719166    0.55171   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  32.905983  31.687243   0.322851    243.0
# 1            Material   58.61244  77.531646   0.667575    316.0
# 2         Attribution  47.488584  55.913978    0.51358    372.0
# 3               Value       40.0       70.0   0.509091     60.0
# 4         Consequence   22.44898       50.0   0.309859     22.0
# 5            Location  51.010886  69.198312   0.587287    474.0
# 6          EnergyFlow  58.255452   48.95288   0.532006    382.0
# 7             Measure    26.5625  44.736842   0.333333     38.0
# 8            Function  41.547278  46.178344   0.437406    314.0
# 9           Component   75.61553  72.590909   0.740724   2200.0
# 10     AnnotatorNotes   3.333333  33.333333   0.060606      3.0
# 11              Shape  54.545455  43.979058   0.486957    191.0
# 12              State  13.333333  33.333333   0.190476      6.0
# 13             Effect  53.441296  50.574713   0.519685    261.0
# 14        PhysicsFlow  19.230769  35.714286       0.25     28.0
# 15  ScientificConcept  27.862595   40.10989   0.328829    182.0
# 16           InfoFlow  76.388889  61.797753    0.68323     89.0
# 0            accuracy          -          -  62.034356   5181.0
# 1           macro avg   41.32843   50.91956   0.439617   5181.0
# 2        weighted avg  59.985306  62.034356   0.605414   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  40.434783  38.271605   0.393235    243.0
# 1            Material  60.913706  75.949367   0.676056    316.0
# 2         Attribution  46.929825  57.526882   0.516908    372.0
# 3               Value  34.513274       65.0   0.450867     60.0
# 4         Consequence  26.666667  36.363636   0.307692     22.0
# 5            Location       54.5  68.987342   0.608939    474.0
# 6          EnergyFlow   60.39604  47.905759   0.534307    382.0
# 7             Measure  22.222222  36.842105   0.277228     38.0
# 8            Function       47.5  42.356688   0.447811    314.0
# 9           Component  76.625825  73.909091   0.752429   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  63.870968  51.832461   0.572254    191.0
# 12              State   8.333333  33.333333   0.133333      6.0
# 13             Effect  54.230769  54.022989   0.541267    261.0
# 14        PhysicsFlow  35.294118  42.857143   0.387097     28.0
# 15  ScientificConcept  30.677291  42.307692   0.355658    182.0
# 16           InfoFlow  75.862069  49.438202   0.598639     89.0
# 0            accuracy          -          -  62.767805   5181.0
# 1           macro avg  43.468876  48.053194   0.444337   5181.0
# 2        weighted avg  62.180486  62.767805   0.620489   5181.0

# %% [markdown]
# ### stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  18.918919   8.641975   0.118644    243.0
# 1            Material  44.370861  63.607595   0.522757    316.0
# 2         Attribution  14.869888  21.505376   0.175824    372.0
# 3               Value     20.625       55.0        0.3     60.0
# 4         Consequence  16.666667   4.545455   0.071429     22.0
# 5            Location  33.130699  45.991561   0.385159    474.0
# 6          EnergyFlow  38.141809  40.837696   0.394437    382.0
# 7             Measure  11.764706  21.052632   0.150943     38.0
# 8            Function   25.43554  23.248408   0.242928    314.0
# 9           Component  67.569969  69.136364   0.683442   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  32.876712  37.696335    0.35122    191.0
# 12              State        0.0        0.0        0.0      6.0
# 13             Effect   34.10596  39.463602   0.365897    261.0
# 14        PhysicsFlow   4.878049   7.142857   0.057971     28.0
# 15  ScientificConcept  20.689655  13.186813   0.161074    182.0
# 16           InfoFlow  56.140351  35.955056   0.438356     89.0
# 0            accuracy          -          -  49.121791   5181.0
# 1           macro avg  25.893223  28.647749   0.260005   5181.0
# 2        weighted avg  45.781862  49.121791   0.469091   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System       22.5  14.814815    0.17866    243.0
# 1            Material   52.18509  64.240506   0.575887    316.0
# 2         Attribution  21.005386  31.451613   0.251884    372.0
# 3               Value  26.666667  53.333333   0.355556     60.0
# 4         Consequence        0.0        0.0        0.0     22.0
# 5            Location  40.527183  51.898734   0.455134    474.0
# 6          EnergyFlow  46.380697  45.287958   0.458278    382.0
# 7             Measure   9.302326  21.052632   0.129032     38.0
# 8            Function  30.797101  27.070064   0.288136    314.0
# 9           Component  69.542484  72.545455   0.710122   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  37.724551  32.984293   0.351955    191.0
# 12              State       12.5  33.333333   0.181818      6.0
# 13             Effect  39.597315  45.210728   0.422182    261.0
# 14        PhysicsFlow   4.081633   7.142857   0.051948     28.0
# 15  ScientificConcept  19.254658  17.032967   0.180758    182.0
# 16           InfoFlow  55.357143  34.831461   0.427586     89.0
# 0            accuracy          -          -  52.943447   5181.0
# 1           macro avg  28.671896  32.484162   0.295232   5181.0
# 2        weighted avg   49.69644  52.943447   0.509512   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  35.672515  25.102881   0.294686    243.0
# 1            Material  59.007833  71.518987   0.646638    316.0
# 2         Attribution   27.06422  47.580645   0.345029    372.0
# 3               Value  33.333333  46.666667   0.388889     60.0
# 4         Consequence  28.571429   9.090909   0.137931     22.0
# 5            Location  47.940075  54.008439   0.507937    474.0
# 6          EnergyFlow  52.702703   51.04712   0.518617    382.0
# 7             Measure  15.662651  34.210526   0.214876     38.0
# 8            Function  44.890511  39.171975   0.418367    314.0
# 9           Component  69.916922  72.681818   0.712726   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  40.298507  42.408377   0.413265    191.0
# 12              State        8.0  33.333333   0.129032      6.0
# 13             Effect  33.633634  42.911877   0.377104    261.0
# 14        PhysicsFlow  19.444444       25.0    0.21875     28.0
# 15  ScientificConcept  14.117647  13.186813   0.136364    182.0
# 16           InfoFlow       58.0   32.58427   0.417266     89.0
# 0            accuracy          -          -  56.649296   5181.0
# 1           macro avg  34.603319  37.676743   0.345734   5181.0
# 2        weighted avg  53.305282  56.649296   0.544929   5181.0

# %% [markdown]
# ### not stratified, td-idf_half

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  23.550725  26.748971   0.250482    243.0
# 1            Material  56.446991  62.341772   0.592481    316.0
# 2         Attribution  30.170316  33.333333   0.316731    372.0
# 3               Value  23.622047       50.0   0.320856     60.0
# 4         Consequence       20.0  36.363636   0.258065     22.0
# 5            Location  46.234676  55.696203   0.505263    474.0
# 6          EnergyFlow  52.836879  39.005236   0.448795    382.0
# 7             Measure  17.777778  21.052632   0.192771     38.0
# 8            Function  34.482759  31.847134   0.331126    314.0
# 9           Component  74.020619  65.272727    0.69372   2200.0
# 10     AnnotatorNotes        4.0  33.333333   0.071429      3.0
# 11              Shape  42.957746  31.937173   0.366366    191.0
# 12              State       25.0  33.333333   0.285714      6.0
# 13             Effect  55.029586  35.632184   0.432558    261.0
# 14        PhysicsFlow       20.0  35.714286    0.25641     28.0
# 15  ScientificConcept  25.454545  38.461538   0.306346    182.0
# 16           InfoFlow  76.470588  58.426966    0.66242     89.0
# 0            accuracy          -          -  51.534453   5181.0
# 1           macro avg  36.944427  40.500027    0.37009   5181.0
# 2        weighted avg  55.552296  51.534453   0.530004   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  32.170543  34.156379   0.331337    243.0
# 1            Material  56.363636  68.670886   0.619116    316.0
# 2         Attribution  35.930736  44.623656   0.398082    372.0
# 3               Value  31.531532  58.333333   0.409357     60.0
# 4         Consequence      18.75  27.272727   0.222222     22.0
# 5            Location  45.560408  66.033755    0.53919    474.0
# 6          EnergyFlow  55.902778  42.146597   0.480597    382.0
# 7             Measure       22.0  28.947368       0.25     38.0
# 8            Function  39.672131  38.535032   0.390953    314.0
# 9           Component  74.230963  66.909091   0.703801   2200.0
# 10     AnnotatorNotes   2.439024  33.333333   0.045455      3.0
# 11              Shape  51.515152  35.602094   0.421053    191.0
# 12              State  18.181818  33.333333   0.235294      6.0
# 13             Effect  48.305085  43.678161   0.458753    261.0
# 14        PhysicsFlow  19.607843  35.714286   0.253165     28.0
# 15  ScientificConcept  25.461255  37.912088   0.304636    182.0
# 16           InfoFlow  79.032258   55.05618   0.649007     89.0
# 0            accuracy          -          -  55.935148   5181.0
# 1           macro avg  38.626774  44.132841   0.394824   5181.0
# 2        weighted avg  57.060588  55.935148   0.558864   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System  38.116592  34.979424   0.364807    243.0
# 1            Material  58.837772  76.898734   0.666667    316.0
# 2         Attribution  37.179487  46.774194   0.414286    372.0
# 3               Value   40.40404  66.666667   0.503145     60.0
# 4         Consequence  42.307692       50.0   0.458333     22.0
# 5            Location  51.404959  65.611814    0.57646    474.0
# 6          EnergyFlow  53.538462  45.549738   0.492221    382.0
# 7             Measure  22.058824  39.473684   0.283019     38.0
# 8            Function   38.00738  32.802548   0.352137    314.0
# 9           Component  73.249884  71.818182    0.72527   2200.0
# 10     AnnotatorNotes   4.166667  66.666667   0.078431      3.0
# 11              Shape  53.296703   50.78534   0.520107    191.0
# 12              State  46.153846      100.0   0.631579      6.0
# 13             Effect  51.440329   47.89272   0.496032    261.0
# 14        PhysicsFlow  24.528302  46.428571   0.320988     28.0
# 15  ScientificConcept  28.630705  37.912088   0.326241    182.0
# 16           InfoFlow     78.125  56.179775   0.653595     89.0
# 0            accuracy          -          -  59.795406   5181.0
# 1           macro avg  43.614509  55.084715   0.462548   5181.0
# 2        weighted avg  58.005504  59.795406   0.585071   5181.0

# %% [markdown]
# ### stratified, td-idf_half

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall  F1 score  support
# 0              System   9.774436   5.349794  0.069149    243.0
# 1            Material  29.562044  51.265823     0.375    316.0
# 2         Attribution  15.899582  20.430108  0.178824    372.0
# 3               Value  15.948276  61.666667  0.253425     60.0
# 4         Consequence   7.142857   9.090909      0.08     22.0
# 5            Location  29.422719  33.333333  0.312562    474.0
# 6          EnergyFlow  29.099307  32.984293  0.309202    382.0
# 7             Measure   8.695652  10.526316  0.095238     38.0
# 8            Function  33.187773  24.203822  0.279926    314.0
# 9           Component   66.87054  59.636364  0.630466   2200.0
# 10     AnnotatorNotes   1.785714  33.333333  0.033898      3.0
# 11              Shape   19.54023  17.801047  0.186301    191.0
# 12              State       25.0  33.333333  0.285714      6.0
# 13             Effect  21.827411  16.475096  0.187773    261.0
# 14        PhysicsFlow   2.985075   7.142857  0.042105     28.0
# 15  ScientificConcept  13.265306  14.285714  0.137566    182.0
# 16           InfoFlow       30.0   6.741573  0.110092     89.0
# 0            accuracy          -          -  40.14669   5181.0
# 1           macro avg  21.176878  25.741199  0.209838   5181.0
# 2        weighted avg  41.773157   40.14669   0.40263   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System   16.27907  11.522634    0.13494    243.0
# 1            Material  36.554622  55.063291   0.439394    316.0
# 2         Attribution  22.427984  29.301075   0.254079    372.0
# 3               Value   19.71831  46.666667   0.277228     60.0
# 4         Consequence  11.111111  13.636364   0.122449     22.0
# 5            Location  34.876033  44.514768   0.391103    474.0
# 6          EnergyFlow  34.190231  34.816754   0.345006    382.0
# 7             Measure  17.307692  23.684211        0.2     38.0
# 8            Function       32.4  25.796178   0.287234    314.0
# 9           Component  67.551622  62.454545   0.649032   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  27.374302   25.65445   0.264865    191.0
# 12              State  28.571429  33.333333   0.307692      6.0
# 13             Effect  25.628141   19.54023   0.221739    261.0
# 14        PhysicsFlow   3.225806   7.142857   0.044444     28.0
# 15  ScientificConcept  12.871287  14.285714   0.135417    182.0
# 16           InfoFlow       25.0   4.494382    0.07619     89.0
# 0            accuracy          -          -  44.084154   5181.0
# 1           macro avg   24.41692  26.582791   0.244165   5181.0
# 2        weighted avg   44.59783  44.084154    0.43839   5181.0

# %%
with open("formal_eva_results_llama2chat13b/thf_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['System', 'Material', 'Attribution', 'Value', 'Consequence', 'Location', 'EnergyFlow', 'Measure', 'Function', 'Component', 'AnnotatorNotes', 'Shape', 'State', 'Effect', 'PhysicsFlow', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0              System    17.1875  13.580247   0.151724    243.0
# 1            Material  41.012658  51.265823   0.455696    316.0
# 2         Attribution  21.043771  33.602151   0.258799    372.0
# 3               Value   22.54902  38.333333   0.283951     60.0
# 4         Consequence       10.0  13.636364   0.115385     22.0
# 5            Location      36.64  48.312236   0.416742    474.0
# 6          EnergyFlow  40.697674  36.649215   0.385675    382.0
# 7             Measure  17.045455  39.473684   0.238095     38.0
# 8            Function  27.881041   23.88535    0.25729    314.0
# 9           Component  67.816092  64.363636   0.660448   2200.0
# 10     AnnotatorNotes        0.0        0.0        0.0      3.0
# 11              Shape  30.434783  36.649215   0.332542    191.0
# 12              State       50.0  33.333333        0.4      6.0
# 13             Effect  28.488372  18.773946   0.226328    261.0
# 14        PhysicsFlow   2.325581   3.571429   0.028169     28.0
# 15  ScientificConcept  14.210526  14.835165   0.145161    182.0
# 16           InfoFlow       52.0  14.606742    0.22807     89.0
# 0            accuracy          -          -  45.994982   5181.0
# 1           macro avg  28.196028  28.521875   0.269651   5181.0
# 2        weighted avg  46.106423  45.994982   0.454912   5181.0

# %% [markdown]
# # Assembly

# %%
with open("data/immutable_data_formal/sen_assembly_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_assembly_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### not stratified, random

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response_zero_shot(response)
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PART', 'QTY', 'RPOS', 'TOOL', 'WGT', 'PROP', 'ID', 'OPER', 'DIM']
#          entity  precision    recall  F1 score  support
# 0          PART  63.800905  6.811594   0.12309   2070.0
# 1           QTY   4.166667  3.278689  0.036697     61.0
# 2          RPOS  19.444444  1.440329   0.02682    486.0
# 3          TOOL   6.666667  6.944444  0.068027     72.0
# 4           WGT        0.0       0.0       0.0      2.0
# 5          PROP       25.0  1.818182  0.033898     55.0
# 6            ID   4.166667  3.076923  0.035398     65.0
# 7          OPER   11.84573  8.206107  0.096956    524.0
# 8           DIM   9.090909  5.714286  0.070175     35.0
# 0      accuracy          -         -  6.023739   3370.0
# 1     macro avg  16.020221  4.143395  0.054563   3370.0
# 2  weighted avg   44.63597  6.023739  0.098633   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_1_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['TOOL', 'ID', 'QTY', 'RPOS', 'PART', 'DIM', 'PROP', 'WGT', 'OPER']
#          entity  precision     recall   F1 score  support
# 0          TOOL      11.25       25.0   0.155172     72.0
# 1            ID  10.502283  35.384615   0.161972     65.0
# 2           QTY   4.744526  21.311475   0.077612     61.0
# 3          RPOS  23.655914   4.526749   0.075993    486.0
# 4          PART  60.318332  53.091787   0.564748   2070.0
# 5           DIM   3.703704  11.428571   0.055944     35.0
# 6          PROP   3.703704   1.818182    0.02439     55.0
# 7           WGT        0.0        0.0        0.0      2.0
# 8          OPER  11.979576  58.206107   0.198697    524.0
# 0      accuracy          -          -  44.065282   3370.0
# 1     macro avg  14.428671   23.41861   0.146059   3370.0
# 2  weighted avg  42.952052  44.065282   0.397571   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   6.329114  32.786885   0.106101     61.0
# 1          PROP        0.0        0.0        0.0     55.0
# 2          PART  63.500785  39.082126   0.483852   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS   28.00789  29.218107   0.286002    486.0
# 5          OPER  20.984215  43.129771   0.282324    524.0
# 6           DIM   6.349206  11.428571   0.081633     35.0
# 7          TOOL       22.5       25.0   0.236842     72.0
# 8            ID  30.612245  23.076923   0.263158     65.0
# 0      accuracy          -          -  36.617211   3370.0
# 1     macro avg  19.809273   22.63582   0.193323   3370.0
# 2  weighted avg  47.558541  36.617211   0.395251   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   16.56051  42.622951   0.238532     61.0
# 1          PROP   4.021448  27.272727   0.070093     55.0
# 2          PART  69.223007  66.280193   0.677196   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  24.114544  65.843621   0.353006    486.0
# 5          OPER  30.311111  65.076336   0.413584    524.0
# 6           DIM   3.168317  45.714286   0.059259     35.0
# 7          TOOL       26.0  36.111111   0.302326     72.0
# 8            ID  25.179856  53.846154   0.343137     65.0
# 0      accuracy          -          -  63.827893   3370.0
# 1     macro avg   22.06431  44.751931   0.273015   3370.0
# 2  weighted avg  52.149931  63.827893   0.550334   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall  F1 score  support
# 0           QTY  14.509804  60.655738  0.234177     61.0
# 1          PROP    6.53753  49.090909  0.115385     55.0
# 2          PART  68.553459  68.454106  0.685037   2070.0
# 3           WGT        0.0        0.0       0.0      2.0
# 4          RPOS  26.661329  68.518519  0.383862    486.0
# 5          OPER  35.582822  66.412214  0.463382    524.0
# 6           DIM   5.454545  51.428571   0.09863     35.0
# 7          TOOL  23.931624  38.888889  0.296296     72.0
# 8            ID   58.62069  52.307692  0.552846     65.0
# 0      accuracy          -          -  66.52819   3370.0
# 1     macro avg    26.6502  50.639626  0.314402   3370.0
# 2  weighted avg  53.554142   66.52819  0.572329   3370.0

# %% [markdown]
# ### stratified, random

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   6.004619  42.622951   0.105263     61.0
# 1          PROP        0.0        0.0        0.0     55.0
# 2          PART  72.504004  65.603865   0.688816   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS    32.8594  42.798354   0.371761    486.0
# 5          OPER  23.200677  52.290076   0.321408    524.0
# 6           DIM   7.142857   8.571429   0.077922     35.0
# 7          TOOL  42.105263  11.111111   0.175824     72.0
# 8            ID   10.25641  49.230769   0.169761     65.0
# 0      accuracy          -          -  56.646884   3370.0
# 1     macro avg  21.563692  30.247617   0.212306   3370.0
# 2  weighted avg  54.161614  56.646884   0.536434   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  17.391304  32.786885   0.227273     61.0
# 1          PROP   3.100775  14.545455   0.051118     55.0
# 2          PART  67.479109  46.811594   0.552767   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  24.501758  43.004115   0.312173    486.0
# 5          OPER  33.187135  43.320611   0.375828    524.0
# 6           DIM        0.0        0.0        0.0     35.0
# 7          TOOL    9.42029  18.055556    0.12381     72.0
# 8            ID   5.785124  43.076923   0.102004     65.0
# 0      accuracy          -          -  43.738872   3370.0
# 1     macro avg  17.873944  26.844571   0.193886   3370.0
# 2  weighted avg  50.820586  43.738872   0.452551   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  38.888889   34.42623   0.365217     61.0
# 1          PROP  12.269939  36.363636   0.183486     55.0
# 2          PART  60.168472  72.463768   0.657462   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  32.409382   62.55144   0.426966    486.0
# 5          OPER  38.324022  65.458015   0.483439    524.0
# 6           DIM   4.637681  45.714286   0.084211     35.0
# 7          TOOL   9.302326  27.777778   0.139373     72.0
# 8            ID  12.032086  69.230769   0.205011     65.0
# 0      accuracy          -          -  67.329377   3370.0
# 1     macro avg  23.114755  45.998436   0.282796   3370.0
# 2  weighted avg  48.974102  67.329377   0.557998   3370.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_1_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['TOOL', 'ID', 'QTY', 'RPOS', 'PART', 'DIM', 'PROP', 'WGT', 'OPER']
#          entity  precision     recall   F1 score  support
# 0          TOOL  27.192982  43.055556   0.333333     72.0
# 1            ID  30.081301  56.923077   0.393617     65.0
# 2           QTY   9.964413  45.901639   0.163743     61.0
# 3          RPOS  39.903846  51.234568   0.448649    486.0
# 4          PART  80.706179  61.835749   0.700219   2070.0
# 5           DIM   7.894737  34.285714   0.128342     35.0
# 6          PROP   16.82243  32.727273   0.222222     55.0
# 7           WGT       50.0      100.0   0.666667      2.0
# 8          OPER  33.232932  63.167939   0.435526    524.0
# 0      accuracy          -          -  58.991098   3370.0
# 1     macro avg  32.866536  54.347946   0.388035   3370.0
# 2  weighted avg  62.223049  58.991098   0.585559   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  14.354067  49.180328   0.222222     61.0
# 1          PROP   19.58042  50.909091   0.282828     55.0
# 2          PART  78.786334  74.637681   0.766559   2070.0
# 3           WGT       50.0      100.0   0.666667      2.0
# 4          RPOS   36.20283  63.168724    0.46027    486.0
# 5          OPER  44.472362  67.557252   0.536364    524.0
# 6           DIM   7.228916  34.285714   0.119403     35.0
# 7          TOOL       48.0       50.0   0.489796     72.0
# 8            ID  25.735294  53.846154   0.348259     65.0
# 0      accuracy          -          -  69.703264   3370.0
# 1     macro avg  36.040025  60.398327   0.432485   3370.0
# 2  weighted avg  62.735944  69.703264   0.648086   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  22.424242  60.655738   0.327434     61.0
# 1          PROP  21.276596  54.545455   0.306122     55.0
# 2          PART  77.615248  84.589372   0.809524   2070.0
# 3           WGT  66.666667      100.0        0.8      2.0
# 4          RPOS  40.198238  75.102881   0.523673    486.0
# 5          OPER  53.926702  78.625954   0.639752    524.0
# 6           DIM   8.791209  45.714286   0.147465     35.0
# 7          TOOL  50.617284  56.944444   0.535948     72.0
# 8            ID  35.971223  76.923077   0.490196     65.0
# 0      accuracy          -          -  80.237389   3370.0
# 1     macro avg  41.943045  70.344578   0.508902   3370.0
# 2  weighted avg   64.51608  80.237389   0.706075   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  26.865672  59.016393   0.369231     61.0
# 1          PROP  28.205128       60.0   0.383721     55.0
# 2          PART  70.095002  81.980676   0.755734   2070.0
# 3           WGT       20.0       50.0   0.285714      2.0
# 4          RPOS  33.621518  72.016461   0.458415    486.0
# 5          OPER  49.748111  75.381679   0.599393    524.0
# 6           DIM   6.493506  42.857143   0.112782     35.0
# 7          TOOL       40.0       50.0   0.444444     72.0
# 8            ID  27.058824  70.769231   0.391489     65.0
# 0      accuracy          -          -  77.418398   3370.0
# 1     macro avg  33.565307  62.446843   0.422325   3370.0
# 2  weighted avg  58.041812  77.418398   0.654847   3370.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall  F1 score  support
# 0           QTY   9.340659  27.868852  0.139918     61.0
# 1          PROP   6.273063  30.909091  0.104294     55.0
# 2          PART  67.768221  72.318841  0.699696   2070.0
# 3           WGT   3.448276       50.0  0.064516      2.0
# 4          RPOS  22.979798   56.17284  0.326165    486.0
# 5          OPER  32.865169  66.984733  0.440955    524.0
# 6           DIM   4.307692       40.0  0.077778     35.0
# 7          TOOL   22.38806  20.833333  0.215827     72.0
# 8            ID  23.497268  66.153846  0.346774     65.0
# 0      accuracy          -          -  66.11276   3370.0
# 1     macro avg  21.429801  47.915726  0.268436   3370.0
# 2  weighted avg  51.300141   66.11276  0.561766   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   21.83908  31.147541   0.256757     61.0
# 1          PROP   7.926829  23.636364   0.118721     55.0
# 2          PART  67.418546  77.971014   0.723118   2070.0
# 3           WGT  11.111111       50.0   0.181818      2.0
# 4          RPOS  26.495017   65.63786   0.377515    486.0
# 5          OPER  41.311853   68.51145   0.515434    524.0
# 6           DIM   4.819277  57.142857   0.088889     35.0
# 7          TOOL       23.0  31.944444   0.267442     72.0
# 8            ID    29.6875  58.461538   0.393782     65.0
# 0      accuracy          -          -  71.394659   3370.0
# 1     macro avg  25.956579  51.605897   0.324831   3370.0
# 2  weighted avg  53.301224  71.394659   0.599683   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  31.372549  52.459016   0.392638     61.0
# 1          PROP  13.684211  23.636364   0.173333     55.0
# 2          PART  66.554904  76.714976   0.712747   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  31.449407  70.987654   0.435881    486.0
# 5          OPER  39.701174  70.992366    0.50924    524.0
# 6           DIM   3.822938  54.285714   0.071429     35.0
# 7          TOOL  28.888889  36.111111   0.320988     72.0
# 8            ID  33.333333  66.153846   0.443299     65.0
# 0      accuracy          -          -  72.344214   3370.0
# 1     macro avg  27.645267  50.149005   0.339951   3370.0
# 2  weighted avg  53.680506  72.344214   0.605928   3370.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_1_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['TOOL', 'ID', 'QTY', 'RPOS', 'PART', 'DIM', 'PROP', 'WGT', 'OPER']
#          entity  precision     recall   F1 score  support
# 0          TOOL  23.357664  44.444444    0.30622     72.0
# 1            ID  21.656051  52.307692   0.306306     65.0
# 2           QTY   9.854015  44.262295   0.161194     61.0
# 3          RPOS  50.214592  48.148148   0.491597    486.0
# 4          PART  81.985044   58.26087   0.681164   2070.0
# 5           DIM  10.655738  37.142857   0.165605     35.0
# 6          PROP  18.085106  30.909091   0.228188     55.0
# 7           WGT  66.666667      100.0        0.8      2.0
# 8          OPER  28.021486  59.732824   0.381475    524.0
# 0      accuracy          -          -  55.727003   3370.0
# 1     macro avg  34.499596  52.800914   0.391305   3370.0
# 2  weighted avg  63.497937  55.727003   0.569897   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  17.105263  42.622951   0.244131     61.0
# 1          PROP       24.0  43.636364   0.309677     55.0
# 2          PART  78.590786  56.038647   0.654258   2070.0
# 3           WGT  33.333333       50.0        0.4      2.0
# 4          RPOS  35.961272  53.497942   0.430108    486.0
# 5          OPER  40.085592  53.625954   0.458776    524.0
# 6           DIM   8.974359       40.0   0.146597     35.0
# 7          TOOL  37.878788  34.722222   0.362319     72.0
# 8            ID       25.0  41.538462   0.312139     65.0
# 0      accuracy          -          -  53.946588   3370.0
# 1     macro avg  33.436599  46.186949   0.368667   3370.0
# 2  weighted avg   61.79864  53.946588    0.56023   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY       20.0  54.098361   0.292035     61.0
# 1          PROP  19.727891  52.727273   0.287129     55.0
# 2          PART  76.347635   67.05314   0.713992   2070.0
# 3           WGT       40.0      100.0   0.571429      2.0
# 4          RPOS  35.739645  62.139918   0.453794    486.0
# 5          OPER  46.143058   62.78626   0.531932    524.0
# 6           DIM   6.593407  34.285714   0.110599     35.0
# 7          TOOL  52.380952  45.833333   0.488889     72.0
# 8            ID  24.203822  58.461538   0.342342     65.0
# 0      accuracy          -          -  64.272997   3370.0
# 1     macro avg  35.681823  59.709504   0.421349   3370.0
# 2  weighted avg  61.587096  64.272997   0.615226   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  29.054054  70.491803   0.411483     61.0
# 1          PROP  26.923077  63.636364   0.378378     55.0
# 2          PART  73.886193  80.917874   0.772423   2070.0
# 3           WGT  16.666667       50.0       0.25      2.0
# 4          RPOS  37.645811  73.045267   0.496851    486.0
# 5          OPER  52.418301  76.526718   0.622188    524.0
# 6           DIM    8.75576  54.285714   0.150794     35.0
# 7          TOOL  48.314607  59.722222   0.534161     72.0
# 8            ID  26.627219  69.230769   0.384615     65.0
# 0      accuracy          -          -  77.655786   3370.0
# 1     macro avg  35.587965  66.428526   0.444544   3370.0
# 2  weighted avg  61.575592  77.655786   0.677021   3370.0

# %% [markdown]
# ### stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  11.904762  32.786885   0.174672     61.0
# 1          PROP   2.884615  16.363636   0.049046     55.0
# 2          PART  70.959596  67.874396   0.693827   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  25.502183  60.082305   0.358063    486.0
# 5          OPER  32.429907  66.221374   0.435383    524.0
# 6           DIM   3.754266  31.428571   0.067073     35.0
# 7          TOOL  11.956522  15.277778   0.134146     72.0
# 8            ID  10.377358  50.769231   0.172324     65.0
# 0      accuracy          -          -  63.145401   3370.0
# 1     macro avg  18.863246  37.867131   0.231615   3370.0
# 2  weighted avg  53.063898  63.145401   0.556362   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  22.522523  40.983607   0.290698     61.0
# 1          PROP   8.333333  36.363636   0.135593     55.0
# 2          PART  68.139224  73.768116    0.70842   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  26.152623  67.695473   0.377294    486.0
# 5          OPER  37.359263  69.656489   0.486342    524.0
# 6           DIM   3.640777  42.857143   0.067114     35.0
# 7          TOOL  22.105263  29.166667   0.251497     72.0
# 8            ID  21.243523  63.076923   0.317829     65.0
# 0      accuracy          -          -  69.525223   3370.0
# 1     macro avg  23.277392  47.063117   0.292754   3370.0
# 2  weighted avg   52.89812  69.525223    0.58485   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  27.272727  49.180328   0.350877     61.0
# 1          PROP  14.012739       40.0   0.207547     55.0
# 2          PART  67.133816   71.73913   0.693601   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  32.082922  66.872428   0.433622    486.0
# 5          OPER  42.248521  68.129771   0.521549    524.0
# 6           DIM   3.386005  42.857143   0.062762     35.0
# 7          TOOL  28.431373  40.277778   0.333333     72.0
# 8            ID  30.405405  69.230769   0.422535     65.0
# 0      accuracy          -          -  68.486647   3370.0
# 1     macro avg  27.219279  49.809705   0.336203   3370.0
# 2  weighted avg  54.383911  68.486647   0.595331   3370.0

# %% [markdown]
# ### not stratified, tf-idf_half

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY      18.75  44.262295   0.263415     61.0
# 1          PROP  18.681319  30.909091   0.232877     55.0
# 2          PART  79.739904  56.280193    0.65987   2070.0
# 3           WGT       25.0       50.0   0.333333      2.0
# 4          RPOS  40.350877  52.057613   0.454627    486.0
# 5          OPER  37.698413  54.389313   0.445312    524.0
# 6           DIM   9.090909  37.142857   0.146067     35.0
# 7          TOOL  34.328358  31.944444   0.330935     72.0
# 8            ID  24.778761  43.076923   0.314607     65.0
# 0      accuracy          -          -  53.768546   3370.0
# 1     macro avg  32.046505  44.451414   0.353449   3370.0
# 2  weighted avg  62.625449  53.768546   0.563548   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall  F1 score  support
# 0           QTY  15.591398  47.540984  0.234818     61.0
# 1          PROP  16.071429  32.727273  0.215569     55.0
# 2          PART  75.990676  62.995169  0.688854   2070.0
# 3           WGT  33.333333      100.0       0.5      2.0
# 4          RPOS  37.121212  60.493827  0.460094    486.0
# 5          OPER  42.234332  59.160305  0.492846    524.0
# 6           DIM   7.482993  31.428571  0.120879     35.0
# 7          TOOL  44.927536  43.055556  0.439716     72.0
# 8            ID  28.030303  56.923077  0.375635     65.0
# 0      accuracy          -          -  60.41543   3370.0
# 1     macro avg  33.420357  54.924974  0.392046   3370.0
# 2  weighted avg  60.739681   60.41543  0.592068   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY  25.730994  72.131148    0.37931     61.0
# 1          PROP  29.661017  63.636364   0.404624     55.0
# 2          PART  76.824231  80.869565    0.78795   2070.0
# 3           WGT       25.0       50.0   0.333333      2.0
# 4          RPOS  40.198238  75.102881   0.523673    486.0
# 5          OPER  50.721154  80.534351   0.622419    524.0
# 6           DIM   9.574468  51.428571   0.161435     35.0
# 7          TOOL  49.438202  61.111111   0.546584     72.0
# 8            ID  29.518072  75.384615   0.424242     65.0
# 0      accuracy          -          -  78.694362   3370.0
# 1     macro avg  37.407375  67.799845   0.464841   3370.0
# 2  weighted avg  63.562215  78.694362   0.691498   3370.0

# %% [markdown]
# ### stratified, tf-idf_half

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   5.555556  18.032787   0.084942     61.0
# 1          PROP   3.717472  18.181818   0.061728     55.0
# 2          PART  67.387387  54.202899   0.600803   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  24.039517  45.061728   0.313529    486.0
# 5          OPER  23.245985  52.480916   0.322203    524.0
# 6           DIM   3.205128  14.285714   0.052356     35.0
# 7          TOOL  13.414634  15.277778   0.142857     72.0
# 8            ID   8.303249  35.384615   0.134503     65.0
# 0      accuracy          -          -  49.732938   3370.0
# 1     macro avg  16.540992  28.100917   0.190325   3370.0
# 2  weighted avg  49.114863  49.732938   0.473089   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   5.603448  21.311475   0.088737     61.0
# 1          PROP   3.389831  14.545455   0.054983     55.0
# 2          PART  65.960744  61.690821   0.637544   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  21.180275  53.909465   0.304121    486.0
# 5          OPER  26.608696  58.396947   0.365591    524.0
# 6           DIM        4.5  25.714286   0.076596     35.0
# 7          TOOL  14.705882  13.888889   0.142857     72.0
# 8            ID   10.15625       40.0   0.161994     65.0
# 0      accuracy          -          -  56.706231   3370.0
# 1     macro avg  16.900569  32.161926   0.203602   3370.0
# 2  weighted avg  48.421377  56.706231   0.501787   3370.0

# %%
with open("formal_eva_results_llama2chat13b/assembly_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'PROP', 'PART', 'WGT', 'RPOS', 'OPER', 'DIM', 'TOOL', 'ID']
#          entity  precision     recall   F1 score  support
# 0           QTY   9.433962  32.786885    0.14652     61.0
# 1          PROP   5.347594  18.181818   0.082645     55.0
# 2          PART  63.421053  69.855072   0.664828   2070.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          RPOS  22.919937  60.082305   0.331818    486.0
# 5          OPER  32.458698  63.740458   0.430135    524.0
# 6           DIM   3.355705  28.571429    0.06006     35.0
# 7          TOOL  21.621622  22.222222   0.219178     72.0
# 8            ID  14.035088  49.230769    0.21843     65.0
# 0      accuracy          -          -  64.094955   3370.0
# 1     macro avg  19.177073  38.296773    0.23929   3370.0
# 2  weighted avg  48.333858  64.094955   0.536621   3370.0

# %% [markdown]
# # Fabner

# %%
with open("data/immutable_data_formal/sen_fabner_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### zero-shot

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response_zero_shot(response)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['APPL', 'CONPRI', 'PARA', 'ENAT', 'FEAT', 'PRO', 'MATE', 'MACEQ', 'MANS', 'MANP', 'CHAR', 'BIOP']
#           entity  precision     recall   F1 score  support
# 0           APPL   2.803738   6.666667   0.039474     90.0
# 1         CONPRI  12.128713   5.235043   0.073134    936.0
# 2           PARA   5.405405   2.051282    0.02974    195.0
# 3           ENAT        0.0        0.0        0.0     52.0
# 4           FEAT        0.0        0.0        0.0    153.0
# 5            PRO  10.706638  23.696682   0.147493    211.0
# 6           MATE  24.444444  18.265683   0.209081    542.0
# 7          MACEQ   5.389222   7.086614   0.061224    127.0
# 8           MANS        0.0        0.0        0.0      4.0
# 9           MANP  20.879121  18.706048   0.197329    711.0
# 10          CHAR   1.470588   0.512821   0.007605    195.0
# 11          BIOP        0.0        0.0        0.0      9.0
# 0       accuracy          -          -  10.883721   3225.0
# 1      macro avg   6.935656   6.851737   0.063757   3225.0
# 2   weighted avg  13.638172  10.883721   0.115289   3225.0

# %% [markdown]
# ### not stratified, random

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_1_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL   6.535948  11.111111   0.082305     90.0
# 2         CONPRI  19.292605  19.230769   0.192616    936.0
# 3           ENAT        0.0        0.0        0.0     52.0
# 4           MANS        0.0        0.0        0.0      4.0
# 5          MACEQ  10.869565   7.874016   0.091324    127.0
# 6            PRO  31.538462   19.43128   0.240469    211.0
# 7           CHAR   0.952381   3.589744   0.015054    195.0
# 8           PARA  12.015504  47.692308    0.19195    195.0
# 9           MATE  29.166667   7.749077   0.122449    542.0
# 10          FEAT        0.0        0.0        0.0    153.0
# 11          MANP  20.757576  19.268636   0.199854    711.0
# 0       accuracy          -          -  16.124031   3225.0
# 1      macro avg  10.927392  11.328912   0.094668   3225.0
# 2   weighted avg  18.535464  16.124031   0.154686   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL       20.0   6.666667        0.1     90.0
# 2         CONPRI  23.148148  29.380342   0.258945    936.0
# 3           ENAT        0.0        0.0        0.0     52.0
# 4           MANS   2.083333       50.0       0.04      4.0
# 5          MACEQ  20.618557  15.748031   0.178571    127.0
# 6            PRO  24.256293  50.236967    0.32716    211.0
# 7           CHAR  30.923695  39.487179   0.346847    195.0
# 8           PARA  23.033708  21.025641   0.219839    195.0
# 9           MATE  33.671171  55.166052   0.418182    542.0
# 10          FEAT  11.658031  29.411765   0.166976    153.0
# 11          MANP  37.148218  55.696203   0.445695    711.0
# 0       accuracy          -          -  39.286822   3225.0
# 1      macro avg  18.878429  29.401571   0.208518   3225.0
# 2   weighted avg  27.342377  39.286822   0.317159   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL  17.647059   3.333333   0.056075     90.0
# 2         CONPRI  23.115578  29.487179   0.259155    936.0
# 3           ENAT        0.0        0.0        0.0     52.0
# 4           MANS   1.428571       25.0   0.027027      4.0
# 5          MACEQ  26.548673  23.622047       0.25    127.0
# 6            PRO  25.223214  53.554502   0.342944    211.0
# 7           CHAR  52.475248  27.179487   0.358108    195.0
# 8           PARA  18.024691  37.435897   0.243333    195.0
# 9           MATE  31.597222  50.369004   0.388336    542.0
# 10          FEAT  15.925926  28.104575    0.20331    153.0
# 11          MANP  38.226601  54.571027   0.449594    711.0
# 0       accuracy          -          -  38.852713   3225.0
# 1      macro avg  20.851065  27.721421   0.214823   3225.0
# 2   weighted avg  28.655154  38.852713   0.319492   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL  10.948905  16.666667   0.132159     90.0
# 2         CONPRI  30.655738  19.978632   0.241915    936.0
# 3           ENAT        0.0        0.0        0.0     52.0
# 4           MANS   1.010101       25.0   0.019417      4.0
# 5          MACEQ  29.007634   29.92126   0.294574    127.0
# 6            PRO   23.26087    50.7109   0.318927    211.0
# 7           CHAR  59.504132  36.923077   0.455696    195.0
# 8           PARA  15.339806  40.512821   0.222535    195.0
# 9           MATE  33.601286  38.560886   0.359107    542.0
# 10          FEAT  16.718266  35.294118   0.226891    153.0
# 11          MANP   36.24498  50.773558   0.422964    711.0
# 0       accuracy          -          -  34.821705   3225.0
# 1      macro avg  21.357643   28.69516   0.224515   3225.0
# 2   weighted avg  30.824734  34.821705   0.311765   3225.0

# %% [markdown]
# ### stratified, random

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL  13.333333   8.888889   0.106667     90.0
# 2         CONPRI  24.406048  36.217949   0.291613    936.0
# 3           ENAT   7.638889  21.153846   0.112245     52.0
# 4           MANS   0.291971       50.0   0.005806      4.0
# 5          MACEQ  15.566038  25.984252    0.19469    127.0
# 6            PRO   21.73913   2.369668   0.042735    211.0
# 7           CHAR        0.0        0.0        0.0    195.0
# 8           PARA  15.733333  60.512821   0.249735    195.0
# 9           MATE  34.782609  16.236162   0.221384    542.0
# 10          FEAT  13.736264  16.339869   0.149254    153.0
# 11          MANP  47.705146  48.241913    0.47972    711.0
# 0       accuracy          -          -  30.139535   3225.0
# 1      macro avg  16.244397  23.828781   0.154487   3225.0
# 2   weighted avg  27.580302  30.139535   0.265041   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL     11.875  21.111111      0.152     90.0
# 2         CONPRI  29.709035  20.726496   0.244179    936.0
# 3           ENAT  15.789474  23.076923     0.1875     52.0
# 4           MANS   0.666667       75.0   0.013216      4.0
# 5          MACEQ  13.716814  24.409449   0.175637    127.0
# 6            PRO        0.0        0.0        0.0    211.0
# 7           CHAR       38.4  24.615385        0.3    195.0
# 8           PARA  15.461347  63.589744   0.248746    195.0
# 9           MATE   38.15331  40.405904   0.392473    542.0
# 10          FEAT  13.333333   27.45098   0.179487    153.0
# 11          MANP  45.454545  50.632911   0.479042    711.0
# 0       accuracy          -          -  32.620155   3225.0
# 1      macro avg  18.546627  30.918242    0.19769   3225.0
# 2   weighted avg  30.072062  32.620155   0.298334   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        0.0        0.0        0.0      9.0
# 1           APPL  19.811321  23.333333   0.214286     90.0
# 2         CONPRI  30.864198  21.367521   0.252525    936.0
# 3           ENAT   21.73913   9.615385   0.133333     52.0
# 4           MANS   0.884956       75.0   0.017493      4.0
# 5          MACEQ  12.449799  24.409449   0.164894    127.0
# 6            PRO  24.869565  67.772512   0.363868    211.0
# 7           CHAR  76.595745  36.923077    0.49827    195.0
# 8           PARA  27.586207  49.230769   0.353591    195.0
# 9           MATE   26.10261  53.505535   0.350877    542.0
# 10          FEAT  10.060362  32.679739   0.153846    153.0
# 11          MANP  45.679012  62.447257   0.527629    711.0
# 0       accuracy          -          -  42.015504   3225.0
# 1      macro avg  24.720242  38.023715   0.252551   3225.0
# 2   weighted avg  33.213827  42.015504   0.345842   3225.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_1_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   5.263158  11.111111   0.071429      9.0
# 1           APPL   9.565217  24.444444     0.1375     90.0
# 2         CONPRI  27.364865  25.961538   0.266447    936.0
# 3           ENAT  14.084507  19.230769   0.162602     52.0
# 4           MANS        0.0        0.0        0.0      4.0
# 5          MACEQ  14.705882  19.685039    0.16835    127.0
# 6            PRO  24.935733  45.971564   0.323333    211.0
# 7           CHAR  35.172414  26.153846        0.3    195.0
# 8           PARA       22.5  23.076923   0.227848    195.0
# 9           MATE  29.058824  45.571956   0.354885    542.0
# 10          FEAT  30.769231  13.071895   0.183486    153.0
# 11          MANP  33.512352  43.881857   0.380024    711.0
# 0       accuracy          -          -  33.271318   3225.0
# 1      macro avg  20.577682  24.846745   0.214659   3225.0
# 2   weighted avg  27.880375  33.271318    0.29582   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall  F1 score  support
# 0           BIOP  12.765957  66.666667  0.214286      9.0
# 1           APPL   15.47619  28.888889   0.20155     90.0
# 2         CONPRI  32.604374  35.042735  0.337796    936.0
# 3           ENAT       45.0  34.615385  0.391304     52.0
# 4           MANS   1.754386       25.0  0.032787      4.0
# 5          MACEQ  18.131868  25.984252  0.213592    127.0
# 6            PRO  25.925926  56.398104  0.355224    211.0
# 7           CHAR  62.962963  34.871795  0.448845    195.0
# 8           PARA  26.923077  35.897436  0.307692    195.0
# 9           MATE  32.635061  54.612546  0.408558    542.0
# 10          FEAT  36.170213  33.333333  0.346939    153.0
# 11          MANP  46.215596  56.680731   0.50916    711.0
# 0       accuracy          -          -      44.0   3225.0
# 1      macro avg  29.713801  40.665989  0.313978   3225.0
# 2   weighted avg   35.89299       44.0  0.385383   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP  14.285714  88.888889   0.246154      9.0
# 1           APPL  12.953368  27.777778   0.176678     90.0
# 2         CONPRI   35.40146  41.452991    0.38189    936.0
# 3           ENAT  37.777778  32.692308   0.350515     52.0
# 4           MANS   4.651163       50.0   0.085106      4.0
# 5          MACEQ  21.794872   40.15748   0.282548    127.0
# 6            PRO  27.075099   64.92891   0.382148    211.0
# 7           CHAR       70.0  35.897436   0.474576    195.0
# 8           PARA  22.739726  42.564103   0.296429    195.0
# 9           MATE  34.009009  55.719557   0.422378    542.0
# 10          FEAT  29.714286  33.986928   0.317073    153.0
# 11          MANP  49.137931  64.135021   0.556437    711.0
# 0       accuracy          -          -  49.333333   3225.0
# 1      macro avg    29.9617   48.18345   0.330994   3225.0
# 2   weighted avg  37.486657  49.333333   0.413663   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP  10.144928  77.777778   0.179487      9.0
# 1           APPL  13.068182  25.555556   0.172932     90.0
# 2         CONPRI  34.011091  39.316239   0.364718    936.0
# 3           ENAT  51.515152  32.692308        0.4     52.0
# 4           MANS       6.25       50.0   0.111111      4.0
# 5          MACEQ  19.196429  33.858268   0.245014    127.0
# 6            PRO  29.333333  62.559242   0.399395    211.0
# 7           CHAR  68.965517  41.025641   0.514469    195.0
# 8           PARA   24.81203  50.769231   0.333333    195.0
# 9           MATE  29.817008  51.107011   0.376615    542.0
# 10          FEAT  38.064516  38.562092   0.383117    153.0
# 11          MANP  46.610169  61.884669   0.531722    711.0
# 0       accuracy          -          -  47.968992   3225.0
# 1      macro avg  30.982363  47.092336   0.334326   3225.0
# 2   weighted avg  36.540785  47.968992   0.403506   3225.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   7.692308  44.444444   0.131148      9.0
# 1           APPL   5.882353  11.111111   0.076923     90.0
# 2         CONPRI  25.121163  33.226496   0.286109    936.0
# 3           ENAT  16.901408  23.076923   0.195122     52.0
# 4           MANS   0.884956       50.0   0.017391      4.0
# 5          MACEQ   10.40724  18.110236   0.132184    127.0
# 6            PRO  24.524313  54.976303   0.339181    211.0
# 7           CHAR   61.22449  15.384615   0.245902    195.0
# 8           PARA       25.0  38.461538    0.30303    195.0
# 9           MATE  28.828829  41.328413   0.339651    542.0
# 10          FEAT  28.985507  13.071895    0.18018    153.0
# 11          MANP   42.17119  56.821378   0.484122    711.0
# 0       accuracy          -          -  38.170543   3225.0
# 1      macro avg  23.135313  33.334446   0.227579   3225.0
# 2   weighted avg  30.495601  38.170543   0.321669   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   4.395604  44.444444       0.08      9.0
# 1           APPL   9.677419  16.666667   0.122449     90.0
# 2         CONPRI  29.154796  32.799145   0.308698    936.0
# 3           ENAT  27.659574       25.0   0.262626     52.0
# 4           MANS   1.639344       50.0   0.031746      4.0
# 5          MACEQ  16.104869  33.858268   0.218274    127.0
# 6            PRO  24.231465  63.507109   0.350785    211.0
# 7           CHAR  74.193548  35.384615   0.479167    195.0
# 8           PARA  20.915033  49.230769   0.293578    195.0
# 9           MATE  30.788177  46.125461   0.369276    542.0
# 10          FEAT  19.021739  22.875817   0.207715    153.0
# 11          MANP  43.951165  55.696203   0.491315    711.0
# 0       accuracy          -          -  42.294574   3225.0
# 1      macro avg  25.144395  39.632375   0.267969   3225.0
# 2   weighted avg  32.928806  42.294574   0.356012   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   6.410256  55.555556   0.114943      9.0
# 1           APPL  15.789474       30.0   0.206897     90.0
# 2         CONPRI  34.086444   37.07265   0.355169    936.0
# 3           ENAT  26.666667  15.384615   0.195122     52.0
# 4           MANS   2.197802       50.0   0.042105      4.0
# 5          MACEQ  18.181818   29.92126    0.22619    127.0
# 6            PRO  28.037383  56.872038   0.375587    211.0
# 7           CHAR  83.098592   30.25641   0.443609    195.0
# 8           PARA  19.103314   50.25641   0.276836    195.0
# 9           MATE  27.896996   47.97048   0.352782    542.0
# 10          FEAT  35.064935  35.294118   0.351792    153.0
# 11          MANP  44.142259  59.353024   0.506299    711.0
# 0       accuracy          -          -  44.651163   3225.0
# 1      macro avg  28.389662  41.494713   0.287277   3225.0
# 2   weighted avg  35.598052  44.651163   0.377017   3225.0

# %% [markdown]
# ### not stratified, tfidf

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_1_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall  F1 score  support
# 0           BIOP       15.0  33.333333  0.206897      9.0
# 1           APPL  11.415525  27.777778  0.161812     90.0
# 2         CONPRI  26.741803  27.884615  0.273013    936.0
# 3           ENAT  13.513514   9.615385   0.11236     52.0
# 4           MANS   1.724138       25.0  0.032258      4.0
# 5          MACEQ  10.280374  17.322835  0.129032    127.0
# 6            PRO  21.782178  41.706161  0.286179    211.0
# 7           CHAR  36.363636  28.717949  0.320917    195.0
# 8           PARA  23.111111  26.666667  0.247619    195.0
# 9           MATE  30.787589  47.601476  0.373913    542.0
# 10          FEAT  19.753086  10.457516  0.136752    153.0
# 11          MANP   33.96861  42.616034  0.378041    711.0
# 0       accuracy          -          -  33.79845   3225.0
# 1      macro avg   20.37013  28.224979  0.221566   3225.0
# 2   weighted avg  27.368163   33.79845  0.297037   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP  13.157895  55.555556   0.212766      9.0
# 1           APPL  18.539326  36.666667   0.246269     90.0
# 2         CONPRI  35.328754  38.461538   0.368286    936.0
# 3           ENAT  25.490196       25.0   0.252427     52.0
# 4           MANS   6.382979       75.0   0.117647      4.0
# 5          MACEQ  22.988506  31.496063   0.265781    127.0
# 6            PRO  31.428571  62.559242   0.418384    211.0
# 7           CHAR  56.296296  38.974359   0.460606    195.0
# 8           PARA  31.212121  52.820513   0.392381    195.0
# 9           MATE  35.083532  54.243542   0.426087    542.0
# 10          FEAT  39.449541  28.104575   0.328244    153.0
# 11          MANP  47.690387  53.727145   0.505291    711.0
# 0       accuracy          -          -  46.015504   3225.0
# 1      macro avg  30.254009  46.050767   0.332847   3225.0
# 2   weighted avg  37.761155  46.015504   0.406567   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   15.09434  88.888889   0.258065      9.0
# 1           APPL  19.047619  44.444444   0.266667     90.0
# 2         CONPRI  38.279933  48.504274   0.427898    936.0
# 3           ENAT  38.181818  40.384615   0.392523     52.0
# 4           MANS   9.090909       75.0   0.162162      4.0
# 5          MACEQ   24.21875  48.818898    0.32376    127.0
# 6            PRO  30.184805  69.668246   0.421203    211.0
# 7           CHAR       71.2  45.641026    0.55625    195.0
# 8           PARA       27.5  62.051282   0.381102    195.0
# 9           MATE  33.258929   54.98155   0.414465    542.0
# 10          FEAT  35.057471  39.869281   0.373089    153.0
# 11          MANP  52.505967  61.884669   0.568108    711.0
# 0       accuracy          -          -  54.077519   3225.0
# 1      macro avg  32.801712  56.678098   0.378774   3225.0
# 2   weighted avg  40.035696  54.077519   0.448471   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP  11.764706  88.888889   0.207792      9.0
# 1           APPL  19.753086  35.555556   0.253968     90.0
# 2         CONPRI  41.186586  51.175214   0.456408    936.0
# 3           ENAT  36.956522  32.692308   0.346939     52.0
# 4           MANS   5.555556       50.0        0.1      4.0
# 5          MACEQ  29.184549  53.543307   0.377778    127.0
# 6            PRO  35.235732  67.298578   0.462541    211.0
# 7           CHAR  73.170732  46.153846   0.566038    195.0
# 8           PARA  27.858628  68.717949    0.39645    195.0
# 9           MATE  36.619718  57.564576   0.447633    542.0
# 10          FEAT  28.717949  36.601307   0.321839    153.0
# 11          MANP  50.973654  62.587904   0.561869    711.0
# 0       accuracy          -          -  55.348837   3225.0
# 1      macro avg  33.081452  54.231619   0.374938   3225.0
# 2   weighted avg  41.458657  55.348837   0.463557   3225.0

# %% [markdown]
# ### stratified, tfidf

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   3.592814  66.666667   0.068182      9.0
# 1           APPL   4.458599   7.777778    0.05668     90.0
# 2         CONPRI  27.234401  34.508547    0.30443    936.0
# 3           ENAT        8.0   7.692308   0.078431     52.0
# 4           MANS        0.0        0.0        0.0      4.0
# 5          MACEQ   15.72327  19.685039   0.174825    127.0
# 6            PRO  26.133333  46.445498   0.334471    211.0
# 7           CHAR  17.021277   4.102564   0.066116    195.0
# 8           PARA  21.428571  35.384615   0.266925    195.0
# 9           MATE  25.692137  42.804428   0.321107    542.0
# 10          FEAT  20.183486  14.379085   0.167939    153.0
# 11          MANP  40.833333  55.133615    0.46918    711.0
# 0       accuracy          -          -  36.775194   3225.0
# 1      macro avg  17.525102  27.881679   0.192357   3225.0
# 2   weighted avg  27.099358  36.775194   0.305668   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   3.896104  33.333333   0.069767      9.0
# 1           APPL   9.268293  21.111111   0.128814     90.0
# 2         CONPRI  29.894938  33.440171   0.315683    936.0
# 3           ENAT  23.529412  15.384615   0.186047     52.0
# 4           MANS   4.819277      100.0   0.091954      4.0
# 5          MACEQ  15.450644  28.346457        0.2    127.0
# 6            PRO  24.029575  61.611374   0.345745    211.0
# 7           CHAR       62.5  30.769231   0.412371    195.0
# 8           PARA  25.067385  47.692308   0.328622    195.0
# 9           MATE  28.159204  52.214022   0.365869    542.0
# 10          FEAT  20.283019  28.104575   0.235616    153.0
# 11          MANP  44.524793  60.618847   0.513401    711.0
# 0       accuracy          -          -  44.124031   3225.0
# 1      macro avg   24.28522  42.718837   0.266157   3225.0
# 2   weighted avg  32.317678  44.124031    0.35968   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall  F1 score  support
# 0           BIOP   4.255319  44.444444   0.07767      9.0
# 1           APPL   9.223301  21.111111  0.128378     90.0
# 2         CONPRI   30.70018  36.538462  0.333659    936.0
# 3           ENAT  33.333333  28.846154  0.309278     52.0
# 4           MANS   4.477612       75.0  0.084507      4.0
# 5          MACEQ  23.295455  32.283465  0.270627    127.0
# 6            PRO  28.444444  60.663507  0.387292    211.0
# 7           CHAR  69.148936  33.333333  0.449827    195.0
# 8           PARA  22.621564  54.871795  0.320359    195.0
# 9           MATE   29.20082  52.583026  0.375494    542.0
# 10          FEAT  18.877551  24.183007  0.212034    153.0
# 11          MANP  45.523193  59.353024  0.515263    711.0
# 0       accuracy          -          -  45.51938   3225.0
# 1      macro avg  26.591809  43.600944  0.288699   3225.0
# 2   weighted avg  33.889195   45.51938  0.375058   3225.0

# %% [markdown]
# ### not stratified, tfidf_half

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP        8.0  22.222222   0.117647      9.0
# 1           APPL  13.541667  28.888889   0.184397     90.0
# 2         CONPRI  33.695652  36.431624   0.350103    936.0
# 3           ENAT  30.612245  28.846154    0.29703     52.0
# 4           MANS   2.173913       25.0       0.04      4.0
# 5          MACEQ  24.539877  31.496063   0.275862    127.0
# 6            PRO  27.111111  57.819905   0.369138    211.0
# 7           CHAR  62.992126  41.025641   0.496894    195.0
# 8           PARA  26.234568  43.589744   0.327553    195.0
# 9           MATE   32.51462  51.291513   0.397996    542.0
# 10          FEAT  29.861111  28.104575   0.289562    153.0
# 11          MANP  45.283019  50.632911   0.478088    711.0
# 0       accuracy          -          -  43.193798   3225.0
# 1      macro avg  28.046659  37.112437   0.302022   3225.0
# 2   weighted avg  35.675822  43.193798   0.382816   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   7.692308  44.444444   0.131148      9.0
# 1           APPL  11.386139  25.555556   0.157534     90.0
# 2         CONPRI  36.406397  41.346154   0.387194    936.0
# 3           ENAT  36.538462  36.538462   0.365385     52.0
# 4           MANS   1.754386       25.0   0.032787      4.0
# 5          MACEQ  25.668449  37.795276   0.305732    127.0
# 6            PRO  25.396825  60.663507   0.358042    211.0
# 7           CHAR  73.873874  42.051282   0.535948    195.0
# 8           PARA  28.954424  55.384615   0.380282    195.0
# 9           MATE  34.777651  56.273063    0.42988    542.0
# 10          FEAT  30.612245  39.215686    0.34384    153.0
# 11          MANP  45.937161  59.634318   0.518972    711.0
# 0       accuracy          -          -  49.271318   3225.0
# 1      macro avg  29.916527   43.65853   0.328895   3225.0
# 2   weighted avg  37.811477  49.271318    0.41691   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP       12.5  77.777778   0.215385      9.0
# 1           APPL  14.606742  28.888889    0.19403     90.0
# 2         CONPRI  39.249771  45.833333   0.422868    936.0
# 3           ENAT  34.693878  32.692308   0.336634     52.0
# 4           MANS   6.896552       50.0   0.121212      4.0
# 5          MACEQ  28.061224  43.307087   0.340557    127.0
# 6            PRO  28.343313  67.298578   0.398876    211.0
# 7           CHAR  68.333333  42.051282   0.520635    195.0
# 8           PARA  25.720621  59.487179   0.359133    195.0
# 9           MATE  34.549601  55.904059   0.427061    542.0
# 10          FEAT  25.877193  38.562092   0.309711    153.0
# 11          MANP  48.911798  60.056259   0.539141    711.0
# 0       accuracy          -          -  51.627907   3225.0
# 1      macro avg  30.645336  50.154904    0.34877   3225.0
# 2   weighted avg  38.865947  51.627907   0.432356   3225.0

# %% [markdown]
# ### stratified, tfidf_half

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   1.507538  33.333333   0.028846      9.0
# 1           APPL   8.527132  12.222222   0.100457     90.0
# 2         CONPRI   24.85482  22.863248   0.238175    936.0
# 3           ENAT       12.5   7.692308   0.095238     52.0
# 4           MANS   2.272727       25.0   0.041667      4.0
# 5          MACEQ  17.159763  22.834646   0.195946    127.0
# 6            PRO  17.424242  32.701422   0.227348    211.0
# 7           CHAR  29.577465  10.769231   0.157895    195.0
# 8           PARA  19.138756  20.512821    0.19802    195.0
# 9           MATE  19.783465  37.084871   0.258023    542.0
# 10          FEAT   7.446809   4.575163    0.05668    153.0
# 11          MANP   29.83871  41.631505   0.347622    711.0
# 0       accuracy          -          -  27.782946   3225.0
# 1      macro avg  15.835952  22.601731    0.16216   3225.0
# 2   weighted avg   22.67814  27.782946     0.2404   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall  F1 score  support
# 0           BIOP   1.360544  22.222222  0.025641      9.0
# 1           APPL    9.23913  18.888889  0.124088     90.0
# 2         CONPRI  24.150485  21.260684  0.226136    936.0
# 3           ENAT  15.789474  11.538462  0.133333     52.0
# 4           MANS   2.040816       25.0  0.037736      4.0
# 5          MACEQ  14.285714  21.259843  0.170886    127.0
# 6            PRO  19.649123  53.080569  0.286812    211.0
# 7           CHAR  43.333333  13.333333  0.203922    195.0
# 8           PARA  14.015152  18.974359   0.16122    195.0
# 9           MATE  20.503597  42.066421  0.275695    542.0
# 10          FEAT  10.619469   7.843137  0.090226    153.0
# 11          MANP  36.512821  50.070323  0.422301    711.0
# 0       accuracy          -          -  31.72093   3225.0
# 1      macro avg  17.624972   25.46152  0.179833   3225.0
# 2   weighted avg   24.84322   31.72093  0.262653   3225.0

# %%
with open("formal_eva_results_llama2chat13b/fabner_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['BIOP', 'APPL', 'CONPRI', 'ENAT', 'MANS', 'MACEQ', 'PRO', 'CHAR', 'PARA', 'MATE', 'FEAT', 'MANP']
#           entity  precision     recall   F1 score  support
# 0           BIOP   7.894737  66.666667   0.141176      9.0
# 1           APPL   7.386364  14.444444   0.097744     90.0
# 2         CONPRI  27.050998  26.068376   0.265506    936.0
# 3           ENAT  16.129032   9.615385   0.120482     52.0
# 4           MANS   2.777778       25.0       0.05      4.0
# 5          MACEQ  14.814815  18.897638    0.16609    127.0
# 6            PRO  21.984436  53.554502   0.311724    211.0
# 7           CHAR  45.205479  16.923077   0.246269    195.0
# 8           PARA  14.239482  22.564103   0.174603    195.0
# 9           MATE  21.834862  43.911439   0.291667    542.0
# 10          FEAT  13.636364   13.72549   0.136808    153.0
# 11          MANP  38.058991   56.25879    0.45403    711.0
# 0       accuracy          -          -  35.410853   3225.0
# 1      macro avg  19.251112  30.635826   0.204675   3225.0
# 2   weighted avg  26.666092  35.410853   0.290175   3225.0

# %%
import pickle
import nltk
nltk.download('punkt')

from gpt_ner_api_codes.prompts_all import *
from gpt_ner_api_codes.demonstration_samples_generation import *
# %reload_ext autoreload
# %autoreload 2

import tqdm
def nop(it, *a, **k):
    return it
tqdm.tqdm = nop
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Thin film head technology dataset

# %%
with open("data/immutable_data_formal/sen_thf_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### Zero-shot

# %%
def process_response_zero_shot_gpt(response):
    processed_response = []
    for demonstrations_one_sentence in response:
        rows_list = demonstrations_one_sentence.split("\n")

        processed_demonstrations_one_sentence = ""
        for row in rows_list:
            entity_one_row = row.split(": ")[0]
            if len(row.split(": ")) > 1:
                extracted_words_list = row.split(": ")[1].split(", ")    
            else:
                extracted_words_list = row.split(": ")[0].split(", ")    
            processed_demonstrations_one_row = ""
            for extracted_word in extracted_words_list:
                processed_demonstrations_one_row = processed_demonstrations_one_row + extracted_word + ": " + entity_one_row + '\n'
            processed_demonstrations_one_sentence = processed_demonstrations_one_sentence + processed_demonstrations_one_row 

        processed_response.append(processed_demonstrations_one_sentence)    
    
    return processed_response

# %%
#### example = 0
with open("data/immutable_data_formal/sen_thf_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)  
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 0)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_0_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500

# %%
processed_response = process_response_zero_shot_gpt(response)
# print(processed_response[0])

# %%
transformed_output = change_output_format_to_tokens_tags(sentences_input, processed_response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Component', 'ScientificConcept', 'Attribution', 'System', 'Function', 'EnergyFlow', 'State', 'Effect', 'Shape', 'Consequence', 'Location', 'PhysicsFlow', 'Material', 'Value', 'AnnotatorNotes', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure   1.287554   7.894737    0.02214     38.0
# 1           Component   50.75337  29.090909   0.369835   2200.0
# 2   ScientificConcept   9.467456   8.791209   0.091168    182.0
# 3         Attribution   7.407407   2.688172   0.039448    372.0
# 4              System   5.821918   6.995885   0.063551    243.0
# 5            Function   2.785924   6.050955   0.038153    314.0
# 6          EnergyFlow  26.373626   6.282723    0.10148    382.0
# 7               State   1.027397      100.0   0.020339      6.0
# 8              Effect   9.179688  18.007663   0.121604    261.0
# 9               Shape   7.236842   5.759162    0.06414    191.0
# 10        Consequence   0.655738  18.181818   0.012658     22.0
# 11           Location   9.142053   13.71308   0.109705    474.0
# 12        PhysicsFlow        0.0        0.0        0.0     28.0
# 13           Material  28.852459  27.848101   0.283414    316.0
# 14              Value   5.345912  28.333333   0.089947     60.0
# 15     AnnotatorNotes   0.095694  33.333333   0.001908      3.0
# 16           InfoFlow    2.55102   5.617978   0.035088     89.0
# 0            accuracy          -          -  18.780158   5181.0
# 1           macro avg   9.881415  18.740533   0.086152   5181.0
# 2        weighted avg   28.24681  18.780158   0.213551   5181.0

# %% [markdown]
# ### not stratified, random

# %%
with open("data/immutable_data_formal/sen_thf_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)  
    
print(len(all_fewshot_sen), len(all_fewshot_dem) )
# Out:
# 500 500

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 1)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_1_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  64.071856  28.010471     0.3898    382.0
# 1   ScientificConcept  14.942529   7.142857   0.096654    182.0
# 2            InfoFlow  66.666667  35.955056   0.467153     89.0
# 3              Effect  22.709163   21.83908   0.222656    261.0
# 4              System  14.868805  20.987654   0.174061    243.0
# 5             Measure  12.162162  47.368421   0.193548     38.0
# 6            Material  52.148997  57.594937   0.547368    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence   4.347826   4.545455   0.044444     22.0
# 10           Location  28.293737  27.637131   0.279616    474.0
# 11              Shape  28.666667  22.513089   0.252199    191.0
# 12          Component  52.817518  82.227273     0.6432   2200.0
# 13              Value  23.113208  81.666667   0.360294     60.0
# 14        Attribution  42.553191  21.505376   0.285714    372.0
# 15              State   2.843602      100.0     0.0553      6.0
# 16           Function  19.629057   40.44586   0.264308    314.0
# 0            accuracy          -          -  52.229299   5181.0
# 1           macro avg  26.460881  35.261137   0.251548   5181.0
# 2        weighted avg  42.113048  52.229299   0.443304   5181.0

# %%
#### example = 3
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 3)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_3_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['Shape', 'EnergyFlow', 'PhysicsFlow', 'System', 'Component', 'ScientificConcept', 'Material', 'Effect', 'Function', 'AnnotatorNotes', 'Attribution', 'InfoFlow', 'Consequence', 'Value', 'State', 'Location', 'Measure']
#                entity  precision     recall   F1 score  support
# 0               Shape  29.951691  32.460733   0.311558    191.0
# 1          EnergyFlow  68.148148   24.08377   0.355899    382.0
# 2         PhysicsFlow        0.0        0.0        0.0     28.0
# 3              System  18.374558  21.399177   0.197719    243.0
# 4           Component  59.881423  82.636364   0.694423   2200.0
# 5   ScientificConcept  13.513514   8.241758   0.102389    182.0
# 6            Material  56.395349  61.392405   0.587879    316.0
# 7              Effect  27.111111  23.371648   0.251029    261.0
# 8            Function  21.126761  38.216561   0.272109    314.0
# 9      AnnotatorNotes        0.0        0.0        0.0      3.0
# 10        Attribution  44.303797  18.817204   0.264151    372.0
# 11           InfoFlow  59.210526  50.561798   0.545455     89.0
# 12        Consequence  15.384615   9.090909   0.114286     22.0
# 13              Value  19.491525  76.666667   0.310811     60.0
# 14              State        3.0      100.0   0.058252      6.0
# 15           Location  31.799163  32.067511   0.319328    474.0
# 16            Measure  10.185185  57.894737   0.173228     38.0
# 0            accuracy          -          -  53.213665   5181.0
# 1           macro avg  28.110433  37.464779   0.268148   5181.0
# 2        weighted avg  46.455173  53.213665   0.473435   5181.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_5_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  55.494505  26.439791   0.358156    382.0
# 1   ScientificConcept  14.912281   9.340659   0.114865    182.0
# 2            InfoFlow  81.428571  64.044944   0.716981     89.0
# 3              Effect  26.267281   21.83908   0.238494    261.0
# 4              System  19.409283  18.930041   0.191667    243.0
# 5             Measure  10.454545  60.526316   0.178295     38.0
# 6            Material  54.913295  60.126582   0.574018    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence    9.52381   9.090909   0.093023     22.0
# 10           Location  32.603939  31.434599   0.320086    474.0
# 11              Shape       28.0  32.984293   0.302885    191.0
# 12          Component  60.371914  85.590909   0.708028   2200.0
# 13              Value  18.978102  86.666667   0.311377     60.0
# 14        Attribution  44.370861  18.010753   0.256214    372.0
# 15              State   3.045685      100.0   0.059113      6.0
# 16           Function  20.517928  32.802548   0.252451    314.0
# 0            accuracy          -          -  54.352442   5181.0
# 1           macro avg  28.252471   38.69577   0.275038   5181.0
# 2        weighted avg  46.017703  54.352442   0.478946   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_10_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  56.218905  29.581152    0.38765    382.0
# 1   ScientificConcept       13.6   9.340659   0.110749    182.0
# 2            InfoFlow  77.464789  61.797753     0.6875     89.0
# 3              Effect  31.325301  29.885057   0.305882    261.0
# 4              System   17.90393  16.872428   0.173729    243.0
# 5             Measure   9.356725  42.105263    0.15311     38.0
# 6            Material  56.626506  59.493671   0.580247    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow   1.219512   3.571429   0.018182     28.0
# 9         Consequence       20.0  27.272727   0.230769     22.0
# 10           Location  39.354839  38.607595   0.389776    474.0
# 11              Shape  32.323232  33.507853   0.329049    191.0
# 12          Component   61.20745  86.636364    0.71735   2200.0
# 13              Value  17.894737       85.0   0.295652     60.0
# 14        Attribution  44.705882  20.430108   0.280443    372.0
# 15              State   4.137931      100.0    0.07947      6.0
# 16           Function  22.342733  32.802548   0.265806    314.0
# 0            accuracy          -          -  56.050955   5181.0
# 1           macro avg  29.746028  39.817918   0.294433   5181.0
# 2        weighted avg  47.543807  56.050955   0.497591   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_20_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  57.964602  34.293194   0.430921    382.0
# 1   ScientificConcept  21.052632  10.989011   0.144404    182.0
# 2            InfoFlow  80.882353  61.797753   0.700637     89.0
# 3              Effect   38.69863  43.295019    0.40868    261.0
# 4              System  29.218107  29.218107   0.292181    243.0
# 5             Measure       12.5  57.894737   0.205607     38.0
# 6            Material  63.414634  74.050633   0.683212    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow   1.020408   3.571429   0.015873     28.0
# 9         Consequence  16.666667  27.272727   0.206897     22.0
# 10           Location  43.545279  47.679325   0.455186    474.0
# 11              Shape  34.810127  28.795812   0.315186    191.0
# 12          Component  63.893511  87.272727   0.737752   2200.0
# 13              Value  22.510823  86.666667   0.357388     60.0
# 14        Attribution  51.813472   26.88172   0.353982    372.0
# 15              State   6.122449      100.0   0.115385      6.0
# 16           Function   32.55814  44.585987   0.376344    314.0
# 0            accuracy          -          -  60.837676   5181.0
# 1           macro avg  33.921872  44.956756   0.341155   5181.0
# 2        weighted avg  52.117808  60.837676   0.546347   5181.0

# %%
# Out:
# 4

# %% [markdown]
# ### stratified, random

# %%
with open("data/immutable_data_formal/sen_thf_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_5_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  56.852792  29.319372   0.386874    382.0
# 1   ScientificConcept  14.285714   6.593407   0.090226    182.0
# 2            InfoFlow  44.186047  42.696629   0.434286     89.0
# 3              Effect  34.246575   47.89272   0.399361    261.0
# 4              System  17.301038  20.576132    0.18797    243.0
# 5             Measure   7.575758  52.631579    0.13245     38.0
# 6            Material  42.430279  67.405063   0.520782    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence  10.810811  18.181818   0.135593     22.0
# 10           Location  33.565217    40.7173   0.367969    474.0
# 11              Shape       27.5  28.795812    0.28133    191.0
# 12          Component  62.555518  83.227273   0.714258   2200.0
# 13              Value  16.803279  68.333333   0.269737     60.0
# 14        Attribution  28.666667   11.55914   0.164751    372.0
# 15              State   2.620087      100.0   0.051064      6.0
# 16           Function       17.0  27.070064   0.208845    314.0
# 0            accuracy          -          -  54.584057   5181.0
# 1           macro avg  24.494105  37.941155   0.255617   5181.0
# 2        weighted avg  44.612427  54.584057     0.4764   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_10_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  56.175299  36.910995   0.445498    382.0
# 1   ScientificConcept  11.363636   2.747253   0.044248    182.0
# 2            InfoFlow  62.711864  41.573034        0.5     89.0
# 3              Effect  32.995951  62.452107   0.431788    261.0
# 4              System  20.754717  22.633745   0.216535    243.0
# 5             Measure    8.62069  39.473684   0.141509     38.0
# 6            Material  42.967245   70.56962   0.534132    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence  19.047619  18.181818   0.186047     22.0
# 10           Location  38.888889  42.827004   0.407631    474.0
# 11              Shape  31.797235  36.125654   0.338235    191.0
# 12          Component  64.210526  83.181818   0.724752   2200.0
# 13              Value  18.113208       80.0   0.295385     60.0
# 14        Attribution  33.215548  25.268817   0.287023    372.0
# 15              State   5.454545      100.0   0.103448      6.0
# 16           Function  23.399558  33.757962   0.276402    314.0
# 0            accuracy          -          -  57.884578   5181.0
# 1           macro avg  27.630384  40.923736   0.290155   5181.0
# 2        weighted avg  47.033594  57.884578   0.507718   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_20_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow  52.664577  43.979058  0.479315    382.0
# 1   ScientificConcept  17.647059   3.296703  0.055556    182.0
# 2            InfoFlow  69.387755  38.202247  0.492754     89.0
# 3              Effect   32.55814  59.003831  0.419619    261.0
# 4              System  19.402985  21.399177  0.203523    243.0
# 5             Measure  11.464968  47.368421  0.184615     38.0
# 6            Material   51.74538  79.746835  0.627646    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8         PhysicsFlow        0.0        0.0       0.0     28.0
# 9         Consequence       20.0  13.636364  0.162162     22.0
# 10           Location   41.39265  45.147679  0.431887    474.0
# 11              Shape  36.744186  41.361257  0.389163    191.0
# 12          Component  64.987843  85.045455  0.736759   2200.0
# 13              Value  20.253165       80.0  0.323232     60.0
# 14        Attribution  35.580524  25.537634   0.29734    372.0
# 15              State   5.660377      100.0  0.107143      6.0
# 16           Function   26.42369  36.942675  0.308101    314.0
# 0            accuracy          -          -  60.14283   5181.0
# 1           macro avg  29.759606  42.392196  0.306989   5181.0
# 2        weighted avg  48.704615   60.14283  0.527363   5181.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("data/immutable_data_formal/sen_thf_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 1)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_1_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  61.264822  40.575916   0.488189    382.0
# 1   ScientificConcept       20.8  28.571429   0.240741    182.0
# 2            InfoFlow  57.692308   67.41573   0.621762     89.0
# 3              Effect  40.217391  42.528736   0.413408    261.0
# 4              System  20.703125    21.8107   0.212425    243.0
# 5             Measure    9.65251  65.789474    0.16835     38.0
# 6            Material  61.398964       75.0   0.675214    316.0
# 7      AnnotatorNotes   4.166667  33.333333   0.074074      3.0
# 8         PhysicsFlow   6.557377  28.571429   0.106667     28.0
# 9         Consequence  13.043478  27.272727   0.176471     22.0
# 10           Location  33.640553  46.202532   0.389333    474.0
# 11              Shape  31.162791  35.078534   0.330049    191.0
# 12          Component  61.768662       83.5   0.710089   2200.0
# 13              Value  22.907489  86.666667   0.362369     60.0
# 14        Attribution  40.495868  13.172043   0.198783    372.0
# 15              State   3.448276      100.0   0.066667      6.0
# 16           Function  21.464226  41.082803   0.281967    314.0
# 0            accuracy          -          -  59.197066   5181.0
# 1           macro avg  30.022618  49.210121   0.324503   5181.0
# 2        weighted avg  48.077793  59.197066   0.514654   5181.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_5_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  62.745098   50.26178    0.55814    382.0
# 1   ScientificConcept  27.604167  29.120879   0.283422    182.0
# 2            InfoFlow  67.924528  80.898876   0.738462     89.0
# 3              Effect  45.421245  47.509579   0.464419    261.0
# 4              System  45.614035  32.098765   0.376812    243.0
# 5             Measure  13.445378  84.210526   0.231884     38.0
# 6            Material  71.469741  78.481013   0.748115    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow      9.375  21.428571   0.130435     28.0
# 9         Consequence  18.367347  40.909091   0.253521     22.0
# 10           Location  46.507666  57.594937   0.514609    474.0
# 11              Shape  38.265306  39.267016   0.387597    191.0
# 12          Component  66.516464  87.227273   0.754769   2200.0
# 13              Value  28.235294       80.0   0.417391     60.0
# 14        Attribution  45.212766  22.849462   0.303571    372.0
# 15              State        4.8      100.0   0.091603      6.0
# 16           Function  29.189189  51.592357   0.372842    314.0
# 0            accuracy          -          -  65.276974   5181.0
# 1           macro avg  36.511366  53.144125   0.389858   5181.0
# 2        weighted avg  55.034929  65.276974   0.585173   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_10_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171BB6A0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023781579D60>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171884C0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171887F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023781579D30>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162C9E20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701EDC0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F61670>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171BB1F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188430>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188460>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188F40>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD520>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD880>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DDE50>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171BB6D0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F61C40>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701EF40>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188F40>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188550>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188BB0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188E20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD160>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD340>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD0D0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D21C0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD550>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD4F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023781579970>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162C9580>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188DF0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188640>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188E80>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188580>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F612E0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:20 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816272E20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2100>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2040>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2D00>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816272E20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F61E20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701E1F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188100>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171884F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188040>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188370>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD190>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD640>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2790>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2A00>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2700>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD580>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD6A0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023781579D60>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171889A0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171884C0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171882B0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188160>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F61E20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F61F40>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2790>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2A30>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2D00>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171BB4C0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816F612E0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701E280>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188190>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188520>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188610>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171880D0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DDA60>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD6D0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2EB0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2970>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381731B370>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381731B580>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD460>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:21 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DDA60>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023781579430>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162C9250>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188DF0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188D00>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188160>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701E2B0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162720A0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816272820>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381731B8E0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816272220>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701E6A0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701ED90>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188820>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188670>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171883D0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162C9E50>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD280>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD7F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2940>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D2A00>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381731BEE0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381731BB20>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD3D0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD670>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023781579DF0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162C9340>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188D30>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188520>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188EB0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701E490>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816272550>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:22 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023816272E80>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381731F400>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162720A0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701EDF0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002381701E700>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188BE0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238171888E0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023817188220>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238162C9310>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DD7C0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238170DDA30>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Connection error: try again automatically
# Connection error: try again automatically
# 11/22/2023 21:29:23 - WARNING - urllib3.connectionpool -   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000238172D24F0>: Failed to resolve 'openai-aiattack-000518-canadaeast-02-smrattack.openai.azure.com' ([Errno 11001] getaddrinfo failed)")': //openai/deployments/gpt-4-32k/chat/completions?api-version=2023-07-01-preview
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16376\831352570.py in <cell line: 7>()
#       5 transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
#       6 transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
# ----> 7 get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
#
# C:\Siemens old windows machine document folder\master_thesis_code\instructner0829\instructner\gpt_ner_api_codes\prompts_all.py in get_evaluation_without_o(transformed_solution, transformed_output, target_names)
#    1053         for element in transformed_solution[i]["ner_tags"]:
#    1054             y_true.append( element )
# -> 1055         for element in transformed_output[i]["ner_tags"]:
#    1056             y_pred.append( element )
#    1057     extracted_entities = list(set(y_true))
#
# IndexError: list index out of range

# %%
prompt_text1 , response1 = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input[:20], dataset = "film", num_examples = 10)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20

# %%
response2 = response
len(response2)
response_new = []
for r in response1:
    response_new.append(r)
for r in response[14:]:
    response_new.append(r)
print(len(response_new))    
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response_new)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  61.736334   50.26178   0.554113    382.0
# 1   ScientificConcept  30.769231  30.769231   0.307692    182.0
# 2            InfoFlow  79.775281  79.775281   0.797753     89.0
# 3              Effect  52.727273  55.555556   0.541045    261.0
# 4              System  45.303867  33.744856   0.386792    243.0
# 5             Measure   13.50211  84.210526   0.232727     38.0
# 6            Material  72.804533  81.329114   0.768311    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow  19.230769  35.714286       0.25     28.0
# 9         Consequence   20.37037       50.0   0.289474     22.0
# 10           Location  50.344828  61.603376    0.55408    474.0
# 11              Shape  39.719626  44.502618   0.419753    191.0
# 12          Component  67.929825       88.0   0.766733   2200.0
# 13              Value  34.782609       80.0   0.484848     60.0
# 14        Attribution  54.395604  26.612903   0.357401    372.0
# 15              State   5.405405      100.0   0.102564      6.0
# 16           Function  32.824427   54.77707   0.410501    314.0
# 0            accuracy          -          -  67.438718   5181.0
# 1           macro avg  40.095417  56.285682   0.424929   5181.0
# 2        weighted avg   57.73341  67.438718    0.60993   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_20_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  64.356436   51.04712   0.569343    382.0
# 1   ScientificConcept  36.129032  30.769231   0.332344    182.0
# 2            InfoFlow  81.052632  86.516854   0.836957     89.0
# 3              Effect  54.135338  55.172414    0.54649    261.0
# 4              System  45.989305  35.390947        0.4    243.0
# 5             Measure  13.333333  78.947368   0.228137     38.0
# 6            Material  74.220963  82.911392   0.783259    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow  14.545455  28.571429   0.192771     28.0
# 9         Consequence   17.54386  45.454545   0.253165     22.0
# 10           Location  52.166378   63.50211   0.572788    474.0
# 11              Shape  45.454545   49.73822      0.475    191.0
# 12          Component  70.545455  88.181818   0.783838   2200.0
# 13              Value  38.842975  78.333333   0.519337     60.0
# 14        Attribution  61.883408  37.096774   0.463866    372.0
# 15              State   8.823529      100.0   0.162162      6.0
# 16           Function  36.647173  59.872611   0.454655    314.0
# 0            accuracy          -          -  69.156533   5181.0
# 1           macro avg  42.098225  57.147422   0.445536   5181.0
# 2        weighted avg  60.596761  69.156533   0.635701   5181.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("data/immutable_data_formal/sen_thf_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_5_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow  55.136986  42.146597  0.477745    382.0
# 1   ScientificConcept       18.4  12.637363  0.149837    182.0
# 2            InfoFlow  72.941176  69.662921  0.712644     89.0
# 3              Effect  37.888199  46.743295  0.418525    261.0
# 4              System  19.900498  16.460905   0.18018    243.0
# 5             Measure        8.0  68.421053  0.143251     38.0
# 6            Material       48.0  64.556962  0.550607    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8         PhysicsFlow        0.0        0.0       0.0     28.0
# 9         Consequence  10.526316   9.090909  0.097561     22.0
# 10           Location  38.058252  41.350211   0.39636    474.0
# 11              Shape  34.246575  39.267016  0.365854    191.0
# 12          Component  64.332303  85.181818  0.733033   2200.0
# 13              Value  20.952381  73.333333  0.325926     60.0
# 14        Attribution       40.0  12.365591  0.188912    372.0
# 15              State   3.821656      100.0   0.07362      6.0
# 16           Function  27.241379  50.318471  0.353468    314.0
# 0            accuracy          -          -  58.65663   5181.0
# 1           macro avg   29.37916  43.031556  0.303972   5181.0
# 2        weighted avg  48.669514   58.65663  0.517175   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_10_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow  52.265861  45.287958  0.485273    382.0
# 1   ScientificConcept      18.75  13.186813  0.154839    182.0
# 2            InfoFlow   77.21519  68.539326   0.72619     89.0
# 3              Effect  41.355932  46.743295  0.438849    261.0
# 4              System  22.077922   13.99177  0.171285    243.0
# 5             Measure    8.46395  71.052632  0.151261     38.0
# 6            Material  56.692913   68.35443  0.619799    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8         PhysicsFlow    2.12766   3.571429  0.026667     28.0
# 9         Consequence  14.285714  13.636364  0.139535     22.0
# 10           Location  41.481481  47.257384  0.441815    474.0
# 11              Shape  34.666667  40.837696     0.375    191.0
# 12          Component  66.470384  87.227273  0.754472   2200.0
# 13              Value  21.393035  71.666667  0.329502     60.0
# 14        Attribution  44.444444  15.053763    0.2249    372.0
# 15              State    4.83871      100.0  0.092308      6.0
# 16           Function  30.769231  53.503185  0.390698    314.0
# 0            accuracy          -          -  60.89558   5181.0
# 1           macro avg  31.605829  44.700587  0.324847   5181.0
# 2        weighted avg  51.157186   60.89558  0.541849   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_20_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow  53.561254   49.21466   0.51296    382.0
# 1   ScientificConcept  27.835052  14.835165  0.193548    182.0
# 2            InfoFlow  80.821918  66.292135  0.728395     89.0
# 3              Effect  44.117647  51.724138   0.47619    261.0
# 4              System   31.29771  16.872428  0.219251    243.0
# 5             Measure   8.777429  73.684211  0.156863     38.0
# 6            Material  64.075067  75.632911  0.693759    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8         PhysicsFlow        0.0        0.0       0.0     28.0
# 9         Consequence  10.526316  18.181818  0.133333     22.0
# 10           Location  44.827586  52.109705  0.481951    474.0
# 11              Shape  34.615385  42.408377  0.381176    191.0
# 12          Component  66.609176  87.772727  0.757403   2200.0
# 13              Value  29.192547  78.333333  0.425339     60.0
# 14        Attribution   45.56962  19.354839  0.271698    372.0
# 15              State   6.976744      100.0  0.130435      6.0
# 16           Function   34.52381  55.414013  0.425428    314.0
# 0            accuracy          -          -  63.28894   5181.0
# 1           macro avg  34.313368  47.166498   0.35222   5181.0
# 2        weighted avg  53.394752   63.28894  0.565564   5181.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("data/immutable_data_formal/sen_thf_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 1)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_1_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  63.821138  41.099476        0.5    382.0
# 1   ScientificConcept  21.484375   30.21978   0.251142    182.0
# 2            InfoFlow  59.649123  76.404494   0.669951     89.0
# 3              Effect  42.293907  45.210728   0.437037    261.0
# 4              System  26.807229  36.625514   0.309565    243.0
# 5             Measure  13.106796  71.052632   0.221311     38.0
# 6            Material  60.508083  82.911392   0.699599    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow   8.396947  39.285714   0.138365     28.0
# 9         Consequence  34.615385  40.909091      0.375     22.0
# 10           Location  36.308623  50.632911   0.422907    474.0
# 11              Shape  36.453202  38.743455   0.375635    191.0
# 12          Component  62.314335       82.0   0.708145   2200.0
# 13              Value       20.0  81.666667   0.321311     60.0
# 14        Attribution   49.39759  22.043011   0.304833    372.0
# 15              State   3.870968      100.0   0.074534      6.0
# 16           Function   19.80198  38.216561    0.26087    314.0
# 0            accuracy          -          -  61.204401   5181.0
# 1           macro avg  32.872334  51.589496   0.357071   5181.0
# 2        weighted avg  49.961025  61.204401   0.535108   5181.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_5_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  62.283737  47.120419   0.536513    382.0
# 1   ScientificConcept  30.697674  36.263736   0.332494    182.0
# 2            InfoFlow  69.090909  85.393258   0.763819     89.0
# 3              Effect   47.97048  49.808429   0.488722    261.0
# 4              System  37.226277  41.975309   0.394584    243.0
# 5             Measure  16.304348  78.947368    0.27027     38.0
# 6            Material  68.911917  84.177215   0.757835    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow  14.285714  39.285714   0.209524     28.0
# 9         Consequence   21.95122  40.909091   0.285714     22.0
# 10           Location  51.041667  62.025316       0.56    474.0
# 11              Shape  45.402299  41.361257   0.432877    191.0
# 12          Component  69.233563  86.636364   0.769635   2200.0
# 13              Value  24.867725  78.333333    0.37751     60.0
# 14        Attribution  55.823293  37.365591   0.447665    372.0
# 15              State   4.651163      100.0   0.088889      6.0
# 16           Function  28.191489  50.636943   0.362187    314.0
# 0            accuracy          -          -  67.554526   5181.0
# 1           macro avg  38.113734  56.484667   0.416367   5181.0
# 2        weighted avg  57.265236  67.554526   0.610604   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_10_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  68.683274   50.52356   0.582202    382.0
# 1   ScientificConcept   32.54717  37.912088   0.350254    182.0
# 2            InfoFlow  74.311927  91.011236   0.818182     89.0
# 3              Effect  49.480969  54.789272       0.52    261.0
# 4              System       39.6  40.740741   0.401623    243.0
# 5             Measure  17.801047  89.473684   0.296943     38.0
# 6            Material  68.316832  87.341772   0.766667    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow  13.432836  32.142857   0.189474     28.0
# 9         Consequence  27.272727  40.909091   0.327273     22.0
# 10           Location  55.231561  67.932489   0.609272    474.0
# 11              Shape  48.421053  48.167539    0.48294    191.0
# 12          Component  71.610487  86.909091   0.785216   2200.0
# 13              Value  26.136364  76.666667   0.389831     60.0
# 14        Attribution   57.03125  39.247312   0.464968    372.0
# 15              State   6.315789      100.0   0.118812      6.0
# 16           Function  33.669355  53.184713   0.412346    314.0
# 0            accuracy          -          -  69.561861   5181.0
# 1           macro avg  40.580155  58.644242   0.442118   5181.0
# 2        weighted avg  60.011098  69.561861   0.635668   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_20_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow  67.434211  53.664921  0.597668    382.0
# 1   ScientificConcept  34.848485  37.912088  0.363158    182.0
# 2            InfoFlow  75.675676  94.382022      0.84     89.0
# 3              Effect  51.546392  57.471264  0.543478    261.0
# 4              System  42.366412  45.679012  0.439604    243.0
# 5             Measure   17.44186  78.947368  0.285714     38.0
# 6            Material  70.812183  88.291139  0.785915    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8         PhysicsFlow  21.818182  42.857143  0.289157     28.0
# 9         Consequence  31.428571       50.0  0.385965     22.0
# 10           Location  57.529611  71.729958  0.638498    474.0
# 11              Shape  47.115385  51.308901  0.491228    191.0
# 12          Component  74.843994  87.227273  0.805626   2200.0
# 13              Value  30.263158  76.666667  0.433962     60.0
# 14        Attribution  59.782609  44.354839  0.509259    372.0
# 15              State        7.5      100.0  0.139535      6.0
# 16           Function  37.060041  57.006369  0.449184    314.0
# 0            accuracy          -          -  71.49199   5181.0
# 1           macro avg  42.792163  61.029351  0.470468   5181.0
# 2        weighted avg  62.456955   71.49199  0.660074   5181.0

# %% [markdown]
# ### stratified, if-idf

# %%
with open("data/immutable_data_formal/sen_thf_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_5_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  56.690141  42.146597   0.483483    382.0
# 1   ScientificConcept  17.857143  13.736264    0.15528    182.0
# 2            InfoFlow  70.930233  68.539326   0.697143     89.0
# 3              Effect  35.087719  38.314176     0.3663    261.0
# 4              System   22.54902  18.930041   0.205817    243.0
# 5             Measure   8.895706  76.315789   0.159341     38.0
# 6            Material  50.826446  77.848101      0.615    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence  17.647059  13.636364   0.153846     22.0
# 10           Location  38.928571  45.991561   0.421663    474.0
# 11              Shape  35.746606  41.361257   0.383495    191.0
# 12          Component  65.087719  84.318182   0.734653   2200.0
# 13              Value   19.43128  68.333333   0.302583     60.0
# 14        Attribution       39.2  13.172043   0.197183    372.0
# 15              State   3.614458      100.0   0.069767      6.0
# 16           Function  21.723519  38.535032   0.277842    314.0
# 0            accuracy          -          -  58.675931   5181.0
# 1           macro avg  29.659742   43.59871   0.307259   5181.0
# 2        weighted avg  48.968739  58.675931   0.519768   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_10_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Connection error: try again automatically
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  54.984894  47.643979   0.510519    382.0
# 1   ScientificConcept  22.222222  16.483516   0.189274    182.0
# 2            InfoFlow  77.272727  76.404494   0.768362     89.0
# 3              Effect  40.199336  46.360153   0.430605    261.0
# 4              System  23.312883   15.63786   0.187192    243.0
# 5             Measure   9.926471  71.052632   0.174194     38.0
# 6            Material  57.494407  81.329114   0.673657    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence        0.0        0.0        0.0     22.0
# 10           Location  42.190305  49.578059   0.455868    474.0
# 11              Shape       37.5  43.979058   0.404819    191.0
# 12          Component  66.998578  85.636364   0.751796   2200.0
# 13              Value  21.495327  76.666667   0.335766     60.0
# 14        Attribution  37.714286  17.741935   0.241316    372.0
# 15              State   4.411765      100.0   0.084507      6.0
# 16           Function  26.760563  48.407643   0.344671    314.0
# 0            accuracy          -          -  61.686933   5181.0
# 1           macro avg  30.734339  45.701263    0.32662   5181.0
# 2        weighted avg  51.135831  61.686933   0.548393   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_20_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  50.704225  47.120419   0.488467    382.0
# 1   ScientificConcept  22.297297  18.131868        0.2    182.0
# 2            InfoFlow  75.308642  68.539326   0.717647     89.0
# 3              Effect  42.214533  46.743295   0.443636    261.0
# 4              System   27.61194  15.226337   0.196286    243.0
# 5             Measure  11.016949  68.421053   0.189781     38.0
# 6            Material  64.720195  84.177215   0.731774    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow   3.030303   3.571429   0.032787     28.0
# 9         Consequence       12.5  18.181818   0.148148     22.0
# 10           Location  48.175182  55.696203   0.516634    474.0
# 11              Shape   37.55102  48.167539   0.422018    191.0
# 12          Component  68.465909  87.636364    0.76874   2200.0
# 13              Value  25.433526  73.333333   0.377682     60.0
# 14        Attribution  48.087432  23.655914   0.317117    372.0
# 15              State   5.405405      100.0   0.102564      6.0
# 16           Function  32.936508  52.866242   0.405868    314.0
# 0            accuracy          -          -  64.041691   5181.0
# 1           macro avg  33.850533  47.733433   0.356421   5181.0
# 2        weighted avg  53.948789  64.041691   0.574867   5181.0

# %% [markdown]
# ### not stratified, tf-idf_half

# %%
with open("data/immutable_data_formal/sen_thf_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_5_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow  68.032787  43.455497  0.530351    382.0
# 1   ScientificConcept   29.20354  36.263736  0.323529    182.0
# 2            InfoFlow  71.428571   89.88764   0.79602     89.0
# 3              Effect  44.086022  47.126437  0.455556    261.0
# 4              System   41.22449  41.563786  0.413934    243.0
# 5             Measure  15.533981  84.210526  0.262295     38.0
# 6            Material  66.057441  80.063291  0.723891    316.0
# 7      AnnotatorNotes   8.333333  33.333333  0.133333      3.0
# 8         PhysicsFlow       10.0  39.285714   0.15942     28.0
# 9         Consequence  31.034483  40.909091  0.352941     22.0
# 10           Location   49.20071  58.438819  0.534233    474.0
# 11              Shape   44.91018  39.267016  0.418994    191.0
# 12          Component    67.4369  86.227273  0.756832   2200.0
# 13              Value  27.419355       85.0  0.414634     60.0
# 14        Attribution  55.072464  30.645161  0.393782    372.0
# 15              State   4.761905      100.0  0.090909      6.0
# 16           Function  29.657795  49.681529  0.371429    314.0
# 0            accuracy          -          -  65.97182   5181.0
# 1           macro avg  39.023174  57.962285  0.419534   5181.0
# 2        weighted avg  56.624264   65.97182  0.596406   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_10_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  66.300366  47.382199   0.552672    382.0
# 1   ScientificConcept  29.147982  35.714286   0.320988    182.0
# 2            InfoFlow  74.736842  79.775281   0.771739     89.0
# 3              Effect   49.81685   52.10728   0.509363    261.0
# 4              System  39.919355  40.740741   0.403259    243.0
# 5             Measure  17.435897  89.473684   0.291845     38.0
# 6            Material  69.487179  85.759494   0.767705    316.0
# 7      AnnotatorNotes       10.0  33.333333   0.153846      3.0
# 8         PhysicsFlow  10.714286  32.142857   0.160714     28.0
# 9         Consequence  26.923077  31.818182   0.291667     22.0
# 10           Location  51.258993  60.126582   0.553398    474.0
# 11              Shape  44.886364  41.361257   0.430518    191.0
# 12          Component  69.393718  86.363636   0.769542   2200.0
# 13              Value  32.450331  81.666667   0.464455     60.0
# 14        Attribution   57.03125  39.247312   0.464968    372.0
# 15              State   5.263158      100.0        0.1      6.0
# 16           Function  30.876494  49.363057   0.379902    314.0
# 0            accuracy          -          -  67.438718   5181.0
# 1           macro avg  40.331891  58.022109   0.434505   5181.0
# 2        weighted avg  58.281095  67.438718    0.61619   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_not_stratified_input_30_example_20_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  66.346154  54.188482   0.596542    382.0
# 1   ScientificConcept  32.512315  36.263736   0.342857    182.0
# 2            InfoFlow  78.723404  83.146067   0.808743     89.0
# 3              Effect       50.0  54.789272   0.522852    261.0
# 4              System  42.578125  44.855967   0.436874    243.0
# 5             Measure  16.042781  78.947368   0.266667     38.0
# 6            Material  69.059406  88.291139      0.775    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow  14.705882  35.714286   0.208333     28.0
# 9         Consequence  20.588235  31.818182       0.25     22.0
# 10           Location   54.51448  67.510549   0.603205    474.0
# 11              Shape  48.704663   49.21466   0.489583    191.0
# 12          Component  72.706422  86.454545   0.789867   2200.0
# 13              Value  39.097744  86.666667    0.53886     60.0
# 14        Attribution  62.453532   45.16129   0.524181    372.0
# 15              State   8.108108      100.0       0.15      6.0
# 16           Function  35.084034  53.184713   0.422785    314.0
# 0            accuracy          -          -  70.140899   5181.0
# 1           macro avg  41.836782  58.600407   0.454491   5181.0
# 2        weighted avg  61.127512  70.140899   0.646471   5181.0

# %% [markdown]
# ### stratified, if-idf_half

# %%
with open("data/immutable_data_formal/sen_thf_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_thf_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_5_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  47.083333  29.581152   0.363344    382.0
# 1   ScientificConcept  13.970588   10.43956   0.119497    182.0
# 2            InfoFlow  57.831325  53.932584    0.55814     89.0
# 3              Effect  27.848101  25.287356    0.26506    261.0
# 4              System  19.105691  19.341564   0.192229    243.0
# 5             Measure   8.041958  60.526316   0.141975     38.0
# 6            Material  45.414847  65.822785   0.537468    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence  17.391304  18.181818   0.177778     22.0
# 10           Location  32.659933   40.92827   0.363296    474.0
# 11              Shape  29.032258  32.984293   0.308824    191.0
# 12          Component  61.356834  83.863636   0.708661   2200.0
# 13              Value   17.96875  76.666667   0.291139     60.0
# 14        Attribution  35.897436  11.290323   0.171779    372.0
# 15              State   3.225806      100.0     0.0625      6.0
# 16           Function  20.272904  33.121019   0.251511    314.0
# 0            accuracy          -          -  54.584057   5181.0
# 1           macro avg  25.711828  38.939255   0.265482   5181.0
# 2        weighted avg  44.287555  54.584057   0.474082   5181.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_10_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall  F1 score  support
# 0          EnergyFlow   52.10728  35.602094  0.423017    382.0
# 1   ScientificConcept  15.517241    9.89011  0.120805    182.0
# 2            InfoFlow  72.972973  60.674157  0.662577     89.0
# 3              Effect  30.962343   28.35249     0.296    261.0
# 4              System  18.220339  17.695473  0.179541    243.0
# 5             Measure   8.041958  60.526316  0.141975     38.0
# 6            Material  42.222222  66.139241  0.515413    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8         PhysicsFlow        0.0        0.0       0.0     28.0
# 9         Consequence   5.555556   4.545455      0.05     22.0
# 10           Location   36.92053  47.046414  0.413729    474.0
# 11              Shape  28.640777  30.890052  0.297229    191.0
# 12          Component  63.639527  83.136364   0.72093   2200.0
# 13              Value  20.338983       80.0  0.324324     60.0
# 14        Attribution  36.885246  12.096774  0.182186    372.0
# 15              State   3.508772      100.0  0.067797      6.0
# 16           Function  22.222222  36.942675  0.277512    314.0
# 0            accuracy          -          -  55.66493   5181.0
# 1           macro avg  26.926822   39.61986  0.274884   5181.0
# 2        weighted avg   46.40429   55.66493  0.491508   5181.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
with open("formal_eva_results_gpt3.5/thf_stratified_input_30_example_20_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['EnergyFlow', 'ScientificConcept', 'InfoFlow', 'Effect', 'System', 'Measure', 'Material', 'AnnotatorNotes', 'PhysicsFlow', 'Consequence', 'Location', 'Shape', 'Component', 'Value', 'Attribution', 'State', 'Function']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  53.076923  36.125654   0.429907    382.0
# 1   ScientificConcept  15.454545   9.340659   0.116438    182.0
# 2            InfoFlow  74.683544  66.292135   0.702381     89.0
# 3              Effect  31.679389  31.800766     0.3174    261.0
# 4              System  22.869955  20.987654   0.218884    243.0
# 5             Measure  10.062893  84.210526   0.179775     38.0
# 6            Material  48.034934  69.620253   0.568475    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8         PhysicsFlow        0.0        0.0        0.0     28.0
# 9         Consequence   8.333333   9.090909   0.086957     22.0
# 10           Location  40.909091  49.367089   0.447419    474.0
# 11              Shape  34.653465  36.649215   0.356234    191.0
# 12          Component  65.617174  83.363636   0.734334   2200.0
# 13              Value  21.761658       70.0   0.332016     60.0
# 14        Attribution   44.88189  15.322581   0.228457    372.0
# 15              State   4.347826      100.0   0.083333      6.0
# 16           Function  27.254902  44.267516   0.337379    314.0
# 0            accuracy          -          -  57.595059   5181.0
# 1           macro avg  29.624796  42.731682   0.302317   5181.0
# 2        weighted avg  49.461266  57.595059   0.517147   5181.0

# %% [markdown]
# # tfidf + sentence

# %%
# sentence
# with open("data/immutable_data/sen_thf_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
#     all_fewshot_sen_sentence = pickle.load(data)    
# with open("data/immutable_data/dem_thf_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
#     all_fewshot_dem_sentence = pickle.load(data) 
    
# # tfidf
# with open("data/immutable_data/sen_thf_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
#     all_fewshot_sen_tfidf = pickle.load(data)    
# with open("data/immutable_data/dem_thf_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
#     all_fewshot_dem_tfidf = pickle.load(data)

# %%
# combine the 2 selected examples step by step
# print(len(all_fewshot_sen_sentence), len(all_fewshot_sen_sentence[0]))

# all_fewshot_sen = []
# all_fewshot_dem = []
# for i in range(len(all_fewshot_sen_sentence)):
#     sen_per_input = []
#     dem_per_input = []
  
#     for j in range(len(all_fewshot_sen_sentence[i])):
#         sen_per_input.append(all_fewshot_sen_sentence[i][j])
#         sen_per_input.append(all_fewshot_sen_tfidf[i][j])
#         dem_per_input.append(all_fewshot_dem_sentence[i][j])
#         dem_per_input.append(all_fewshot_dem_tfidf[i][j])
    
#     all_fewshot_sen.append(sen_per_input) 
#     all_fewshot_dem.append(dem_per_input)
# Out:
# 30 100

# %%
# prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 5)
# with open("results/thf_stratified_input_30_example_5_tfidf_sentence.txt", "wb") as data:   #Pickling
#     pickle.dump(response, data)  
# transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
# transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
# get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 1
# Instruction generated: running GPT API now. Input: 2
# Instruction generated: running GPT API now. Input: 3
# Instruction generated: running GPT API now. Input: 4
# Instruction generated: running GPT API now. Input: 5
# Instruction generated: running GPT API now. Input: 6
# Instruction generated: running GPT API now. Input: 7
# Instruction generated: running GPT API now. Input: 8
# Instruction generated: running GPT API now. Input: 9
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 11
# Instruction generated: running GPT API now. Input: 12
# Instruction generated: running GPT API now. Input: 13
# Instruction generated: running GPT API now. Input: 14
# Instruction generated: running GPT API now. Input: 15
# Instruction generated: running GPT API now. Input: 16
# Instruction generated: running GPT API now. Input: 17
# Instruction generated: running GPT API now. Input: 18
# Instruction generated: running GPT API now. Input: 19
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 21
# Instruction generated: running GPT API now. Input: 22
# Instruction generated: running GPT API now. Input: 23
# Instruction generated: running GPT API now. Input: 24
# Instruction generated: running GPT API now. Input: 25
# Instruction generated: running GPT API now. Input: 26
# Instruction generated: running GPT API now. Input: 27
# Instruction generated: running GPT API now. Input: 28
# Instruction generated: running GPT API now. Input: 29
# Instruction generated: running GPT API now. Input: 30
# ['Component', 'Effect', 'Value', 'Function', 'Measure', 'Shape', 'Location', 'Material', 'System', 'EnergyFlow', 'InfoFlow', 'PhysicsFlow', 'Attribution', 'ScientificConcept', 'Consequence']
#                entity  precision     recall   F1 score  support
# 0           Component      66.25  94.642857   0.779412    112.0
# 1              Effect  47.619048  52.631579        0.5     19.0
# 2               Value  45.454545      100.0      0.625      5.0
# 3            Function  23.076923  29.032258   0.257143     31.0
# 4             Measure  23.076923       60.0   0.333333      5.0
# 5               Shape       50.0  38.461538   0.434783     13.0
# 6            Location       40.0  57.142857   0.470588     28.0
# 7            Material  89.473684  91.891892   0.906667     37.0
# 8              System  44.444444       80.0   0.571429      5.0
# 9          EnergyFlow  81.818182  31.034483       0.45     29.0
# 10           InfoFlow  85.714286      100.0   0.923077     12.0
# 11        PhysicsFlow        0.0        0.0        0.0      1.0
# 12        Attribution  66.666667  43.478261   0.526316     23.0
# 13  ScientificConcept  33.333333  33.333333   0.333333      9.0
# 14        Consequence      100.0      100.0        1.0      2.0
# 0            accuracy          -          -  68.882175    331.0
# 1           macro avg  53.128536  60.776604   0.540739    331.0
# 2        weighted avg  60.786056  68.882175   0.622423    331.0

# %%
# prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 10)
# with open("results/thf_stratified_input_30_example_10_tfidf_sentence.txt", "wb") as data:   #Pickling
#     pickle.dump(response, data)  
# transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
# transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
# get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 1
# Instruction generated: running GPT API now. Input: 2
# Instruction generated: running GPT API now. Input: 3
# Instruction generated: running GPT API now. Input: 4
# Instruction generated: running GPT API now. Input: 5
# Instruction generated: running GPT API now. Input: 6
# Instruction generated: running GPT API now. Input: 7
# Instruction generated: running GPT API now. Input: 8
# Instruction generated: running GPT API now. Input: 9
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 11
# Instruction generated: running GPT API now. Input: 12
# Instruction generated: running GPT API now. Input: 13
# Instruction generated: running GPT API now. Input: 14
# Instruction generated: running GPT API now. Input: 15
# Instruction generated: running GPT API now. Input: 16
# Instruction generated: running GPT API now. Input: 17
# Instruction generated: running GPT API now. Input: 18
# Instruction generated: running GPT API now. Input: 19
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 21
# Instruction generated: running GPT API now. Input: 22
# Instruction generated: running GPT API now. Input: 23
# Instruction generated: running GPT API now. Input: 24
# Instruction generated: running GPT API now. Input: 25
# Instruction generated: running GPT API now. Input: 26
# Instruction generated: running GPT API now. Input: 27
# Instruction generated: running GPT API now. Input: 28
# Instruction generated: running GPT API now. Input: 29
# Instruction generated: running GPT API now. Input: 30
# ['Component', 'Effect', 'Value', 'Function', 'Measure', 'Shape', 'Location', 'Material', 'System', 'EnergyFlow', 'InfoFlow', 'PhysicsFlow', 'Attribution', 'ScientificConcept', 'Consequence']
#                entity  precision     recall   F1 score  support
# 0           Component  74.125874  94.642857   0.831373    112.0
# 1              Effect  66.666667  52.631579   0.588235     19.0
# 2               Value  33.333333       80.0   0.470588      5.0
# 3            Function  20.512821  25.806452   0.228571     31.0
# 4             Measure  14.285714       20.0   0.166667      5.0
# 5               Shape       50.0  53.846154   0.518519     13.0
# 6            Location  46.666667       75.0   0.575342     28.0
# 7            Material  89.473684  91.891892   0.906667     37.0
# 8              System  57.142857       80.0   0.666667      5.0
# 9          EnergyFlow  68.421053  44.827586   0.541667     29.0
# 10           InfoFlow  85.714286      100.0   0.923077     12.0
# 11        PhysicsFlow        0.0        0.0        0.0      1.0
# 12        Attribution  47.619048  43.478261   0.454545     23.0
# 13  ScientificConcept       37.5  33.333333   0.352941      9.0
# 14        Consequence      100.0      100.0        1.0      2.0
# 0            accuracy          -          -  70.996979    331.0
# 1           macro avg  52.764134  59.697208   0.548324    331.0
# 2        weighted avg  62.360074  70.996979   0.654709    331.0

# %%
# prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 20)
# with open("results/thf_stratified_input_30_example_20_tfidf_sentence.txt", "wb") as data:   #Pickling
#     pickle.dump(response, data)  
# transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
# transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
# get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 1
# Instruction generated: running GPT API now. Input: 2
# Instruction generated: running GPT API now. Input: 3
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# exceed maximun token length, -{i} 3
# exceed maximun token length, -{i} 4
# exceed maximun token length, -{i} 5
# Instruction generated: running GPT API now. Input: 4
# Instruction generated: running GPT API now. Input: 5
# Instruction generated: running GPT API now. Input: 6
# exceed maximun token length, -{i} 1
# Instruction generated: running GPT API now. Input: 7
# Instruction generated: running GPT API now. Input: 8
# Instruction generated: running GPT API now. Input: 9
# Instruction generated: running GPT API now. Input: 10
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# exceed maximun token length, -{i} 3
# Instruction generated: running GPT API now. Input: 11
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# exceed maximun token length, -{i} 3
# exceed maximun token length, -{i} 4
# exceed maximun token length, -{i} 5
# exceed maximun token length, -{i} 6
# Instruction generated: running GPT API now. Input: 12
# Instruction generated: running GPT API now. Input: 13
# Instruction generated: running GPT API now. Input: 14
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# Instruction generated: running GPT API now. Input: 15
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# Instruction generated: running GPT API now. Input: 16
# Instruction generated: running GPT API now. Input: 17
# Instruction generated: running GPT API now. Input: 18
# Instruction generated: running GPT API now. Input: 19
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 21
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# exceed maximun token length, -{i} 3
# exceed maximun token length, -{i} 4
# exceed maximun token length, -{i} 5
# exceed maximun token length, -{i} 6
# Instruction generated: running GPT API now. Input: 22
# Instruction generated: running GPT API now. Input: 23
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# exceed maximun token length, -{i} 3
# exceed maximun token length, -{i} 4
# Instruction generated: running GPT API now. Input: 24
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# Instruction generated: running GPT API now. Input: 25
# Instruction generated: running GPT API now. Input: 26
# Instruction generated: running GPT API now. Input: 27
# Instruction generated: running GPT API now. Input: 28
# Instruction generated: running GPT API now. Input: 29
# exceed maximun token length, -{i} 1
# exceed maximun token length, -{i} 2
# exceed maximun token length, -{i} 3
# exceed maximun token length, -{i} 4
# exceed maximun token length, -{i} 5
# Instruction generated: running GPT API now. Input: 30
# ['Component', 'Effect', 'Value', 'Function', 'Measure', 'Shape', 'Location', 'Material', 'System', 'EnergyFlow', 'InfoFlow', 'PhysicsFlow', 'Attribution', 'ScientificConcept', 'Consequence']
#                entity  precision     recall   F1 score  support
# 0           Component  75.182482  91.964286   0.827309    112.0
# 1              Effect       50.0  21.052632   0.296296     19.0
# 2               Value  26.666667       80.0        0.4      5.0
# 3            Function  18.918919  22.580645   0.205882     31.0
# 4             Measure  14.285714       20.0   0.166667      5.0
# 5               Shape  41.666667  38.461538        0.4     13.0
# 6            Location  47.727273       75.0   0.583333     28.0
# 7            Material  87.804878  97.297297   0.923077     37.0
# 8              System  57.142857       80.0   0.666667      5.0
# 9          EnergyFlow  48.148148  44.827586   0.464286     29.0
# 10           InfoFlow  92.307692      100.0       0.96     12.0
# 11        PhysicsFlow        0.0        0.0        0.0      1.0
# 12        Attribution  57.894737  47.826087    0.52381     23.0
# 13  ScientificConcept  27.272727  33.333333        0.3      9.0
# 14        Consequence      100.0      100.0        1.0      2.0
# 0            accuracy          -          -  68.277946    331.0
# 1           macro avg  49.667917  56.822894   0.514488    331.0
# 2        weighted avg    59.9856  68.277946   0.629173    331.0

# %% [markdown]
# # Assembly

# %%
with open("data/immutable_data_formal/sen_assembly_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_assembly_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### Zero shot

# %%
with open("data/immutable_data_formal/sen_assembly_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)
#### example = 0
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 0)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_0_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390

# %%
def process_response_zero_shot_gpt(response):
    processed_response = []
    for demonstrations_one_sentence in response:
        rows_list = demonstrations_one_sentence.split("\n")

        processed_demonstrations_one_sentence = ""
        for row in rows_list:
            entity_one_row = row.split(": ")[0]
            if len(row.split(": ")) > 1:
                extracted_words_list = row.split(": ")[1].split(", ")    
            else:
                extracted_words_list = row.split(": ")[0].split(", ")
            processed_demonstrations_one_row = ""
            for extracted_word in extracted_words_list:
                processed_demonstrations_one_row = processed_demonstrations_one_row + extracted_word + ": " + entity_one_row + '\n'
            processed_demonstrations_one_sentence = processed_demonstrations_one_sentence + processed_demonstrations_one_row 

        processed_response.append(processed_demonstrations_one_sentence)    
    
    return processed_response

# %%
processed_response = process_response_zero_shot_gpt(response)
transformed_output = change_output_format_to_tokens_tags(sentences_input, processed_response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['OPER', 'QTY', 'TOOL', 'PART', 'DIM', 'WGT', 'RPOS', 'PROP', 'ID']
#          entity  precision     recall  F1 score  support
# 0          OPER  38.956715  66.984733  0.492632    524.0
# 1           QTY   3.878116   22.95082  0.066351     61.0
# 2          TOOL   7.627119       25.0  0.116883     72.0
# 3          PART  69.015444  69.082126  0.690488   2070.0
# 4           DIM       6.25   5.714286  0.059701     35.0
# 5           WGT        0.0        0.0       0.0      2.0
# 6          RPOS  46.153846  34.567901  0.395294    486.0
# 7          PROP   5.612245       40.0  0.098434     55.0
# 8            ID       10.0  64.615385  0.173196     65.0
# 0      accuracy          -          -  60.74184   3370.0
# 1     macro avg  20.832609  36.546139  0.232553   3370.0
# 2  weighted avg  55.688189   60.74184  0.566999   3370.0

# %% [markdown]
# ### not stratified, random

# %%
with open("data/immutable_data_formal/sen_assembly_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 1)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_1_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall  F1 score  support
# 0           DIM  27.777778  14.285714  0.188679     35.0
# 1           WGT        5.0       50.0  0.090909      2.0
# 2          PROP   5.263158  12.727273  0.074468     55.0
# 3          PART  60.404192  77.971014  0.680725   2070.0
# 4          TOOL  13.306452  45.833333   0.20625     72.0
# 5           QTY   6.111111  36.065574  0.104513     61.0
# 6          OPER  35.641736  73.664122  0.480398    524.0
# 7          RPOS  44.688645  25.102881  0.321476    486.0
# 8            ID   7.606679  63.076923  0.135762     65.0
# 0      accuracy          -          -  66.20178   3370.0
# 1     macro avg  22.866639  44.302982  0.253687   3370.0
# 2  weighted avg  50.008487   66.20178  0.551335   3370.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_5_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  36.363636  22.857143   0.280702     35.0
# 1           WGT   4.545455       50.0   0.083333      2.0
# 2          PROP   8.988764  29.090909   0.137339     55.0
# 3          PART  71.539961  88.647343   0.791802   2070.0
# 4          TOOL       25.0  41.666667     0.3125     72.0
# 5           QTY   8.333333  54.098361    0.14442     61.0
# 6          OPER  44.742268  82.824427   0.580991    524.0
# 7          RPOS  61.942257  48.559671   0.544406    486.0
# 8            ID  18.217054  72.307692   0.291022     65.0
# 0      accuracy          -          -  78.338279   3370.0
# 1     macro avg  31.074748  54.450246   0.351835   3370.0
# 2  weighted avg  61.396216  78.338279   0.675318   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_10_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  17.307692  25.714286   0.206897     35.0
# 1           WGT   4.545455       50.0   0.083333      2.0
# 2          PROP  11.165049  41.818182   0.176245     55.0
# 3          PART  71.504559  90.917874    0.80051   2070.0
# 4          TOOL  30.909091  47.222222   0.373626     72.0
# 5           QTY  10.197368  50.819672   0.169863     61.0
# 6          OPER  45.379877  84.351145    0.59012    524.0
# 7          RPOS  60.606061  69.958848   0.649475    486.0
# 8            ID   27.52809  75.384615   0.403292     65.0
# 0      accuracy          -          -  83.412463   3370.0
# 1     macro avg  31.015916  59.576316   0.383707   3370.0
# 2  weighted avg    61.4581  83.412463   0.701039   3370.0

# %%
 #### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_20_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  17.171717  48.571429   0.253731     35.0
# 1           WGT   4.166667       50.0   0.076923      2.0
# 2          PROP  15.289256  67.272727   0.249158     55.0
# 3          PART  76.811594  89.613527   0.827202   2070.0
# 4          TOOL  30.973451  48.611111   0.378378     72.0
# 5           QTY  13.970588  62.295082   0.228228     61.0
# 6          OPER  46.504559   87.59542   0.607545    524.0
# 7          RPOS   66.25222  76.748971   0.711153    486.0
# 8            ID  31.543624  72.307692   0.439252     65.0
# 0      accuracy          -          -  84.925816   3370.0
# 1     macro avg   33.63152  67.001773   0.419064   3370.0
# 2  weighted avg  65.919837  84.925816   0.732563   3370.0

# %% [markdown]
# ### stratified, random

# %%
with open("data/immutable_data_formal/sen_assembly_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_5_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM       25.0  17.142857    0.20339     35.0
# 1           WGT   3.448276       50.0   0.064516      2.0
# 2          PROP   9.848485  23.636364   0.139037     55.0
# 3          PART  73.005641  87.536232   0.796134   2070.0
# 4          TOOL  23.577236  40.277778   0.297436     72.0
# 5           QTY   7.972665  57.377049       0.14     61.0
# 6          OPER  46.768508  75.954198   0.578909    524.0
# 7          RPOS  67.218543  41.769547   0.515228    486.0
# 8            ID   26.05042  95.384615   0.409241     65.0
# 0      accuracy          -          -  75.934718   3370.0
# 1     macro avg  31.432197  54.342071   0.349321   3370.0
# 2  weighted avg  63.381994  75.934718   0.674539   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_10_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  26.666667  22.857143   0.246154     35.0
# 1           WGT   7.692308       50.0   0.133333      2.0
# 2          PROP  13.661202  45.454545   0.210084     55.0
# 3          PART  71.779859   88.84058   0.794041   2070.0
# 4          TOOL  26.612903  45.833333   0.336735     72.0
# 5           QTY  13.307985  57.377049   0.216049     61.0
# 6          OPER  42.511628   87.21374   0.571607    524.0
# 7          RPOS  66.371681  61.728395   0.639659    486.0
# 8            ID    16.7979  98.461538   0.286996     65.0
# 0      accuracy          -          -  81.958457   3370.0
# 1     macro avg  31.711348  61.974036   0.381629   3370.0
# 2  weighted avg   61.91006  81.958457   0.691566   3370.0

# %%
 #### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_20_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  15.231788  65.714286   0.247312     35.0
# 1           WGT   5.555556       50.0        0.1      2.0
# 2          PROP  21.582734  54.545455   0.309278     55.0
# 3          PART  71.977186  91.449275   0.805532   2070.0
# 4          TOOL  33.018868  48.611111   0.393258     72.0
# 5           QTY  15.226337  60.655738   0.243421     61.0
# 6          OPER  50.171821  83.587786   0.627058    524.0
# 7          RPOS  72.222222  61.522634   0.664444    486.0
# 8            ID  31.343284  96.923077   0.473684     65.0
# 0      accuracy          -          -  83.649852   3370.0
# 1     macro avg  35.147755  68.112151   0.429332   3370.0
# 2  weighted avg  64.527467  83.649852   0.717735   3370.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("data/immutable_data_formal/sen_assembly_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 1)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_1_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  47.368421  51.428571   0.493151     35.0
# 1           WGT   5.263158       50.0   0.095238      2.0
# 2          PROP  23.333333  63.636364   0.341463     55.0
# 3          PART  78.179551  90.869565   0.840483   2070.0
# 4          TOOL  29.936306  65.277778    0.41048     72.0
# 5           QTY  10.208817  72.131148   0.178862     61.0
# 6          OPER  48.397104  89.312977   0.627767    524.0
# 7          RPOS  70.019724  73.045267   0.715005    486.0
# 8            ID   16.41791  84.615385      0.275     65.0
# 0      accuracy          -          -  86.172107   3370.0
# 1     macro avg  36.569369  71.146339   0.441939   3370.0
# 2  weighted avg  67.661249  86.172107   0.745048   3370.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_5_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall  F1 score  support
# 0           DIM  43.181818  54.285714  0.481013     35.0
# 1           WGT   7.692308       50.0  0.133333      2.0
# 2          PROP  30.327869  67.272727  0.418079     55.0
# 3          PART  78.278198  94.879227  0.857829   2070.0
# 4          TOOL  43.877551  59.722222  0.505882     72.0
# 5           QTY  17.670683  72.131148  0.283871     61.0
# 6          OPER    53.2382  92.557252  0.675958    524.0
# 7          RPOS  77.220077  82.304527  0.796813    486.0
# 8            ID   34.83871  83.076923  0.490909     65.0
# 0      accuracy          -          -  90.41543   3370.0
# 1     macro avg  42.925046  72.914416  0.515965   3370.0
# 2  weighted avg  70.373305   90.41543  0.784245   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_10_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM       37.5       60.0   0.461538     35.0
# 1           WGT       10.0       50.0   0.166667      2.0
# 2          PROP  27.906977  65.454545   0.391304     55.0
# 3          PART  79.164994    95.2657   0.864723   2070.0
# 4          TOOL  44.660194  63.888889   0.525714     72.0
# 5           QTY  19.130435  72.131148   0.302405     61.0
# 6          OPER  56.781609  94.274809   0.708752    524.0
# 7          RPOS  77.396022  88.065844   0.823869    486.0
# 8            ID  39.716312  86.153846   0.543689     65.0
# 0      accuracy          -          -  91.928783   3370.0
# 1     macro avg   43.58406  75.026087   0.532074   3370.0
# 2  weighted avg  71.534422  91.928783   0.798638   3370.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_20_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  39.622642       60.0   0.477273     35.0
# 1           WGT  22.222222      100.0   0.363636      2.0
# 2          PROP   34.95935  78.181818   0.483146     55.0
# 3          PART  78.276269  96.086957    0.86272   2070.0
# 4          TOOL  54.022989  65.277778   0.591195     72.0
# 5           QTY  22.727273  73.770492    0.34749     61.0
# 6          OPER  58.690476  94.083969   0.722874    524.0
# 7          RPOS  80.294659  89.711934   0.847425    486.0
# 8            ID  43.571429  93.846154   0.595122     65.0
# 0      accuracy          -          -  93.086053   3370.0
# 1     macro avg  48.265256    83.4399   0.587876   3370.0
# 2  weighted avg  72.187256  93.086053   0.807987   3370.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("data/immutable_data_formal/sen_assembly_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_5_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  21.153846  31.428571   0.252874     35.0
# 1           WGT        4.0       50.0   0.074074      2.0
# 2          PROP  21.126761  54.545455   0.304569     55.0
# 3          PART  70.689013  91.690821   0.798318   2070.0
# 4          TOOL   32.55814  38.888889    0.35443     72.0
# 5           QTY   9.187279  42.622951   0.151163     61.0
# 6          OPER  47.357294  85.496183   0.609524    524.0
# 7          RPOS  67.430025  54.526749   0.602958    486.0
# 8            ID   30.27027  86.153846      0.448     65.0
# 0      accuracy          -          -  81.988131   3370.0
# 1     macro avg  33.752514  59.483718   0.399545   3370.0
# 2  weighted avg  62.520773  81.988131   0.698681   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_10_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  12.413793  51.428571        0.2     35.0
# 1           WGT   4.166667       50.0   0.076923      2.0
# 2          PROP  25.862069  54.545455   0.350877     55.0
# 3          PART  74.302103  93.864734   0.829456   2070.0
# 4          TOOL       40.0  52.777778    0.45509     72.0
# 5           QTY  17.061611  59.016393   0.264706     61.0
# 6          OPER  50.555556  86.832061   0.639045    524.0
# 7          RPOS  71.610169  69.547325   0.705637    486.0
# 8            ID  39.215686  92.307692   0.550459     65.0
# 0      accuracy          -          -  86.617211   3370.0
# 1     macro avg  37.243073  67.813334   0.452466   3370.0
# 2  weighted avg  66.300895  86.617211   0.743596   3370.0

# %%
 #### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_20_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  13.333333  57.142857   0.216216     35.0
# 1           WGT   4.545455       50.0   0.083333      2.0
# 2          PROP  25.806452  58.181818   0.357542     55.0
# 3          PART  74.398166  94.057971   0.830809   2070.0
# 4          TOOL  53.846154  58.333333       0.56     72.0
# 5           QTY  20.264317  75.409836   0.319444     61.0
# 6          OPER  54.050926  89.122137   0.672911    524.0
# 7          RPOS  75.714286  76.337449   0.760246    486.0
# 8            ID  45.736434  90.769231   0.608247     65.0
# 0      accuracy          -          -  88.575668   3370.0
# 1     macro avg  40.855058  72.150515   0.489861   3370.0
# 2  weighted avg  67.983697  88.575668   0.762196   3370.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("data/immutable_data_formal/sen_assembly_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 1)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_1_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  45.238095  54.285714   0.493506     35.0
# 1           WGT   5.263158       50.0   0.095238      2.0
# 2          PROP  26.896552  70.909091       0.39     55.0
# 3          PART  78.394535  88.695652   0.832276   2070.0
# 4          TOOL  27.173913  69.444444   0.390625     72.0
# 5           QTY   9.738717  67.213115   0.170124     61.0
# 6          OPER       46.9  89.503817   0.615486    524.0
# 7          RPOS   67.43738  72.016461   0.696517    486.0
# 8            ID       14.0  86.153846    0.24086     65.0
# 0      accuracy          -          -  84.896142   3370.0
# 1     macro avg  35.671372  72.024682    0.43607   3370.0
# 2  weighted avg  67.109972  84.896142   0.734986   3370.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_5_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  52.631579  57.142857   0.547945     35.0
# 1           WGT       10.0       50.0   0.166667      2.0
# 2          PROP  31.060606  74.545455   0.438503     55.0
# 3          PART  78.427419  93.961353   0.854945   2070.0
# 4          TOOL  44.444444  66.666667   0.533333     72.0
# 5           QTY  19.067797  73.770492    0.30303     61.0
# 6          OPER  54.033149  93.320611   0.684395    524.0
# 7          RPOS  76.271186  83.333333    0.79646    486.0
# 8            ID  29.230769  87.692308   0.438462     65.0
# 0      accuracy          -          -  90.534125   3370.0
# 1     macro avg  43.907439  75.603675   0.529304   3370.0
# 2  weighted avg  70.492433  90.534125   0.784704   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_10_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  44.444444  57.142857        0.5     35.0
# 1           WGT  11.764706      100.0   0.210526      2.0
# 2          PROP  31.386861  78.181818   0.447917     55.0
# 3          PART  78.987241  95.700483   0.865443   2070.0
# 4          TOOL  54.545455  66.666667        0.6     72.0
# 5           QTY  23.444976  80.327869   0.362963     61.0
# 6          OPER  54.485777  95.038168   0.692629    524.0
# 7          RPOS  76.130199  86.625514   0.810395    486.0
# 8            ID  34.131737  87.692308   0.491379     65.0
# 0      accuracy          -          -  92.551929   3370.0
# 1     macro avg  45.480155  83.041743   0.553472   3370.0
# 2  weighted avg  71.197256  92.551929   0.797654   3370.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_20_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  46.808511  62.857143   0.536585     35.0
# 1           WGT       25.0      100.0        0.4      2.0
# 2          PROP       35.0  89.090909   0.502564     55.0
# 3          PART  79.482072  96.376812   0.871179   2070.0
# 4          TOOL  60.714286  70.833333   0.653846     72.0
# 5           QTY  22.897196  80.327869   0.356364     61.0
# 6          OPER  56.995413  94.847328   0.712034    524.0
# 7          RPOS  77.256944  91.563786   0.838041    486.0
# 8            ID  42.068966  93.846154   0.580952     65.0
# 0      accuracy          -          -  94.094955   3370.0
# 1     macro avg  49.580376  86.638148    0.60573   3370.0
# 2  weighted avg  72.420266  94.094955   0.812324   3370.0

# %% [markdown]
# ### stratified, tf-idf

# %%
with open("data/immutable_data_formal/sen_assembly_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_5_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  21.568627  31.428571   0.255814     35.0
# 1           WGT       6.25       50.0   0.111111      2.0
# 2          PROP  20.125786  58.181818   0.299065     55.0
# 3          PART  73.493976  91.352657    0.81456   2070.0
# 4          TOOL  31.632653  43.055556   0.364706     72.0
# 5           QTY  10.884354  52.459016   0.180282     61.0
# 6          OPER  44.944945  85.687023   0.589626    524.0
# 7          RPOS  65.732759  62.757202   0.642105    486.0
# 8            ID  24.680851  89.230769   0.386667     65.0
# 0      accuracy          -          -  83.382789   3370.0
# 1     macro avg  33.257106  62.683624   0.404882   3370.0
# 2  weighted avg  63.516283  83.382789   0.710736   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_10_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  16.853933  42.857143   0.241935     35.0
# 1           WGT   5.882353       50.0   0.105263      2.0
# 2          PROP  22.727273  54.545455   0.320856     55.0
# 3          PART  74.534161  92.753623   0.826517   2070.0
# 4          TOOL  39.325843  48.611111   0.434783     72.0
# 5           QTY   15.57377  62.295082    0.24918     61.0
# 6          OPER  47.564767   87.59542   0.616521    524.0
# 7          RPOS   69.54023  74.691358   0.720238    486.0
# 8            ID       30.0  87.692308   0.447059     65.0
# 0      accuracy          -          -  86.587537   3370.0
# 1     macro avg  35.778037  66.782389   0.440261   3370.0
# 2  weighted avg  65.456771  86.587537   0.737648   3370.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_20_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  19.672131  68.571429   0.305732     35.0
# 1           WGT   7.142857       50.0      0.125      2.0
# 2          PROP  26.470588  65.454545   0.376963     55.0
# 3          PART  76.666667  94.444444    0.84632   2070.0
# 4          TOOL  58.974359  63.888889   0.613333     72.0
# 5           QTY  21.212121  68.852459   0.324324     61.0
# 6          OPER  53.863382  91.793893   0.678899    524.0
# 7          RPOS  75.650558  83.744856   0.794922    486.0
# 8            ID  43.356643  95.384615   0.596154     65.0
# 0      accuracy          -          -  90.623145   3370.0
# 1     macro avg   42.55659  75.792792   0.517961   3370.0
# 2  weighted avg   69.49779  90.623145   0.779922   3370.0

# %% [markdown]
# ### not stratified, tfidf_half

# %%
with open("data/immutable_data_formal/sen_assembly_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_5_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM       50.0  62.857143   0.556962     35.0
# 1           WGT   9.090909       50.0   0.153846      2.0
# 2          PROP  34.710744  76.363636   0.477273     55.0
# 3          PART  79.500818  93.864734   0.860877   2070.0
# 4          TOOL  47.524752  66.666667   0.554913     72.0
# 5           QTY  19.626168  68.852459   0.305455     61.0
# 6          OPER  54.565702   93.51145    0.68917    524.0
# 7          RPOS  76.817289  80.452675    0.78593    486.0
# 8            ID  31.413613  92.307692    0.46875     65.0
# 0      accuracy          -          -  90.178042   3370.0
# 1     macro avg  44.805555  76.097384   0.539242   3370.0
# 2  weighted avg  71.463044  90.178042    0.78938   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_10_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Connection error: try again automatically
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Connection error: try again automatically
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  31.666667  54.285714        0.4     35.0
# 1           WGT   6.666667       50.0   0.117647      2.0
# 2          PROP  37.719298  78.181818   0.508876     55.0
# 3          PART  78.763549  94.782609   0.860338   2070.0
# 4          TOOL  52.688172  68.055556   0.593939     72.0
# 5           QTY   20.27027  73.770492   0.318021     61.0
# 6          OPER  54.585635  94.274809   0.691393    524.0
# 7          RPOS  78.178368  84.773663   0.813425    486.0
# 8            ID  32.960894  90.769231   0.483607     65.0
# 0      accuracy          -          -  91.513353   3370.0
# 1     macro avg  43.722169  76.543766   0.531916   3370.0
# 2  weighted avg  71.218643  91.513353   0.793571   3370.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_not_stratified_input_30_example_20_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall  F1 score  support
# 0           DIM  33.802817  68.571429   0.45283     35.0
# 1           WGT  18.181818      100.0  0.307692      2.0
# 2          PROP       37.5  81.818182  0.514286     55.0
# 3          PART  79.299235  95.120773  0.864924   2070.0
# 4          TOOL  58.536585  66.666667  0.623377     72.0
# 5           QTY  22.272727  80.327869  0.348754     61.0
# 6          OPER  54.954955  93.129771  0.691218    524.0
# 7          RPOS  78.533095  90.329218  0.840191    486.0
# 8            ID  39.102564  93.846154  0.552036     65.0
# 0      accuracy          -          -  92.72997   3370.0
# 1     macro avg  46.909311  85.534451  0.577257   3370.0
# 2  weighted avg  71.961364   92.72997  0.803476   3370.0

# %% [markdown]
# ### stratified, tfidf_half

# %%
with open("data/immutable_data_formal/sen_assembly_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_assembly_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 5)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_5_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  23.684211  25.714286   0.246575     35.0
# 1           WGT   4.545455       50.0   0.083333      2.0
# 2          PROP  14.835165  49.090909   0.227848     55.0
# 3          PART   72.85086  88.019324     0.7972   2070.0
# 4          TOOL  23.404255  45.833333   0.309859     72.0
# 5           QTY   8.940397  44.262295    0.14876     61.0
# 6          OPER  42.798774  79.961832   0.557552    524.0
# 7          RPOS  62.005277  48.353909   0.543353    486.0
# 8            ID  20.888889  72.307692   0.324138     65.0
# 0      accuracy          -          -  77.744807   3370.0
# 1     macro avg  30.439254  55.949287   0.359846   3370.0
# 2  weighted avg  61.900481  77.744807   0.676621   3370.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 10)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_10_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM   21.95122  25.714286   0.236842     35.0
# 1           WGT   4.545455       50.0   0.083333      2.0
# 2          PROP  14.893617  50.909091   0.230453     55.0
# 3          PART   72.38835  90.048309   0.802583   2070.0
# 4          TOOL  33.333333  44.444444   0.380952     72.0
# 5           QTY       12.0  49.180328   0.192926     61.0
# 6          OPER  44.902163  83.206107   0.583278    524.0
# 7          RPOS  63.636364  60.493827   0.620253    486.0
# 8            ID  24.170616  78.461538   0.369565     65.0
# 0      accuracy          -          -  81.454006   3370.0
# 1     macro avg  32.424568  59.161992    0.38891   3370.0
# 2  weighted avg  62.492437  81.454006   0.698154   3370.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "assembly", num_examples = 20)
with open("formal_eva_results_gpt3.5/assembly_stratified_input_30_example_20_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# ['DIM', 'WGT', 'PROP', 'PART', 'TOOL', 'QTY', 'OPER', 'RPOS', 'ID']
#          entity  precision     recall   F1 score  support
# 0           DIM  16.981132  25.714286   0.204545     35.0
# 1           WGT   4.545455       50.0   0.083333      2.0
# 2          PROP  16.167665  49.090909   0.243243     55.0
# 3          PART  72.671048  90.821256   0.807387   2070.0
# 4          TOOL  32.989691  44.444444   0.378698     72.0
# 5           QTY  12.809917  50.819672    0.20462     61.0
# 6          OPER  46.318036  82.824427   0.594114    524.0
# 7          RPOS  68.085106  65.843621   0.669456    486.0
# 8            ID  25.531915  73.846154   0.379447     65.0
# 0      accuracy          -          -  82.551929   3370.0
# 1     macro avg  32.899996  59.267197   0.396094   3370.0
# 2  weighted avg  63.530555  82.551929   0.710112   3370.0

# %% [markdown]
# # FabNER

# %%
with open("data/immutable_data_formal/sen_fabner_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### zero-shot

# %%
with open("data/immutable_data_formal/sen_fabner_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)
#### example = 0
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 0)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_0_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500

# %%
def process_response_zero_shot_gpt(response):
    processed_response = []
    for demonstrations_one_sentence in response:
        rows_list = demonstrations_one_sentence.split("\n")

        processed_demonstrations_one_sentence = ""
        for row in rows_list:
            entity_one_row = row.split(": ")[0]
            if len(row.split(": ")) > 1:
                extracted_words_list = row.split(": ")[1].split(", ")    
            else:
                extracted_words_list = row.split(": ")[0].split(", ")    
            processed_demonstrations_one_row = ""
            for extracted_word in extracted_words_list:
                processed_demonstrations_one_row = processed_demonstrations_one_row + extracted_word + ": " + entity_one_row + '\n'
            processed_demonstrations_one_sentence = processed_demonstrations_one_sentence + processed_demonstrations_one_row 

        processed_response.append(processed_demonstrations_one_sentence)    
    
    return processed_response

# %%
processed_response = process_response_zero_shot_gpt(response)
transformed_output = change_output_format_to_tokens_tags(sentences_input, processed_response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision    recall  F1 score  support
# 0           MATE  43.157895  7.564576  0.128728    542.0
# 1           MANP  40.952381   6.04782  0.105392    711.0
# 2           PARA  10.714286  1.538462  0.026906    195.0
# 3           FEAT        4.0   1.30719  0.019704    153.0
# 4           ENAT        0.0       0.0       0.0     52.0
# 5           BIOP        0.0       0.0       0.0      9.0
# 6           CHAR   3.703704  0.512821  0.009009    195.0
# 7            PRO  18.181818  2.843602   0.04918    211.0
# 8           APPL        0.0       0.0       0.0     90.0
# 9           MANS        0.0       0.0       0.0      4.0
# 10         MACEQ        0.0       0.0       0.0    127.0
# 11        CONPRI   7.352941  0.534188   0.00996    936.0
# 0       accuracy          -         -  3.131783   3225.0
# 1      macro avg  10.671919  1.695721  0.029073   3225.0
# 2   weighted avg   20.66696  3.131783  0.054085   3225.0

# %% [markdown]
# ### not stratified, random

# %%
with open("data/immutable_data_formal/sen_fabner_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_not_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 1)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_1_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  29.098361  65.498155   0.402951    542.0
# 1           MANP  35.576923  62.447257   0.453292    711.0
# 2           PARA  17.176871  51.794872   0.257982    195.0
# 3           FEAT   9.665428  16.993464   0.123223    153.0
# 4           ENAT   5.660377   5.769231   0.057143     52.0
# 5           BIOP  12.195122  55.555556        0.2      9.0
# 6           CHAR   5.319149  23.076923   0.086455    195.0
# 7            PRO  20.192308   59.71564   0.301796    211.0
# 8           APPL  10.967742  37.777778       0.17     90.0
# 9           MANS   3.703704       50.0   0.068966      4.0
# 10         MACEQ   6.859206   29.92126   0.111601    127.0
# 11        CONPRI  20.160643  26.816239    0.23017    936.0
# 0       accuracy          -          -  44.341085   3225.0
# 1      macro avg  14.714653  40.447198   0.205298   3225.0
# 2   weighted avg   22.43104  44.341085   0.291581   3225.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_5_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall  F1 score  support
# 0           MATE  37.591623  66.236162  0.479626    542.0
# 1           MANP  45.720894  83.403657  0.590637    711.0
# 2           PARA  18.617021  53.846154   0.27668    195.0
# 3           FEAT    9.61039  24.183007  0.137546    153.0
# 4           ENAT  10.869565   9.615385  0.102041     52.0
# 5           BIOP  13.888889  55.555556  0.222222      9.0
# 6           CHAR  15.045396  59.487179  0.240166    195.0
# 7            PRO  25.289575  62.085308  0.359396    211.0
# 8           APPL  15.422886  34.444444  0.213058     90.0
# 9           MANS   7.142857       50.0     0.125      4.0
# 10         MACEQ  15.151515   55.11811  0.237691    127.0
# 11        CONPRI  21.443737  32.371795  0.257982    936.0
# 0       accuracy          -          -  54.48062   3225.0
# 1      macro avg  19.649529   48.86223  0.270171   3225.0
# 2   weighted avg  28.017149   54.48062  0.364714   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_10_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  37.684211  66.051661   0.479893    542.0
# 1           MANP  46.373457  84.528833   0.598904    711.0
# 2           PARA  21.288014  61.025641    0.31565    195.0
# 3           FEAT  10.787172  24.183007   0.149194    153.0
# 4           ENAT       6.25   5.769231       0.06     52.0
# 5           BIOP      9.375  33.333333   0.146341      9.0
# 6           CHAR  15.810811       60.0   0.250267    195.0
# 7            PRO  27.151052  67.298578   0.386921    211.0
# 8           APPL  16.019417  36.666667   0.222973     90.0
# 9           MANS   7.407407       50.0   0.129032      4.0
# 10         MACEQ  15.346535  48.818898   0.233522    127.0
# 11        CONPRI  20.488467  32.264957   0.250622    936.0
# 0       accuracy          -          -  55.162791   3225.0
# 1      macro avg  19.498462  47.495067    0.26861   3225.0
# 2   weighted avg    28.2223  55.162791   0.368993   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_20_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  41.483198  66.051661   0.509609    542.0
# 1           MANP  49.433657  85.935302   0.627632    711.0
# 2           PARA  21.273032  65.128205   0.320707    195.0
# 3           FEAT  14.371257  31.372549   0.197125    153.0
# 4           ENAT        7.5   5.769231   0.065217     52.0
# 5           BIOP   8.823529  33.333333   0.139535      9.0
# 6           CHAR   18.58864  55.384615   0.278351    195.0
# 7            PRO  26.297578  72.037915   0.385298    211.0
# 8           APPL  17.021277  35.555556   0.230216     90.0
# 9           MANS   6.060606       50.0   0.108108      4.0
# 10         MACEQ   17.87234  66.141732   0.281407    127.0
# 11        CONPRI  24.266862  35.363248   0.287826    936.0
# 0       accuracy          -          -  57.643411   3225.0
# 1      macro avg  21.082665  50.172779   0.285919   3225.0
# 2   weighted avg  31.057668  57.643411   0.397418   3225.0

# %% [markdown]
# ### stratified, random

# %%
with open("data/immutable_data_formal/sen_fabner_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_stratified_input_30_example_20_random.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_5_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall  F1 score  support
# 0           MATE  30.369128  66.789668  0.417532    542.0
# 1           MANP  48.239148  82.841069  0.609731    711.0
# 2           PARA  17.985612  64.102564  0.280899    195.0
# 3           FEAT  12.352941   27.45098  0.170385    153.0
# 4           ENAT   7.142857  15.384615  0.097561     52.0
# 5           BIOP        0.0        0.0       0.0      9.0
# 6           CHAR  10.569106  13.333333  0.117914    195.0
# 7            PRO  21.732283  65.402844  0.326241    211.0
# 8           APPL       16.0  35.555556   0.22069     90.0
# 9           MANS   6.451613      100.0  0.121212      4.0
# 10         MACEQ  15.598886  44.094488  0.230453    127.0
# 11        CONPRI  23.348694  32.478632  0.271671    936.0
# 0       accuracy          -          -  52.27907   3225.0
# 1      macro avg  17.482522  45.619479  0.238691   3225.0
# 2   weighted avg  27.433939   52.27907  0.353943   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_10_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall  F1 score  support
# 0           MATE  32.798574  67.896679  0.442308    542.0
# 1           MANP  47.681041  82.419128  0.604124    711.0
# 2           PARA  18.795888  65.641026  0.292237    195.0
# 3           FEAT   14.40678  44.444444    0.2176    153.0
# 4           ENAT   5.797101   7.692308  0.066116     52.0
# 5           BIOP   9.090909  22.222222  0.129032      9.0
# 6           CHAR  26.456311  55.897436  0.359143    195.0
# 7            PRO  26.185567  60.189573  0.364943    211.0
# 8           APPL  17.318436  34.444444  0.230483     90.0
# 9           MANS   5.194805      100.0  0.098765      4.0
# 10         MACEQ  18.181818  39.370079  0.248756    127.0
# 11        CONPRI  24.634334  34.188034  0.286353    936.0
# 0       accuracy          -          -  55.72093   3225.0
# 1      macro avg   20.54513  51.200448  0.278322   3225.0
# 2   weighted avg  29.631365   55.72093  0.381995   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_20_random.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)   
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  40.149095  69.557196   0.509115    542.0
# 1           MANP  53.976765  84.950774   0.660109    711.0
# 2           PARA  22.585925  70.769231   0.342432    195.0
# 3           FEAT  15.513126   42.48366   0.227273    153.0
# 4           ENAT  10.989011  19.230769    0.13986     52.0
# 5           BIOP        0.0        0.0        0.0      9.0
# 6           CHAR  36.861314  51.794872   0.430704    195.0
# 7            PRO  29.222011  72.985782   0.417344    211.0
# 8           APPL  17.073171  31.111111   0.220472     90.0
# 9           MANS   7.272727      100.0   0.135593      4.0
# 10         MACEQ  16.233766  59.055118   0.254669    127.0
# 11        CONPRI  26.455416  38.354701   0.313127    936.0
# 0       accuracy          -          -  59.379845   3225.0
# 1      macro avg  23.027694  53.357768   0.304225   3225.0
# 2   weighted avg  33.870052  59.379845   0.425414   3225.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("data/immutable_data_formal/sen_fabner_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 1)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_1_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  28.647823  69.188192   0.405186    542.0
# 1           MANP  42.662632  79.324895   0.554845    711.0
# 2           PARA  16.515426  46.666667   0.243968    195.0
# 3           FEAT      11.25  35.294118   0.170616    153.0
# 4           ENAT  14.736842  26.923077   0.190476     52.0
# 5           BIOP  13.636364  33.333333   0.193548      9.0
# 6           CHAR  22.309711  43.589744   0.295139    195.0
# 7            PRO  22.074074  70.616114   0.336343    211.0
# 8           APPL  11.764706  35.555556   0.176796     90.0
# 9           MANS   3.846154       50.0   0.071429      4.0
# 10         MACEQ  15.974441  39.370079   0.227273    127.0
# 11        CONPRI  25.146199   32.15812   0.282232    936.0
# 0       accuracy          -          -  53.333333   3225.0
# 1      macro avg  19.047031  46.834991   0.262321   3225.0
# 2   weighted avg  27.081823  53.333333   0.352614   3225.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_5_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE    34.3379  69.372694   0.459377    542.0
# 1           MANP  48.353414   84.66948   0.615542    711.0
# 2           PARA  17.829457  58.974359    0.27381    195.0
# 3           FEAT   17.69437  43.137255   0.250951    153.0
# 4           ENAT  15.730337  26.923077   0.198582     52.0
# 5           BIOP  16.666667  55.555556    0.25641      9.0
# 6           CHAR  31.528662  50.769231   0.388998    195.0
# 7            PRO  24.584718   70.14218   0.364084    211.0
# 8           APPL  14.830508  38.888889   0.214724     90.0
# 9           MANS   3.174603       50.0   0.059701      4.0
# 10         MACEQ  18.857143  51.968504    0.27673    127.0
# 11        CONPRI  26.582278  38.141026   0.313295    936.0
# 0       accuracy          -          -  58.449612   3225.0
# 1      macro avg  22.514171  53.211854   0.306017   3225.0
# 2   weighted avg  31.039119  58.449612   0.400522   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_10_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall  F1 score  support
# 0           MATE  38.367347  69.372694  0.494087    542.0
# 1           MANP  50.541216  85.372714  0.634937    711.0
# 2           PARA   19.50078  64.102564  0.299043    195.0
# 3           FEAT  19.832402  46.405229  0.277886    153.0
# 4           ENAT  18.604651  30.769231  0.231884     52.0
# 5           BIOP  21.052632  88.888889  0.340426      9.0
# 6           CHAR  34.394904  55.384615  0.424361    195.0
# 7            PRO       25.0  71.090047  0.369914    211.0
# 8           APPL  12.195122  33.333333  0.178571     90.0
# 9           MANS   4.651163       50.0  0.085106      4.0
# 10         MACEQ  18.269231   59.84252  0.279926    127.0
# 11        CONPRI   27.91762  39.102564  0.325768    936.0
# 0       accuracy          -          -      60.0   3225.0
# 1      macro avg  24.193922  57.805367  0.328493   3225.0
# 2   weighted avg  32.952896       60.0  0.419495   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_20_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  43.329532  70.110701   0.535588    542.0
# 1           MANP  53.414002  86.919831    0.66167    711.0
# 2           PARA  21.970921   69.74359   0.334152    195.0
# 3           FEAT  25.076453  53.594771   0.341667    153.0
# 4           ENAT  18.390805  30.769231   0.230216     52.0
# 5           BIOP       25.0  88.888889   0.390244      9.0
# 6           CHAR  31.671554  55.384615   0.402985    195.0
# 7            PRO  27.689594  74.407583   0.403599    211.0
# 8           APPL  16.666667  41.111111   0.237179     90.0
# 9           MANS   5.714286       50.0   0.102564      4.0
# 10         MACEQ  19.909502  69.291339   0.309315    127.0
# 11        CONPRI  28.985507  40.598291   0.338229    936.0
# 0       accuracy          -          -  62.387597   3225.0
# 1      macro avg  26.484902  60.901663   0.357284   3225.0
# 2   weighted avg   35.33785  62.387597   0.444967   3225.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("data/immutable_data_formal/sen_fabner_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_stratified_input_30_example_20_sentence.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_5_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE   34.93744   66.97417   0.459203    542.0
# 1           MANP  45.297216   84.66948   0.590196    711.0
# 2           PARA  18.910256  60.512821   0.288156    195.0
# 3           FEAT  11.021505  26.797386    0.15619    153.0
# 4           ENAT   8.474576   9.615385    0.09009     52.0
# 5           BIOP  11.627907  55.555556   0.192308      9.0
# 6           CHAR  23.272727  32.820513    0.27234    195.0
# 7            PRO  23.763955  70.616114   0.355609    211.0
# 8           APPL  12.345679  33.333333    0.18018     90.0
# 9           MANS    4.83871       75.0   0.090909      4.0
# 10         MACEQ  17.039106  48.031496   0.251546    127.0
# 11        CONPRI  22.096881  35.576923   0.272616    936.0
# 0       accuracy          -          -  55.007752   3225.0
# 1      macro avg   19.46883  49.958598   0.266612   3225.0
# 2   weighted avg  28.090239  55.007752   0.368017   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_10_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  39.194915  68.265683   0.497981    542.0
# 1           MANP  48.870968  85.232068    0.62122    711.0
# 2           PARA      21.25   69.74359   0.325749    195.0
# 3           FEAT  13.650794  28.104575   0.183761    153.0
# 4           ENAT  13.953488  11.538462   0.126316     52.0
# 5           BIOP   9.677419  33.333333       0.15      9.0
# 6           CHAR  31.023102  48.205128    0.37751    195.0
# 7            PRO  26.386555  74.407583   0.389578    211.0
# 8           APPL  14.473684  36.666667   0.207547     90.0
# 9           MANS   5.172414       75.0   0.096774      4.0
# 10         MACEQ  17.555556  62.204724    0.27383    127.0
# 11        CONPRI  23.793338  37.393162   0.290818    936.0
# 0       accuracy          -          -  58.294574   3225.0
# 1      macro avg  22.083519  52.507915    0.29509   3225.0
# 2   weighted avg  31.155476  58.294574   0.400934   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_20_sentence.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  43.341121  68.450185   0.530758    542.0
# 1           MANP  53.546713  87.060478   0.663096    711.0
# 2           PARA  21.821036  71.282051   0.334135    195.0
# 3           FEAT       17.5  36.601307   0.236786    153.0
# 4           ENAT  12.244898  11.538462   0.118812     52.0
# 5           BIOP       10.0  44.444444   0.163265      9.0
# 6           CHAR  35.785953  54.871795   0.433198    195.0
# 7            PRO  28.366248  74.881517   0.411458    211.0
# 8           APPL  18.269231  42.222222   0.255034     90.0
# 9           MANS   5.882353       75.0   0.109091      4.0
# 10         MACEQ  17.034068  66.929134   0.271565    127.0
# 11        CONPRI  26.129944  39.529915   0.314626    936.0
# 0       accuracy          -          -  60.651163   3225.0
# 1      macro avg   24.16013  56.067626   0.320152   3225.0
# 2   weighted avg  34.255563  60.651163   0.431573   3225.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("data/immutable_data_formal/sen_fabner_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 1
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 1)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_1_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  28.916602  68.450185   0.406575    542.0
# 1           MANP   38.96648  78.481013   0.520765    711.0
# 2           PARA  19.561551  59.487179   0.294416    195.0
# 3           FEAT  11.061947  32.679739   0.165289    153.0
# 4           ENAT  14.492754  19.230769   0.165289     52.0
# 5           BIOP       12.5  44.444444   0.195122      9.0
# 6           CHAR  25.268817  48.205128    0.33157    195.0
# 7            PRO  22.687861  74.407583    0.34773    211.0
# 8           APPL  13.432836       40.0   0.201117     90.0
# 9           MANS   2.857143       50.0   0.054054      4.0
# 10         MACEQ  16.938111  40.944882   0.239631    127.0
# 11        CONPRI  22.682927  29.807692   0.257618    936.0
# 0       accuracy          -          -  53.612403   3225.0
# 1      macro avg  19.113919  48.844885   0.264931   3225.0
# 2   weighted avg  26.067712  53.612403   0.344678   3225.0

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_5_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  35.255198  68.819188    0.46625    542.0
# 1           MANP  47.124601  82.981716   0.601121    711.0
# 2           PARA  20.970266  68.717949   0.321343    195.0
# 3           FEAT  17.312661   43.79085   0.248148    153.0
# 4           ENAT  14.893617  26.923077   0.191781     52.0
# 5           BIOP  12.820513  55.555556   0.208333      9.0
# 6           CHAR  31.932773  58.461538   0.413043    195.0
# 7            PRO  26.622296  75.829384   0.394089    211.0
# 8           APPL  15.234375  43.333333   0.225434     90.0
# 9           MANS   4.918033       75.0   0.092308      4.0
# 10         MACEQ  19.710145  53.543307   0.288136    127.0
# 11        CONPRI   27.32688  39.209402   0.322071    936.0
# 0       accuracy          -          -  59.968992   3225.0
# 1      macro avg  22.843447  57.680442   0.314338   3225.0
# 2   weighted avg  31.490825  59.968992   0.407748   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_10_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  39.225941  69.188192   0.500668    542.0
# 1           MANP       50.0  85.091421    0.62988    711.0
# 2           PARA  23.302469  77.435897   0.358244    195.0
# 3           FEAT   22.65625  56.862745   0.324022    153.0
# 4           ENAT  17.924528  36.538462   0.240506     52.0
# 5           BIOP       20.0  88.888889   0.326531      9.0
# 6           CHAR   34.80663  64.615385   0.452424    195.0
# 7            PRO  30.366492  82.464455   0.443878    211.0
# 8           APPL  15.899582  42.222222   0.231003     90.0
# 9           MANS    4.83871       75.0   0.090909      4.0
# 10         MACEQ  21.727749  65.354331    0.32613    127.0
# 11        CONPRI  28.169014  42.735043   0.339559    936.0
# 0       accuracy          -          -  64.155039   3225.0
# 1      macro avg  25.743114  65.533087   0.355313   3225.0
# 2   weighted avg  34.016584  64.155039   0.439183   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_20_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  43.068182  69.926199   0.533052    542.0
# 1           MANP  54.008811  86.216596   0.664139    711.0
# 2           PARA  23.427673  76.410256   0.358604    195.0
# 3           FEAT  26.285714  60.130719   0.365805    153.0
# 4           ENAT  23.529412  46.153846   0.311688     52.0
# 5           BIOP       15.0  66.666667   0.244898      9.0
# 6           CHAR   35.73487  63.589744   0.457565    195.0
# 7            PRO  31.711712  83.412322    0.45953    211.0
# 8           APPL   20.37037  48.888889   0.287582     90.0
# 9           MANS   7.692308       75.0   0.139535      4.0
# 10         MACEQ  21.634615  70.866142   0.331492    127.0
# 11        CONPRI  30.785124   47.75641   0.374372    936.0
# 0       accuracy          -          -  66.573643   3225.0
# 1      macro avg  27.770733  66.251483   0.377355   3225.0
# 2   weighted avg  36.830358  66.573643   0.468392   3225.0

# %% [markdown]
# ### stratified, tf-idf

# %%
with open("data/immutable_data_formal/sen_fabner_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_stratified_input_30_example_20_tfidf.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_5_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  33.303249  68.081181   0.447273    542.0
# 1           MANP  42.898762  82.841069   0.565259    711.0
# 2           PARA  18.196203  58.974359   0.278114    195.0
# 3           FEAT   10.39823  30.718954   0.155372    153.0
# 4           ENAT       1.25   1.923077   0.015152     52.0
# 5           BIOP    8.62069  55.555556   0.149254      9.0
# 6           CHAR   9.953704  22.051282   0.137161    195.0
# 7            PRO  26.177024  65.876777   0.374663    211.0
# 8           APPL  10.188679       30.0   0.152113     90.0
# 9           MANS   3.448276       50.0   0.064516      4.0
# 10         MACEQ  14.893617  49.606299   0.229091    127.0
# 11        CONPRI  20.894372  28.952991   0.242723    936.0
# 0       accuracy          -          -  51.813953   3225.0
# 1      macro avg  16.685234  45.381795   0.234224   3225.0
# 2   weighted avg  25.946318  51.813953   0.341237   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_10_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  37.525355  68.265683   0.484293    542.0
# 1           MANP  45.670498  83.825598    0.59127    711.0
# 2           PARA  18.968134  64.102564    0.29274    195.0
# 3           FEAT  15.533981  41.830065   0.226549    153.0
# 4           ENAT   7.936508   9.615385   0.086957     52.0
# 5           BIOP   2.272727  11.111111   0.037736      9.0
# 6           CHAR  20.861678  47.179487   0.289308    195.0
# 7            PRO  28.233151  73.459716   0.407895    211.0
# 8           APPL  14.937759       40.0   0.217523     90.0
# 9           MANS   7.142857      100.0   0.133333      4.0
# 10         MACEQ  16.628702  57.480315   0.257951    127.0
# 11        CONPRI  22.432024  31.730769   0.262832    936.0
# 0       accuracy          -          -  56.372093   3225.0
# 1      macro avg  19.845281  52.383391   0.274032   3225.0
# 2   weighted avg  29.093183  56.372093   0.378558   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_20_tfidf.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  42.359551  69.557196   0.526536    542.0
# 1           MANP   51.41196  87.060478   0.646475    711.0
# 2           PARA  21.702838  66.666667   0.327456    195.0
# 3           FEAT  23.322684  47.712418   0.313305    153.0
# 4           ENAT  19.318182  32.692308   0.242857     52.0
# 5           BIOP   5.660377  33.333333   0.096774      9.0
# 6           CHAR  26.056338  56.923077   0.357488    195.0
# 7            PRO  30.018083  78.672986   0.434555    211.0
# 8           APPL  16.666667  38.888889   0.233333     90.0
# 9           MANS   8.510638      100.0   0.156863      4.0
# 10         MACEQ  18.312757   70.07874   0.290375    127.0
# 11        CONPRI  26.446281  37.606838   0.310543    936.0
# 0       accuracy          -          -  61.271318   3225.0
# 1      macro avg  24.148863  59.932744   0.328047   3225.0
# 2   weighted avg  33.611465  61.271318   0.428183   3225.0

# %% [markdown]
# ### not stratified, tf-idf_half

# %%
with open("data/immutable_data_formal/sen_fabner_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_5_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  34.303913  69.557196   0.459476    542.0
# 1           MANP  47.016129  81.997187   0.597642    711.0
# 2           PARA  22.380952  72.307692   0.341818    195.0
# 3           FEAT  15.128205  38.562092   0.217311    153.0
# 4           ENAT  13.333333  23.076923   0.169014     52.0
# 5           BIOP       12.5  44.444444   0.195122      9.0
# 6           CHAR  31.564246  57.948718    0.40868    195.0
# 7            PRO  25.281804  74.407583   0.377404    211.0
# 8           APPL       13.0  43.333333        0.2     90.0
# 9           MANS   4.761905       75.0   0.089552      4.0
# 10         MACEQ  22.222222  53.543307   0.314088    127.0
# 11        CONPRI  24.193548  33.653846   0.281501    936.0
# 0       accuracy          -          -  58.015504   3225.0
# 1      macro avg  22.140521  55.652693   0.304301   3225.0
# 2   weighted avg  30.279641  58.015504   0.392392   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_10_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall  F1 score  support
# 0           MATE  38.358974   69.00369  0.493078    542.0
# 1           MANP  50.291424  84.950774  0.631799    711.0
# 2           PARA  23.222749  75.384615  0.355072    195.0
# 3           FEAT   18.13602  47.058824  0.261818    153.0
# 4           ENAT       17.5  26.923077  0.212121     52.0
# 5           BIOP  17.021277  88.888889  0.285714      9.0
# 6           CHAR  35.582822  59.487179  0.445298    195.0
# 7            PRO  26.635514  81.042654  0.400938    211.0
# 8           APPL  16.956522  43.333333   0.24375     90.0
# 9           MANS   3.508772       50.0  0.065574      4.0
# 10         MACEQ  21.776504   59.84252  0.319328    127.0
# 11        CONPRI  26.546003  37.606838  0.311229    936.0
# 0       accuracy          -          -  61.24031   3225.0
# 1      macro avg  24.628048  60.293533  0.335477   3225.0
# 2   weighted avg  33.062247   61.24031   0.42321   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_not_stratified_input_30_example_20_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  42.040359  69.188192   0.523013    542.0
# 1           MANP  52.081563  86.216596   0.649364    711.0
# 2           PARA  24.705882  75.384615   0.372152    195.0
# 3           FEAT  23.167155  51.633987   0.319838    153.0
# 4           ENAT  17.582418  30.769231   0.223776     52.0
# 5           BIOP  17.391304  88.888889   0.290909      9.0
# 6           CHAR  34.770115  62.051282   0.445672    195.0
# 7            PRO  28.475712   80.56872   0.420792    211.0
# 8           APPL  18.468468  45.555556   0.262821     90.0
# 9           MANS       6.25       75.0   0.115385      4.0
# 10         MACEQ  21.641791  68.503937   0.328922    127.0
# 11        CONPRI  30.888031  42.735043   0.358584    936.0
# 0       accuracy          -          -  63.875969   3225.0
# 1      macro avg  26.455233  64.708004   0.359269   3225.0
# 2   weighted avg   35.77808  63.875969   0.452138   3225.0

# %% [markdown]
# ### stratified, tf-idf_half

# %%
with open("data/immutable_data_formal/sen_fabner_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_sen = pickle.load(data)    
with open("data/immutable_data_formal/dem_fabner_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   # Unpickling
    all_fewshot_dem = pickle.load(data)

# %%
#### example = 5
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 5)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_5_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  29.472025   69.00369   0.413031    542.0
# 1           MANP  38.990182  78.199719   0.520356    711.0
# 2           PARA  17.045455  53.846154    0.25894    195.0
# 3           FEAT   7.531381  23.529412   0.114105    153.0
# 4           ENAT   6.578947   9.615385   0.078125     52.0
# 5           BIOP        8.0  44.444444   0.135593      9.0
# 6           CHAR  12.631579  24.615385   0.166957    195.0
# 7            PRO  23.271501  65.402844   0.343284    211.0
# 8           APPL   13.02521  34.444444   0.189024     90.0
# 9           MANS   3.389831       50.0   0.063492      4.0
# 10         MACEQ  12.756264  44.094488    0.19788    127.0
# 11        CONPRI   19.67943  23.611111   0.214667    936.0
# 0       accuracy          -          -  48.868217   3225.0
# 1      macro avg  16.030984   43.40059   0.224621   3225.0
# 2   weighted avg  23.933455  48.868217   0.314848   3225.0

# %%
#### example = 10
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 10)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_10_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  31.814273  68.265683   0.434018    542.0
# 1           MANP  40.783745  79.043601   0.538056    711.0
# 2           PARA  17.781403  55.897436   0.269802    195.0
# 3           FEAT   9.395973   27.45098       0.14    153.0
# 4           ENAT   8.196721   9.615385   0.088496     52.0
# 5           BIOP   6.382979  33.333333   0.107143      9.0
# 6           CHAR  12.121212  24.615385   0.162437    195.0
# 7            PRO  24.048443  65.876777   0.352345    211.0
# 8           APPL  11.983471  32.222222   0.174699     90.0
# 9           MANS   4.081633       50.0   0.075472      4.0
# 10         MACEQ  14.691943  48.818898   0.225865    127.0
# 11        CONPRI  22.047244  26.923077   0.242424    936.0
# 0       accuracy          -          -  50.325581   3225.0
# 1      macro avg  16.944087  43.505231    0.23423   3225.0
# 2   weighted avg   25.63225  50.325581   0.333343   3225.0

# %%
#### example = 20
prompt_text , response = get_direct_gpt_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 20)
with open("formal_eva_results_gpt3.5/fabner_stratified_input_30_example_20_tfidf_half.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# Instruction generated: running GPT API now. Input: 180
# Instruction generated: running GPT API now. Input: 190
# Instruction generated: running GPT API now. Input: 200
# Instruction generated: running GPT API now. Input: 210
# Instruction generated: running GPT API now. Input: 220
# Instruction generated: running GPT API now. Input: 230
# Instruction generated: running GPT API now. Input: 240
# Instruction generated: running GPT API now. Input: 250
# Instruction generated: running GPT API now. Input: 260
# Instruction generated: running GPT API now. Input: 270
# Instruction generated: running GPT API now. Input: 280
# Instruction generated: running GPT API now. Input: 290
# Instruction generated: running GPT API now. Input: 300
# Instruction generated: running GPT API now. Input: 310
# Instruction generated: running GPT API now. Input: 320
# Instruction generated: running GPT API now. Input: 330
# Instruction generated: running GPT API now. Input: 340
# Instruction generated: running GPT API now. Input: 350
# Instruction generated: running GPT API now. Input: 360
# Instruction generated: running GPT API now. Input: 370
# Instruction generated: running GPT API now. Input: 380
# Instruction generated: running GPT API now. Input: 390
# Instruction generated: running GPT API now. Input: 400
# Instruction generated: running GPT API now. Input: 410
# Instruction generated: running GPT API now. Input: 420
# Instruction generated: running GPT API now. Input: 430
# Instruction generated: running GPT API now. Input: 440
# Instruction generated: running GPT API now. Input: 450
# Instruction generated: running GPT API now. Input: 460
# Instruction generated: running GPT API now. Input: 470
# Instruction generated: running GPT API now. Input: 480
# Instruction generated: running GPT API now. Input: 490
# Instruction generated: running GPT API now. Input: 500
# ['MATE', 'MANP', 'PARA', 'FEAT', 'ENAT', 'BIOP', 'CHAR', 'PRO', 'APPL', 'MANS', 'MACEQ', 'CONPRI']
#           entity  precision     recall   F1 score  support
# 0           MATE  34.553991  67.896679   0.457996    542.0
# 1           MANP  45.712038  81.715893   0.586276    711.0
# 2           PARA  18.121911  56.410256   0.274314    195.0
# 3           FEAT  13.216958  34.640523   0.191336    153.0
# 4           ENAT   5.454545   5.769231   0.056075     52.0
# 5           BIOP   7.692308  44.444444   0.131148      9.0
# 6           CHAR   18.09291  37.948718   0.245033    195.0
# 7            PRO  26.215278  71.563981   0.383736    211.0
# 8           APPL  11.594203  26.666667   0.161616     90.0
# 9           MANS   4.347826       50.0       0.08      4.0
# 10         MACEQ  14.989293   55.11811    0.23569    127.0
# 11        CONPRI  22.893617  28.739316   0.254856    936.0
# 0       accuracy          -          -  52.992248   3225.0
# 1      macro avg   18.57374  46.742818    0.25484   3225.0
# 2   weighted avg  28.090181  52.992248    0.36094   3225.0

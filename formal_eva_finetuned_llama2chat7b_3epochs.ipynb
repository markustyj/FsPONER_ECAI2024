# %%
import pickle
import nltk
nltk.download('punkt')

from gpt_ner_api_codes.prompts_all import *
from gpt_ner_api_codes.demonstration_samples_generation import *
# %reload_ext autoreload
# %autoreload 2

import tqdm
def nop(it, *a, **k):
    return it
tqdm.tqdm = nop
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def process_response(response):    
    processed_response = []
    for item in response:
        #dem = item[0]["generated_text"]
        #dem = dem.replace("* ", "")
        #dem = dem.split("Note: ")[0]
        #print("############################### not processed" +  item)
        dem = item
        dem = dem.split("Extracted entities of the above sentence:")[-1]
        dem = dem.split("\n\n")[0]
        #print("############################### processed" +  dem)
        processed_response.append ( dem)
    return processed_response

# %% [markdown]
# # Thin-film technology dataset

# %%
with open("data/immutable_data_formal/sen_thf_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %%
with open("formal_eva_results_finetuned_llama2chat7b/thf_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(len(response), response[0])    
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['EnergyFlow', 'Location', 'Consequence', 'Material', 'Effect', 'Function', 'Measure', 'Component', 'Shape', 'System', 'State', 'PhysicsFlow', 'Value', 'AnnotatorNotes', 'Attribution', 'ScientificConcept', 'InfoFlow']
#                entity  precision     recall   F1 score  support
# 0          EnergyFlow  75.531915   74.34555    0.74934    382.0
# 1            Location  87.941788  89.240506   0.885864    474.0
# 2         Consequence       40.0  18.181818       0.25     22.0
# 3            Material  85.618729  81.012658    0.83252    316.0
# 4              Effect  73.205742   58.62069   0.651064    261.0
# 5            Function  69.942197  77.070064   0.733333    314.0
# 6             Measure  37.209302  42.105263   0.395062     38.0
# 7           Component  89.689781  89.363636   0.895264   2200.0
# 8               Shape  72.316384  67.015707   0.695652    191.0
# 9              System  86.931818  62.962963    0.73031    243.0
# 10              State      100.0  33.333333        0.5      6.0
# 11        PhysicsFlow  91.304348       75.0   0.823529     28.0
# 12              Value  84.782609       65.0   0.735849     60.0
# 13     AnnotatorNotes        0.0        0.0        0.0      3.0
# 14        Attribution  74.009901  80.376344   0.770619    372.0
# 15  ScientificConcept   56.20915  47.252747   0.513433    182.0
# 16           InfoFlow  88.888889   89.88764   0.893855     89.0
# 0            accuracy          -          -  80.138969   5181.0
# 1           macro avg  71.387209  61.809936   0.650335   5181.0
# 2        weighted avg  82.440906  80.138969   0.810601   5181.0

# %% [markdown]
# # Assembly instruction

# %%
with open("data/immutable_data_formal/sen_assembly_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_assembly_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %%
def process_response(response):    
    processed_response = []
    for item in response:
        dem = item[0]["generated_text"]
        #dem = dem.replace("* ", "")
        #dem = dem.split("Note: ")[0]
        #print(item)
        #print(item['generated_text'])
        #print("############################### not processed" +  item)
        #dem = item
        dem = dem.split("Extracted entities of the input sentence:")[-1]
        dem = dem.split("\n\n")[0]
        #print("############################### processed" +  dem)
        processed_response.append ( dem)
    return processed_response

# %%
with open("formal_eva_results_finetuned_llama2chat7b/assembly_not_stratified_input_30_example_0_random_3_epochs.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(len(response), response[0])    
# for i in response[5:10]:
#     print(i)
response = process_response(response)    
#print(response)
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'DIM', 'WGT', 'OPER', 'RPOS', 'PROP', 'PART', 'ID', 'TOOL']
#          entity  precision     recall  F1 score  support
# 0           QTY     96.875  50.819672  0.666667     61.0
# 1           DIM  63.636364       20.0  0.304348     35.0
# 2           WGT        0.0        0.0       0.0      2.0
# 3          OPER   88.80597  45.419847   0.60101    524.0
# 4          RPOS  91.101695  44.238683  0.595568    486.0
# 5          PROP  77.777778  38.181818  0.512195     55.0
# 6          PART  94.869487  50.917874  0.662685   2070.0
# 7            ID  92.682927  58.461538  0.716981     65.0
# 8          TOOL  86.111111  43.055556  0.574074     72.0
# 0      accuracy          -          -  48.51632   3370.0
# 1     macro avg   76.87337  39.010554  0.514836   3370.0
# 2  weighted avg  92.530684   48.51632  0.636071   3370.0

# %% [markdown]
# # FabNER manufacturing

# %%
with open("data/immutable_data_formal/sen_fabner_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %%
with open("formal_eva_results_finetuned_llama2chat7b/fabner_not_stratified_input_30_example_0_random_3_epochs.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(len(response), response[0])    
print(response)
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [[{'generated_text': '\n\nExtracted entities of the input sentence: \n\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\nExtracted: CONPRI\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}], [{'generated_text': '\n\nExtracted: CONPRI\n\n\n\nExtracted: CONPRI\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\nExtracted: CONPRI\n\n\n\n\n\n\n\n\n\n\nExt'}], [{ ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33012\4127782982.py in <cell line: 5>()
#       3 #print(len(response), response[0])
#       4 print(response)
# ----> 5 response = process_response(response)
#       6 transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
#       7 transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
#
# ~\AppData\Local\Temp\ipykernel_33012\3850144868.py in process_response(response)
#       7         #print("############################### not processed" +  item)
#       8         dem = item
# ----> 9         dem = dem.split("Extracted entities of the above sentence:")[-1]
#      10         dem = dem.split("\n\n")[0]
#      11         #print("############################### processed" +  dem)
#
# AttributeError: 'list' object has no attribute 'split'

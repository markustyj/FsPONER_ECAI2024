# %%
import pickle
import nltk
nltk.download('punkt')
from random import shuffle
from sklearn.model_selection import train_test_split


from gpt_ner_api_codes.prompts_all import *
from gpt_ner_api_codes.demonstration_samples_generation import *
# %reload_ext autoreload
# %autoreload 2

import tqdm
def nop(it, *a, **k):
    return itm
tqdm.tqdm = nop
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Thin-film technology

# %%
#test data, size 500
with open("data/immutable_data_formal/sen_thf_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)
#training data, size 3760
with open("data/immutable_data_formal/sen_thf_train.txt", "rb") as data:   #Pickling
    sentences_train = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_train.txt", "rb") as data:   #Pickling
    demonstrations_train = pickle.load(data)    
    
print(len(sentences_input), len(sentences_train))
# Out:
# 500 3760

# %% [markdown]
# ### test the stratification of development dataset

# %%
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 100, num_input = 2)
# Out:
# (array(['AnnotatorNotes', 'Attribution', 'Component', 'Consequence',
#        'Effect', 'EnergyFlow', 'Function', 'InfoFlow', 'Location',
#        'Material', 'Measure', 'PhysicsFlow', 'ScientificConcept', 'Shape',
#        'State', 'System', 'Value'], dtype='<U1679'), array([   24,  1722, 11802,   114,   678,  1443,  1386,   198,  2413,
#         1537,   144,   126,   635,   979,    40,   994,   297],
#       dtype=int64))
# Duplicated few-shot examples:  102
# length of stratified_sentences_develop:  95
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  3735

# %% [markdown]
# ### Different development sizes

# %%
# development size = 100
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 100, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "film", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 60)
with open("results_gpt4/thf_not_stratified_input_30_example_60_tfidf_development_100.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# Instruction generated: running GPT API now. Input: 110
# Instruction generated: running GPT API now. Input: 120
# Instruction generated: running GPT API now. Input: 130
# Instruction generated: running GPT API now. Input: 140
# Instruction generated: running GPT API now. Input: 150
# Instruction generated: running GPT API now. Input: 160
# Instruction generated: running GPT API now. Input: 170
# ...

# %%
# development size = 800
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 800, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "film", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 60)
with open("results_gpt4/thf_not_stratified_input_30_example_60_tfidf_development_800.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['AnnotatorNotes', 'Attribution', 'Component', 'Consequence',
#        'Effect', 'EnergyFlow', 'Function', 'InfoFlow', 'Location',
#        'Material', 'Measure', 'PhysicsFlow', 'ScientificConcept', 'Shape',
#        'State', 'System', 'Value'], dtype='<U1679'), array([   24,  1722, 11802,   114,   678,  1443,  1386,   198,  2413,
#         1537,   144,   126,   635,   979,    40,   994,   297],
#       dtype=int64))
# Duplicated few-shot examples:  800
# length of stratified_sentences_develop:  672
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  3735
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# ...

# %%
# development size = 1500
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 1500, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "film", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 60)
with open("results_gpt4/thf_not_stratified_input_30_example_60_tfidf_development_1500.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# (array(['AnnotatorNotes', 'Attribution', 'Component', 'Consequence',
#        'Effect', 'EnergyFlow', 'Function', 'InfoFlow', 'Location',
#        'Material', 'Measure', 'PhysicsFlow', 'ScientificConcept', 'Shape',
#        'State', 'System', 'Value'], dtype='<U1679'), array([   24,  1722, 11802,   114,   678,  1443,  1386,   198,  2413,
#         1537,   144,   126,   635,   979,    40,   994,   297],
#       dtype=int64))
# Duplicated few-shot examples:  1500
# length of stratified_sentences_develop:  1134
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  3753
# Instruction generated: running GPT API now. Input: 10
# ...

# %%
# development size = 3500
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 3500, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "film", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "film", num_examples = 60)
with open("results_gpt4/thf_not_stratified_input_30_example_60_tfidf_development_3500.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['AnnotatorNotes', 'Attribution', 'Component', 'Consequence',
#        'Effect', 'EnergyFlow', 'Function', 'InfoFlow', 'Location',
#        'Material', 'Measure', 'PhysicsFlow', 'ScientificConcept', 'Shape',
#        'State', 'System', 'Value'], dtype='<U1679'), array([   24,  1722, 11802,   114,   678,  1443,  1386,   198,  2413,
#         1537,   144,   126,   635,   979,    40,   994,   297],
#       dtype=int64))
# Duplicated few-shot examples:  3500
# length of stratified_sentences_develop:  2022
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  3753
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# ...

# %% [markdown]
# # FabNER dataset

# %%
#test data, size 500
with open("data/immutable_data_formal/sen_fabner_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)
#training data, size 13658
with open("data/immutable_data_formal/sen_fabner_train.txt", "rb") as data:   #Pickling
    sentences_train = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_train.txt", "rb") as data:   #Pickling
    demonstrations_train = pickle.load(data)    
    
print(len(sentences_input), len(sentences_train))
# Out:
# 500 13658

# %%
# development size = 100
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 100, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "fabner", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 60)
with open("results_gpt4/fabner_not_stratified_input_30_example_60_tfidf_development_100.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['APPL', 'BIOP', 'CHAR', 'CONPRI', 'ENAT', 'FEAT', 'MACEQ', 'MANP',
#        'MANS', 'MATE', 'PARA', 'PRO'], dtype='<U1044'), array([ 2201,   234,  2221, 21011,  1234,  2597,  2538, 10582,    91,
#        12829,  3471,  5099], dtype=int64))
# Duplicated few-shot examples:  108
# length of stratified_sentences_develop:  108
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  13638
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# ...

# %%
# development size = 800
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 800, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "fabner", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 60)
with open("results_gpt4/fabner_not_stratified_input_30_example_60_tfidf_development_800.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['APPL', 'BIOP', 'CHAR', 'CONPRI', 'ENAT', 'FEAT', 'MACEQ', 'MANP',
#        'MANS', 'MATE', 'PARA', 'PRO'], dtype='<U1044'), array([ 2201,   234,  2221, 21011,  1234,  2597,  2538, 10582,    91,
#        12829,  3471,  5099], dtype=int64))
# Duplicated few-shot examples:  804
# length of stratified_sentences_develop:  768
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  13638
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# ...

# %%
# development size = 1500
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 1500, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "fabner", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 60)
with open("results_gpt4/fabner_not_stratified_input_30_example_60_tfidf_development_1500.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['APPL', 'BIOP', 'CHAR', 'CONPRI', 'ENAT', 'FEAT', 'MACEQ', 'MANP',
#        'MANS', 'MATE', 'PARA', 'PRO'], dtype='<U1044'), array([ 2201,   234,  2221, 21011,  1234,  2597,  2538, 10582,    91,
#        12829,  3471,  5099], dtype=int64))
# Duplicated few-shot examples:  1500
# length of stratified_sentences_develop:  1393
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  13638
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# ...

# %%
# development size = 3000
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 3000, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "fabner", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 60)
with open("results_gpt4/fabner_not_stratified_input_30_example_60_tfidf_development_3000.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['APPL', 'BIOP', 'CHAR', 'CONPRI', 'ENAT', 'FEAT', 'MACEQ', 'MANP',
#        'MANS', 'MATE', 'PARA', 'PRO'], dtype='<U1044'), array([ 2201,   234,  2221, 21011,  1234,  2597,  2538, 10582,    91,
#        12829,  3471,  5099], dtype=int64))
# Duplicated few-shot examples:  3000
# length of stratified_sentences_develop:  2634
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  13638
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# ...

# %%
# development size = 6000
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 6000, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "fabner", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 60)
with open("results_gpt4/fabner_not_stratified_input_30_example_60_tfidf_development_6000.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['APPL', 'BIOP', 'CHAR', 'CONPRI', 'ENAT', 'FEAT', 'MACEQ', 'MANP',
#        'MANS', 'MATE', 'PARA', 'PRO'], dtype='<U1044'), array([ 2201,   234,  2221, 21011,  1234,  2597,  2538, 10582,    91,
#        12829,  3471,  5099], dtype=int64))
# Duplicated few-shot examples:  6000
# length of stratified_sentences_develop:  4679
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  13638
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# ...

# %%
# development size = 12000
# get entities of each sentence in the few-shot dataset
entity_list =  get_entity_from_demonstrations(demonstrations_train) 
# print(len(sentences), len(demonstrations), len(entity_list) )
sentences_dev, _, _, demonstrations_dev, _, _ = stratify_the_dataset(sentences_train, demonstrations_train, entity_list, demon_size = 12000, num_input = 2)

all_fewshot_sen, all_fewshot_dem = get_textual_instruction_with_fewshot_examples(sentences_input, sentences_dev, demonstrations_dev, method = "tfidf", dataset = "fabner", num_examples=100, stratify=False)
prompt_text , response = get_direct_gpt4_response(all_fewshot_sen, all_fewshot_dem, sentences_input, dataset = "fabner", num_examples = 60)
with open("results_gpt4/fabner_not_stratified_input_30_example_60_tfidf_development_12000.txt", "wb") as data:   #Pickling
    pickle.dump(response, data)  
    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# (array(['APPL', 'BIOP', 'CHAR', 'CONPRI', 'ENAT', 'FEAT', 'MACEQ', 'MANP',
#        'MANS', 'MATE', 'PARA', 'PRO'], dtype='<U1044'), array([ 2201,   234,  2221, 21011,  1234,  2597,  2538, 10582,    91,
#        12829,  3471,  5099], dtype=int64))
# Duplicated few-shot examples:  12000
# length of stratified_sentences_develop:  7478
# length of stratified_sentences_test:  2
# length of stratified_sentences_train:  13638
# Instruction generated: running GPT API now. Input: 10
# Instruction generated: running GPT API now. Input: 20
# Instruction generated: running GPT API now. Input: 30
# Instruction generated: running GPT API now. Input: 40
# Instruction generated: running GPT API now. Input: 50
# Instruction generated: running GPT API now. Input: 60
# Instruction generated: running GPT API now. Input: 70
# Instruction generated: running GPT API now. Input: 80
# Instruction generated: running GPT API now. Input: 90
# Instruction generated: running GPT API now. Input: 100
# ...

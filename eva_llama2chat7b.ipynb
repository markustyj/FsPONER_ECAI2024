# %%
import pickle
import nltk
nltk.download('punkt')

from gpt_ner_api_codes.prompts_all import *
from gpt_ner_api_codes.demonstration_samples_generation import *
# %reload_ext autoreload
# %autoreload 2

import tqdm
def nop(it, *a, **k):
    return it
tqdm.tqdm = nop
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def process_response(response):    
    processed_response = []
    for item in response:
        dem = item[0]["generated_text"]
        dem = dem.replace("* ", "")
        dem = dem.split("Note: ")[0]
        dem = dem.split("\n\n")[0]
        processed_response.append ( dem)
    return processed_response

# %% [markdown]
# # Thin film head technology dataset

# %%
with open("data/immutable_data_formal/sen_thf_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### zero-shot

# %%
def process_response_zero_shot(response):
    processed_response = []
    for demonstrations_one_sentence in response:
        rows_list = demonstrations_one_sentence.split("\n")

        processed_demonstrations_one_sentence = ""
        for row in rows_list:
            entity_one_row = row.split(": ")[0]
            if len(row.split(": ")) > 1:
                extracted_words_list = row.split(": ")[1].split(", ")    
            else:
                extracted_words_list = row.split(": ")[0].split(", ")    
            processed_demonstrations_one_row = ""
            for extracted_word in extracted_words_list:
                processed_demonstrations_one_row = processed_demonstrations_one_row + extracted_word + ": " + entity_one_row + '\n'
            processed_demonstrations_one_sentence = processed_demonstrations_one_sentence + processed_demonstrations_one_row 

        processed_response.append(processed_demonstrations_one_sentence)    
    
    return processed_response

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
print(response[10])    
response = process_response(response)   
print(response[10])    
response = process_response_zero_shot(response)   
print(response[10])    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [{'generated_text': 'Component: central nonair-bearing region\nLocation: central part of the slider\nFunction: eliminates any lift\nEnergyFlow: low-flying height\nAttribution: allows for\nMaterial: central nonair-bearing region\nEffect: eliminates any lift\nSystem: slider\nScientificConcept: lift\nShape: central part of the slider\nValue: low-flying height\nInfoFlow: allows for\nConsequence: low-flying height\nPhysicsFlow: lift\nMeasure: low-flying height\nState: central part of the slider\nAnnotatorNotes: None\n\nNote: The extracted entities are in the format of "Extracted words: entity types" where "Extracted words" are the actual words extracted from the input sentence and "entity types" are the types of entities they represent.'}]
# Component: central nonair-bearing region
# Location: central part of the slider
# Function: eliminates any lift
# EnergyFlow: low-flying height
# Attribution: allows for
# Material: central nonair-bearing region
# Effect: eliminates any lift
# System: slider
# ScientificConcept: lift
# Shape: central part of the slider
# Value: low-flying height
# InfoFlow: allows for
# Consequence: low-flying height
# PhysicsFlow: lift
# Measure: low-flying height
# State: central part of the slider
# AnnotatorNotes: None
# central nonair-bearing region: Component
# central part of the slider: Location
# eliminates any lift: Function
# low-flying height: EnergyFlow
# allows for: Attribution
# central nonair-bearing region: Material
# eliminates any lift: Effect
# slider: System
# lift: ScientificConcept
# central part of the slider: Shape
# low-flying height: Value
# allows for: InfoFlow
# low-flying height: Consequence
# lift: PhysicsFlow
# low-flying height: Measure
# central part of the slider: State
# None: AnnotatorNotes
#
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall   F1 score  support
# 0         Attribution   0.409836   0.268817   0.003247    372.0
# 1              System   5.029586   6.995885    0.05852    243.0
# 2          EnergyFlow  17.272727   4.973822   0.077236    382.0
# 3         Consequence   2.484472  36.363636   0.046512     22.0
# 4            InfoFlow   2.307692   6.741573   0.034384     89.0
# 5   ScientificConcept   2.068966   1.648352   0.018349    182.0
# 6               State   0.695652  66.666667   0.013769      6.0
# 7               Value   2.371542       10.0   0.038339     60.0
# 8            Material  21.130221   27.21519   0.237898    316.0
# 9         PhysicsFlow   1.897019       25.0   0.035264     28.0
# 10             Effect  16.666667  14.942529   0.157576    261.0
# 11           Function   6.212425   9.872611   0.076261    314.0
# 12              Shape   8.455882  12.041885   0.099352    191.0
# 13           Location  10.277136  18.776371   0.132836    474.0
# 14     AnnotatorNotes        0.0        0.0        0.0      3.0
# 15          Component  61.988304  14.454545   0.234427   2200.0
# 16            Measure   1.366743  15.789474   0.025157     38.0
# 0            accuracy          -          -  12.796757   5181.0
# 1           macro avg    9.44911  15.985374   0.075831   5181.0
# 2        weighted avg  31.789133  12.796757    0.15337   5181.0

# %% [markdown]
# ### not stratified, random

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_1_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
print(response[10])    
response = process_response(response)   
print(response[10])    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [{'generated_text': 'presence: Attribution\ncentral nonair-bearing region: Component\nlift: Attribution\ncentral part: Location\nslider: Component\nlow-flying height: Function\n\nPlease provide the input sentence for which you want to extract the entities.'}]
# presence: Attribution
# central nonair-bearing region: Component
# lift: Attribution
# central part: Location
# slider: Component
# low-flying height: Function
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall   F1 score  support
# 0         Attribution  13.397129  15.053763   0.141772    372.0
# 1              System  16.766467  11.522634   0.136585    243.0
# 2          EnergyFlow  67.647059   6.020942   0.110577    382.0
# 3         Consequence        0.0        0.0        0.0     22.0
# 4            InfoFlow        0.0        0.0        0.0     89.0
# 5   ScientificConcept        0.0        0.0        0.0    182.0
# 6               State      100.0  33.333333        0.5      6.0
# 7               Value  11.320755       50.0   0.184615     60.0
# 8            Material       55.2  21.835443   0.312925    316.0
# 9         PhysicsFlow        0.0        0.0        0.0     28.0
# 10             Effect  13.978495   4.980843   0.073446    261.0
# 11           Function  12.147505  17.834395   0.144516    314.0
# 12              Shape  28.571429  12.565445   0.174545    191.0
# 13           Location  28.045977  25.738397   0.268427    474.0
# 14     AnnotatorNotes        0.0        0.0        0.0      3.0
# 15          Component  56.553148  74.727273   0.643822   2200.0
# 16            Measure        0.0        0.0        0.0     38.0
# 0            accuracy          -          -  39.895773   5181.0
# 1           macro avg  23.742821  16.094851   0.158308   5181.0
# 2        weighted avg   39.42331  39.895773   0.363378   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
print(response[10])    
response = process_response(response)   
print(response[10])    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [{'generated_text': 'presence: Attribution\ncentral: Location\nnonair-bearing region: Component\neliminates: Attribution\nlift: Value\ncentral part: Location\nlow-flying height: ScientificConcept\n\nNote: The extracted entities are not limited to the ones listed above, and you may identify additional entities based on the context of the sentence.'}]
# presence: Attribution
# central: Location
# nonair-bearing region: Component
# eliminates: Attribution
# lift: Value
# central part: Location
# low-flying height: ScientificConcept
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall   F1 score  support
# 0         Attribution   7.485605  10.483871   0.087346    372.0
# 1              System       62.5   2.057613   0.039841    243.0
# 2          EnergyFlow  28.138528  17.015707   0.212072    382.0
# 3         Consequence      18.75  13.636364   0.157895     22.0
# 4            InfoFlow        0.0        0.0        0.0     89.0
# 5   ScientificConcept   5.965293   30.21978   0.099638    182.0
# 6               State        0.0        0.0        0.0      6.0
# 7               Value   4.819277  33.333333   0.084211     60.0
# 8            Material  43.323442  46.202532   0.447167    316.0
# 9         PhysicsFlow        0.0        0.0        0.0     28.0
# 10             Effect        0.0        0.0        0.0    261.0
# 11           Function  11.627907   1.592357   0.028011    314.0
# 12              Shape  25.114155  28.795812   0.268293    191.0
# 13           Location       26.0  16.455696    0.20155    474.0
# 14     AnnotatorNotes        0.0        0.0        0.0      3.0
# 15          Component  68.107093  65.909091   0.669901   2200.0
# 16            Measure        0.0        0.0        0.0     38.0
# 0            accuracy          -          -  37.077784   5181.0
# 1           macro avg  17.754782  15.629539   0.135054   5181.0
# 2        weighted avg  41.460371  37.077784   0.370683   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall   F1 score  support
# 0         Attribution  12.327044  26.344086   0.167952    372.0
# 1              System      100.0   1.234568    0.02439    243.0
# 2          EnergyFlow  33.916084   25.39267   0.290419    382.0
# 3         Consequence  16.666667   9.090909   0.117647     22.0
# 4            InfoFlow        0.0        0.0        0.0     89.0
# 5   ScientificConcept   8.639706  25.824176   0.129477    182.0
# 6               State        0.0        0.0        0.0      6.0
# 7               Value    12.1673  53.333333   0.198142     60.0
# 8            Material  32.007576  53.481013   0.400474    316.0
# 9         PhysicsFlow      100.0   3.571429   0.068966     28.0
# 10             Effect  27.027027   15.32567   0.195599    261.0
# 11           Function   9.090909   0.636943   0.011905    314.0
# 12              Shape  26.190476  11.518325       0.16    191.0
# 13           Location  34.398496  38.607595   0.363817    474.0
# 14     AnnotatorNotes        0.0        0.0        0.0      3.0
# 15          Component  63.565217  66.454545   0.649778   2200.0
# 16            Measure        0.0        0.0        0.0     38.0
# 0            accuracy          -          -  41.652191   5181.0
# 1           macro avg  27.999794  19.459721   0.163445   5181.0
# 2        weighted avg  44.100458  41.652191    0.39243   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall  F1 score  support
# 0         Attribution  20.367279  32.795699  0.251287    372.0
# 1              System  18.942731  17.695473  0.182979    243.0
# 2          EnergyFlow  58.851675  32.198953  0.416244    382.0
# 3         Consequence        0.0        0.0       0.0     22.0
# 4            InfoFlow  91.666667  12.359551  0.217822     89.0
# 5   ScientificConcept       17.6  24.175824  0.203704    182.0
# 6               State       50.0  33.333333       0.4      6.0
# 7               Value       15.0       40.0  0.218182     60.0
# 8            Material  40.874525  68.037975  0.510689    316.0
# 9         PhysicsFlow       25.0   3.571429    0.0625     28.0
# 10             Effect  33.224756   39.08046  0.359155    261.0
# 11           Function  16.129032  12.738854  0.142349    314.0
# 12              Shape  31.034483   4.712042  0.081818    191.0
# 13           Location  30.133657  52.320675  0.382421    474.0
# 14     AnnotatorNotes        0.0        0.0       0.0      3.0
# 15          Component  64.833333  70.727273  0.676522   2200.0
# 16            Measure       40.0  10.526316  0.166667     38.0
# 0            accuracy          -          -  49.10249   5181.0
# 1           macro avg  32.568126  26.721991  0.251314   5181.0
# 2        weighted avg  46.118391   49.10249  0.455904   5181.0

# %% [markdown]
# ### stratified, random

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure        0.0        0.0        0.0     38.0
# 1         Attribution   9.386282  13.978495   0.112311    372.0
# 2            Location  28.178694  34.599156   0.310606    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System  17.073171   5.761317   0.086154    243.0
# 5               Shape  32.142857  18.848168   0.237624    191.0
# 6            Material   32.34375  65.506329   0.433054    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept   6.962025   6.043956   0.064706    182.0
# 9              Effect  21.511628   28.35249   0.244628    261.0
# 10        Consequence        0.0        0.0        0.0     22.0
# 11           Function        0.0        0.0        0.0    314.0
# 12        PhysicsFlow        0.0        0.0        0.0     28.0
# 13           InfoFlow        0.0        0.0        0.0     89.0
# 14          Component  66.926829  62.363636   0.645647   2200.0
# 15              Value       10.0  38.333333   0.158621     60.0
# 16         EnergyFlow  29.761905  19.633508   0.236593    382.0
# 0            accuracy          -          -  39.143023   5181.0
# 1           macro avg  14.958067  17.260023    0.14882   5181.0
# 2        weighted avg   39.26786  39.143023   0.383732   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall  F1 score  support
# 0             Measure        0.0        0.0       0.0     38.0
# 1         Attribution  13.257576  37.634409  0.196078    372.0
# 2            Location  35.729847  34.599156  0.351554    474.0
# 3               State        0.0        0.0       0.0      6.0
# 4              System  13.442623  16.872428  0.149635    243.0
# 5               Shape  35.955056  33.507853  0.346883    191.0
# 6            Material  35.304991  60.443038  0.445741    316.0
# 7      AnnotatorNotes        0.0        0.0       0.0      3.0
# 8   ScientificConcept  13.615023  15.934066  0.146835    182.0
# 9              Effect  22.144522  36.398467  0.275362    261.0
# 10        Consequence        0.0        0.0       0.0     22.0
# 11           Function  22.556391    9.55414  0.134228    314.0
# 12        PhysicsFlow        0.0        0.0       0.0     28.0
# 13           InfoFlow        0.0        0.0       0.0     89.0
# 14          Component  64.454343  65.772727  0.651069   2200.0
# 15              Value  19.480519       50.0  0.280374     60.0
# 16         EnergyFlow  40.133779  31.413613  0.352423    382.0
# 0            accuracy          -          -  45.37734   5181.0
# 1           macro avg  18.592628  23.066465  0.195893   5181.0
# 2        weighted avg  41.844811   45.37734  0.426093   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure        0.0        0.0        0.0     38.0
# 1         Attribution  13.026445  35.752688   0.190955    372.0
# 2            Location  39.493671  32.911392   0.359033    474.0
# 3               State  33.333333  33.333333   0.333333      6.0
# 4              System     4.6875   3.703704   0.041379    243.0
# 5               Shape  29.032258  32.984293   0.308824    191.0
# 6            Material  38.953488  63.607595   0.483173    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  23.809524  13.736264   0.174216    182.0
# 9              Effect  34.319527  44.444444   0.387312    261.0
# 10        Consequence        0.0        0.0        0.0     22.0
# 11           Function  45.833333   3.503185   0.065089    314.0
# 12        PhysicsFlow        0.0        0.0        0.0     28.0
# 13           InfoFlow  28.571429   4.494382    0.07767     89.0
# 14          Component  63.373984  70.863636   0.669099   2200.0
# 15              Value  21.126761       50.0    0.29703     60.0
# 16         EnergyFlow  41.046832  39.005236        0.4    382.0
# 0            accuracy          -          -  47.442579   5181.0
# 1           macro avg  24.506358   25.19648   0.222771   5181.0
# 2        weighted avg  44.268457  47.442579     0.4377   5181.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_1_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall   F1 score  support
# 0         Attribution   26.01626  17.204301    0.20712    372.0
# 1              System  32.758621   15.63786   0.211699    243.0
# 2          EnergyFlow  46.031746  22.774869   0.304729    382.0
# 3         Consequence    9.52381  18.181818      0.125     22.0
# 4            InfoFlow  81.481481  24.719101    0.37931     89.0
# 5   ScientificConcept  15.725806  21.428571   0.181395    182.0
# 6               State  14.285714  33.333333        0.2      6.0
# 7               Value  16.666667  46.666667   0.245614     60.0
# 8            Material  53.672316  60.126582   0.567164    316.0
# 9         PhysicsFlow  15.151515  17.857143   0.163934     28.0
# 10             Effect  51.006711  29.118774   0.370732    261.0
# 11           Function  35.748792  23.566879   0.284069    314.0
# 12              Shape  31.446541   26.17801   0.285714    191.0
# 13           Location   34.18259  33.966245   0.340741    474.0
# 14     AnnotatorNotes   6.666667  33.333333   0.111111      3.0
# 15          Component  65.573034  66.318182   0.659435   2200.0
# 16            Measure  23.684211  23.684211   0.236842     38.0
# 0            accuracy          -          -  44.566686   5181.0
# 1           macro avg   32.91897  30.240934   0.286742   5181.0
# 2        weighted avg   49.40046  44.566686   0.458657   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  24.074074  34.210526   0.282609     38.0
# 1         Attribution  32.098765  34.946237    0.33462    372.0
# 2            Location  42.051282  51.898734   0.464589    474.0
# 3               State       10.0  33.333333   0.153846      6.0
# 4              System  47.619048  20.576132   0.287356    243.0
# 5               Shape  46.296296  39.267016   0.424929    191.0
# 6            Material  59.943182  66.772152   0.631737    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  21.779141  39.010989   0.279528    182.0
# 9              Effect  49.230769  36.781609   0.421053    261.0
# 10        Consequence  18.604651  36.363636   0.246154     22.0
# 11           Function  41.078838  31.528662   0.356757    314.0
# 12        PhysicsFlow   29.62963  28.571429   0.290909     28.0
# 13           InfoFlow  74.193548  51.685393   0.609272     89.0
# 14          Component  72.030981  76.090909   0.740053   2200.0
# 15              Value  25.833333  51.666667   0.344444     60.0
# 16         EnergyFlow  58.075601  44.240838   0.502229    382.0
# 0            accuracy          -          -  56.533488   5181.0
# 1           macro avg  38.384655  39.820251   0.374711   5181.0
# 2        weighted avg  56.352232  56.533488   0.557457   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure   21.95122  23.684211   0.227848     38.0
# 1         Attribution  31.782946  44.086022   0.369369    372.0
# 2            Location   41.97349  60.126582   0.494363    474.0
# 3               State  13.333333  33.333333   0.190476      6.0
# 4              System  36.458333  14.403292    0.20649    243.0
# 5               Shape  49.253731  34.554974   0.406154    191.0
# 6            Material   59.00277  67.405063   0.629247    316.0
# 7      AnnotatorNotes   5.555556  33.333333   0.095238      3.0
# 8   ScientificConcept  23.758865  36.813187   0.288793    182.0
# 9              Effect  51.528384  45.210728   0.481633    261.0
# 10        Consequence   21.95122  40.909091   0.285714     22.0
# 11           Function  35.573123   28.66242    0.31746    314.0
# 12        PhysicsFlow  30.769231  28.571429   0.296296     28.0
# 13           InfoFlow   80.30303  59.550562   0.683871     89.0
# 14          Component  69.864177  74.818182   0.722564   2200.0
# 15              Value  23.853211  43.333333   0.307692     60.0
# 16         EnergyFlow  53.358209  37.434555       0.44    382.0
# 0            accuracy          -          -  56.649296   5181.0
# 1           macro avg  38.251225  41.542959   0.379012   5181.0
# 2        weighted avg  54.528248  56.649296   0.547769   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  31.578947  31.578947   0.315789     38.0
# 1         Attribution  32.046332  44.623656   0.373034    372.0
# 2            Location  40.945946  63.924051   0.499176    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System  30.434783  25.925926       0.28    243.0
# 5               Shape  48.275862  36.649215   0.416667    191.0
# 6            Material  58.579882  62.658228   0.605505    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  24.150943  35.164835   0.286353    182.0
# 9              Effect  41.101695  37.164751   0.390342    261.0
# 10        Consequence  19.565217  40.909091   0.264706     22.0
# 11           Function  37.549407  30.254777   0.335097    314.0
# 12        PhysicsFlow  25.925926       25.0   0.254545     28.0
# 13           InfoFlow  72.307692  52.808989    0.61039     89.0
# 14          Component  71.910112  72.727273   0.723164   2200.0
# 15              Value  32.967033       50.0   0.397351     60.0
# 16         EnergyFlow  61.924686  38.743455   0.476651    382.0
# 0            accuracy          -          -  56.147462   5181.0
# 1           macro avg  37.015557  38.125482   0.366398   5181.0
# 2        weighted avg  55.201307  56.147462   0.550032   5181.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  10.204082  13.157895   0.114943     38.0
# 1         Attribution  14.828897  20.967742   0.173719    372.0
# 2            Location  31.869919  41.350211   0.359963    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System  26.829268   4.526749   0.077465    243.0
# 5               Shape  37.815126  23.560209   0.290323    191.0
# 6            Material  40.044248  57.278481   0.471354    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  13.114754  30.769231   0.183908    182.0
# 9              Effect  28.108108  19.923372   0.233184    261.0
# 10        Consequence        0.0        0.0        0.0     22.0
# 11           Function  28.205128  17.515924    0.21611    314.0
# 12        PhysicsFlow   4.545455   3.571429       0.04     28.0
# 13           InfoFlow  68.181818  16.853933    0.27027     89.0
# 14          Component  68.465788  73.227273   0.707665   2200.0
# 15              Value  14.438503       45.0   0.218623     60.0
# 16         EnergyFlow  41.121495  34.554974   0.375533    382.0
# 0            accuracy          -          -  47.577688   5181.0
# 1           macro avg  25.163093  23.662201   0.219592   5181.0
# 2        weighted avg  46.203639  47.577688   0.456213   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure    10.9375  18.421053   0.137255     38.0
# 1         Attribution  19.581749  27.688172   0.229399    372.0
# 2            Location  34.401114  52.109705    0.41443    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System       20.0    6.17284    0.09434    243.0
# 5               Shape  38.059701  26.701571   0.313846    191.0
# 6            Material  49.625935  62.974684   0.555091    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  16.507937  28.571429   0.209256    182.0
# 9              Effect  32.793522  31.034483   0.318898    261.0
# 10        Consequence  30.769231  18.181818   0.228571     22.0
# 11           Function  29.239766  15.923567   0.206186    314.0
# 12        PhysicsFlow  14.285714  10.714286   0.122449     28.0
# 13           InfoFlow       50.0  31.460674   0.386207     89.0
# 14          Component  67.935702       73.0   0.703769   2200.0
# 15              Value  25.438596  48.333333   0.333333     60.0
# 16         EnergyFlow  47.432024  41.099476   0.440393    382.0
# 0            accuracy          -          -  50.801004   5181.0
# 1           macro avg  28.647558  28.963946   0.276084   5181.0
# 2        weighted avg  47.711449  50.801004   0.484594   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  11.290323  18.421053       0.14     38.0
# 1         Attribution  24.854369  34.408602   0.288613    372.0
# 2            Location  36.935484  48.312236   0.418647    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System  27.678571  12.757202   0.174648    243.0
# 5               Shape  39.849624  27.748691    0.32716    191.0
# 6            Material  51.274788  57.278481   0.541106    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  15.017065  24.175824   0.185263    182.0
# 9              Effect  34.745763  31.417625    0.32998    261.0
# 10        Consequence  13.333333   9.090909   0.108108     22.0
# 11           Function  34.210526  20.700637   0.257937    314.0
# 12        PhysicsFlow  17.647059  10.714286   0.133333     28.0
# 13           InfoFlow  74.285714  29.213483   0.419355     89.0
# 14          Component  67.518731  69.636364   0.685612   2200.0
# 15              Value    20.3125  21.666667   0.209677     60.0
# 16         EnergyFlow   46.52568  40.314136   0.431978    382.0
# 0            accuracy          -          -  49.218298   5181.0
# 1           macro avg  30.322325   26.81507   0.273613   5181.0
# 2        weighted avg  49.256472  49.218298   0.485862   5181.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_1_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Attribution', 'System', 'EnergyFlow', 'Consequence', 'InfoFlow', 'ScientificConcept', 'State', 'Value', 'Material', 'PhysicsFlow', 'Effect', 'Function', 'Shape', 'Location', 'AnnotatorNotes', 'Component', 'Measure']
#                entity  precision     recall   F1 score  support
# 0         Attribution  37.254902  20.430108   0.263889    372.0
# 1              System  43.119266  19.341564   0.267045    243.0
# 2          EnergyFlow  55.319149  20.418848   0.298279    382.0
# 3         Consequence  12.903226  18.181818   0.150943     22.0
# 4            InfoFlow  67.647059  25.842697   0.373984     89.0
# 5   ScientificConcept  20.444444  25.274725   0.226044    182.0
# 6               State  26.315789  83.333333        0.4      6.0
# 7               Value  17.045455       50.0   0.254237     60.0
# 8            Material  51.587302  61.708861    0.56196    316.0
# 9         PhysicsFlow  16.666667  32.142857   0.219512     28.0
# 10             Effect  51.048951  27.969349   0.361386    261.0
# 11           Function  37.209302  25.477707   0.302457    314.0
# 12              Shape  34.545455  29.842932   0.320225    191.0
# 13           Location   32.97491  38.818565   0.356589    474.0
# 14     AnnotatorNotes  14.285714  33.333333        0.2      3.0
# 15          Component  65.037244       63.5   0.642594   2200.0
# 16            Measure  24.444444  28.947368    0.26506     38.0
# 0            accuracy          -          -  44.701795   5181.0
# 1           macro avg   35.75584  35.562592   0.321424   5181.0
# 2        weighted avg  51.096779  44.701795   0.463228   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  35.483871  28.947368   0.318841     38.0
# 1         Attribution   33.62069  41.935484   0.373206    372.0
# 2            Location  47.709924  52.742616   0.501002    474.0
# 3               State   9.090909  33.333333   0.142857      6.0
# 4              System  44.347826  20.987654   0.284916    243.0
# 5               Shape  47.101449  34.031414   0.395137    191.0
# 6            Material  60.504202   68.35443   0.641902    316.0
# 7      AnnotatorNotes   9.090909  33.333333   0.142857      3.0
# 8   ScientificConcept  18.766756  38.461538   0.252252    182.0
# 9              Effect  54.320988  33.716475   0.416076    261.0
# 10        Consequence       24.0  54.545455   0.333333     22.0
# 11           Function  44.559585  27.388535    0.33925    314.0
# 12        PhysicsFlow  36.666667  39.285714    0.37931     28.0
# 13           InfoFlow  75.862069  49.438202   0.598639     89.0
# 14          Component  72.065313  74.227273   0.731303   2200.0
# 15              Value  30.769231  53.333333   0.390244     60.0
# 16         EnergyFlow   50.59761  33.246073   0.401264    382.0
# 0            accuracy          -          -  55.105192   5181.0
# 1           macro avg  40.856353  42.194602   0.390729   5181.0
# 2        weighted avg   56.94912  55.105192   0.551068   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure       25.0  26.315789    0.25641     38.0
# 1         Attribution   34.80663  50.806452   0.413115    372.0
# 2            Location  54.528302  60.970464   0.575697    474.0
# 3               State  22.222222  33.333333   0.266667      6.0
# 4              System  35.862069  21.399177   0.268041    243.0
# 5               Shape  52.631579  36.649215   0.432099    191.0
# 6            Material  57.458564  65.822785   0.613569    316.0
# 7      AnnotatorNotes   4.761905  33.333333   0.083333      3.0
# 8   ScientificConcept  22.651934  45.054945   0.301471    182.0
# 9              Effect  57.978723  41.762452   0.485523    261.0
# 10        Consequence  22.641509  54.545455       0.32     22.0
# 11           Function  38.071066   23.88535   0.293542    314.0
# 12        PhysicsFlow   30.30303  35.714286   0.327869     28.0
# 13           InfoFlow       80.0  58.426966   0.675325     89.0
# 14          Component  73.752228  75.227273   0.744824   2200.0
# 15              Value  25.688073  46.666667   0.331361     60.0
# 16         EnergyFlow  55.087719  41.099476   0.470765    382.0
# 0            accuracy          -          -  57.923181   5181.0
# 1           macro avg  40.790915   44.17726   0.403507   5181.0
# 2        weighted avg  58.160939  57.923181   0.572885   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  17.647059  23.684211   0.202247     38.0
# 1         Attribution  32.459677   43.27957   0.370968    372.0
# 2            Location  44.193062  61.814346   0.515391    474.0
# 3               State       10.0  33.333333   0.153846      6.0
# 4              System  36.538462   39.09465   0.377734    243.0
# 5               Shape  52.898551  38.219895   0.443769    191.0
# 6            Material  53.452685  66.139241   0.591231    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  24.367089  42.307692   0.309237    182.0
# 9              Effect  53.301887  43.295019   0.477801    261.0
# 10        Consequence      18.75  40.909091   0.257143     22.0
# 11           Function  39.565217  28.980892   0.334559    314.0
# 12        PhysicsFlow       50.0  28.571429   0.363636     28.0
# 13           InfoFlow  88.709677  61.797753   0.728477     89.0
# 14          Component   75.62826       72.5   0.740311   2200.0
# 15              Value  28.421053       45.0   0.348387     60.0
# 16         EnergyFlow  57.241379  43.455497   0.494048    382.0
# 0            accuracy          -          -  57.575758   5181.0
# 1           macro avg  40.186709   41.90486   0.394634   5181.0
# 2        weighted avg  57.915075  57.575758   0.571185   5181.0

# %% [markdown]
# ### stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  22.727273  26.315789   0.243902     38.0
# 1         Attribution  17.029703   23.11828   0.196123    372.0
# 2            Location    35.7022  44.514768   0.396244    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System  18.604651   3.292181   0.055944    243.0
# 5               Shape       25.0  20.942408    0.22792    191.0
# 6            Material  38.443936  53.164557   0.446215    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  13.265306  28.571429   0.181185    182.0
# 9              Effect  36.567164  18.773946   0.248101    261.0
# 10        Consequence       37.5  13.636364        0.2     22.0
# 11           Function     11.875   6.050955   0.080169    314.0
# 12        PhysicsFlow        0.0        0.0        0.0     28.0
# 13           InfoFlow  48.484848  17.977528   0.262295     89.0
# 14          Component  67.924528       72.0   0.699029   2200.0
# 15              Value  15.060241  41.666667   0.221239     60.0
# 16         EnergyFlow  37.677054  34.816754   0.361905    382.0
# 0            accuracy          -          -  46.400309   5181.0
# 1           macro avg    25.0507  23.814213   0.224722   5181.0
# 2        weighted avg  44.609761  46.400309   0.445514   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  11.111111  18.421053   0.138614     38.0
# 1         Attribution  20.629921  35.215054   0.260179    372.0
# 2            Location  33.643411  45.780591   0.387846    474.0
# 3               State   8.333333  33.333333   0.133333      6.0
# 4              System  15.714286   4.526749   0.070288    243.0
# 5               Shape  43.362832   25.65445   0.322368    191.0
# 6            Material  44.212963  60.443038   0.510695    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  17.142857  32.967033   0.225564    182.0
# 9              Effect  32.888889   28.35249   0.304527    261.0
# 10        Consequence        0.0        0.0        0.0     22.0
# 11           Function  33.742331  17.515924   0.230608    314.0
# 12        PhysicsFlow   3.448276   3.571429   0.035088     28.0
# 13           InfoFlow  52.083333  28.089888   0.364964     89.0
# 14          Component  66.736842  72.045455   0.692896   2200.0
# 15              Value   22.44898  36.666667   0.278481     60.0
# 16         EnergyFlow  41.971831  39.005236   0.404342    382.0
# 0            accuracy          -          -  49.778035   5181.0
# 1           macro avg  26.321835  28.328729   0.256458   5181.0
# 2        weighted avg  46.592934  49.778035   0.472626   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  11.111111  18.421053   0.138614     38.0
# 1         Attribution  23.464567  40.053763   0.295929    372.0
# 2            Location  39.020537  52.109705   0.446251    474.0
# 3               State   8.695652  33.333333   0.137931      6.0
# 4              System  20.379147  17.695473   0.189427    243.0
# 5               Shape  33.333333  27.225131   0.299712    191.0
# 6            Material  52.272727  58.227848   0.550898    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  19.272727  29.120879   0.231947    182.0
# 9              Effect     40.625  39.846743   0.402321    261.0
# 10        Consequence        0.0        0.0        0.0     22.0
# 11           Function   26.42487  16.242038   0.201183    314.0
# 12        PhysicsFlow   7.142857   7.142857   0.071429     28.0
# 13           InfoFlow  70.731707   32.58427   0.446154     89.0
# 14          Component  69.524656  71.136364   0.703213   2200.0
# 15              Value       25.0       35.0   0.291667     60.0
# 16         EnergyFlow  43.195266  38.219895   0.405556    382.0
# 0            accuracy          -          -  51.244933   5181.0
# 1           macro avg  28.834951   30.37408   0.283072   5181.0
# 2        weighted avg  49.294356  51.244933   0.497327   5181.0

# %% [markdown]
# ### not stratified, td-idf_half

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  27.659574  34.210526   0.305882     38.0
# 1         Attribution  32.822757  40.322581   0.361882    372.0
# 2            Location  48.818898  52.320675   0.505092    474.0
# 3               State  10.526316  33.333333       0.16      6.0
# 4              System  51.754386  24.279835   0.330532    243.0
# 5               Shape  46.153846  31.413613   0.373832    191.0
# 6            Material  56.812339  69.936709    0.62695    316.0
# 7      AnnotatorNotes       20.0  66.666667   0.307692      3.0
# 8   ScientificConcept     15.625  35.714286   0.217391    182.0
# 9              Effect  45.086705  29.885057   0.359447    261.0
# 10        Consequence  16.666667  36.363636   0.228571     22.0
# 11           Function  42.937853  24.203822   0.309572    314.0
# 12        PhysicsFlow      31.25  35.714286   0.333333     28.0
# 13           InfoFlow       75.0  37.078652   0.496241     89.0
# 14          Component  71.969006  71.772727   0.718707   2200.0
# 15              Value       20.0  46.666667       0.28     60.0
# 16         EnergyFlow  47.058824  33.507853   0.391437    382.0
# 0            accuracy          -          -  53.271569   5181.0
# 1           macro avg  38.831892  41.375937   0.370974   5181.0
# 2        weighted avg  55.855561  53.271569   0.535413   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  29.411765  26.315789   0.277778     38.0
# 1         Attribution  31.782946  44.086022   0.369369    372.0
# 2            Location  44.983819  58.649789   0.509158    474.0
# 3               State  15.384615  33.333333   0.210526      6.0
# 4              System  35.606061  19.341564   0.250667    243.0
# 5               Shape  50.434783  30.366492   0.379085    191.0
# 6            Material  50.125945  62.974684   0.558205    316.0
# 7      AnnotatorNotes        5.0  33.333333   0.086957      3.0
# 8   ScientificConcept  20.054945   40.10989   0.267399    182.0
# 9              Effect  48.888889  33.716475   0.399093    261.0
# 10        Consequence  25.641026  45.454545   0.327869     22.0
# 11           Function  35.714286   23.88535    0.28626    314.0
# 12        PhysicsFlow       40.0  35.714286   0.377358     28.0
# 13           InfoFlow  80.701754  51.685393   0.630137     89.0
# 14          Component   71.10812  72.045455   0.715737   2200.0
# 15              Value  20.689655       50.0   0.292683     60.0
# 16         EnergyFlow  48.253968  39.790576   0.436155    382.0
# 0            accuracy          -          -  54.584057   5181.0
# 1           macro avg  38.457799  41.223705   0.374967   5181.0
# 2        weighted avg  54.255696  54.584057   0.535786   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  18.367347  23.684211   0.206897     38.0
# 1         Attribution   29.90991  44.623656   0.358145    372.0
# 2            Location  40.612517  64.345992   0.497959    474.0
# 3               State       10.0  33.333333   0.153846      6.0
# 4              System  30.290456  30.041152   0.301653    243.0
# 5               Shape  53.333333  33.507853   0.411576    191.0
# 6            Material   54.64191  65.189873   0.594517    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept  22.841226  45.054945   0.303142    182.0
# 9              Effect  47.297297  40.229885   0.434783    261.0
# 10        Consequence  30.769231  36.363636   0.333333     22.0
# 11           Function  35.371179  25.796178   0.298343    314.0
# 12        PhysicsFlow  57.142857  28.571429   0.380952     28.0
# 13           InfoFlow  81.428571  64.044944   0.716981     89.0
# 14          Component  73.221757  71.590909   0.723972   2200.0
# 15              Value  31.428571       55.0        0.4     60.0
# 16         EnergyFlow  52.559727  40.314136   0.456296    382.0
# 0            accuracy          -          -  56.514186   5181.0
# 1           macro avg  39.365641  41.276008   0.386611   5181.0
# 2        weighted avg  55.227288  56.514186   0.550668   5181.0

# %% [markdown]
# ### stratified, td-idf_half

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure   9.302326  10.526316   0.098765     38.0
# 1         Attribution  17.021277  19.354839   0.181132    372.0
# 2            Location  30.721649  31.434599    0.31074    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System  22.222222   4.938272   0.080808    243.0
# 5               Shape  19.607843  15.706806   0.174419    191.0
# 6            Material  32.167832  43.670886    0.37047    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept   8.548708  23.626374   0.125547    182.0
# 9              Effect  21.367521   9.578544   0.132275    261.0
# 10        Consequence   8.695652   9.090909   0.088889     22.0
# 11           Function  19.587629   6.050955   0.092457    314.0
# 12        PhysicsFlow        0.0        0.0        0.0     28.0
# 13           InfoFlow        0.0        0.0        0.0     89.0
# 14          Component  62.803819  65.772727    0.64254   2200.0
# 15              Value   6.329114       25.0    0.10101     60.0
# 16         EnergyFlow  33.217993   25.13089    0.28614    382.0
# 0            accuracy          -          -  39.606254   5181.0
# 1           macro avg  17.152564  17.051889   0.157953   5181.0
# 2        weighted avg  39.619693  39.606254   0.387137   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  13.235294  23.684211   0.169811     38.0
# 1         Attribution  15.178571   18.27957   0.165854    372.0
# 2            Location  29.674099   36.49789   0.327342    474.0
# 3               State        0.0        0.0        0.0      6.0
# 4              System       6.25   2.057613    0.03096    243.0
# 5               Shape  27.083333  20.418848   0.232836    191.0
# 6            Material  38.975501  55.379747   0.457516    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept   6.866953  17.582418   0.098765    182.0
# 9              Effect    26.5625   13.02682   0.174807    261.0
# 10        Consequence  14.285714  18.181818       0.16     22.0
# 11           Function   27.39726  12.738854   0.173913    314.0
# 12        PhysicsFlow        0.0        0.0        0.0     28.0
# 13           InfoFlow  22.222222   2.247191   0.040816     89.0
# 14          Component  64.970995  66.181818   0.655708   2200.0
# 15              Value   6.735751  21.666667   0.102767     60.0
# 16         EnergyFlow  35.376045  33.246073    0.34278    382.0
# 0            accuracy          -          -  42.018915   5181.0
# 1           macro avg  19.694955  20.069973   0.184346   5181.0
# 2        weighted avg  41.527543  42.018915   0.410135   5181.0

# %%
with open("formal_eva_results_llama2chat7b/thf_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Measure', 'Attribution', 'Location', 'State', 'System', 'Shape', 'Material', 'AnnotatorNotes', 'ScientificConcept', 'Effect', 'Consequence', 'Function', 'PhysicsFlow', 'InfoFlow', 'Component', 'Value', 'EnergyFlow']
#                entity  precision     recall   F1 score  support
# 0             Measure  22.857143  42.105263   0.296296     38.0
# 1         Attribution  17.833333  28.763441   0.220165    372.0
# 2            Location  32.591415  43.248945   0.371714    474.0
# 3               State  18.181818  33.333333   0.235294      6.0
# 4              System   17.34104  12.345679   0.144231    243.0
# 5               Shape  31.788079   25.13089   0.280702    191.0
# 6            Material  40.088106  57.594937   0.472727    316.0
# 7      AnnotatorNotes        0.0        0.0        0.0      3.0
# 8   ScientificConcept   9.684685  23.626374    0.13738    182.0
# 9              Effect       25.0  17.624521   0.206742    261.0
# 10        Consequence  14.285714  18.181818       0.16     22.0
# 11           Function  31.097561  16.242038   0.213389    314.0
# 12        PhysicsFlow   4.545455   3.571429       0.04     28.0
# 13           InfoFlow       40.0   8.988764   0.146789     89.0
# 14          Component  66.055886  65.545455   0.657997   2200.0
# 15              Value  10.852713  23.333333   0.148148     60.0
# 16         EnergyFlow  39.393939  27.225131   0.321981    382.0
# 0            accuracy          -          -  44.450878   5181.0
# 1           macro avg  24.799817  26.285962   0.238444   5181.0
# 2        weighted avg  44.217262  44.450878   0.434657   5181.0

# %% [markdown]
# # Assembly

# %%
with open("data/immutable_data_formal/sen_assembly_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_assembly_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### zero-shot

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
print(response[10])    
response = process_response(response)   
print(response[10])    
response = process_response_zero_shot(response)   
print(response[10])    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [{'generated_text': '\n* entity type: PART (align nuts, engine body, woodruff, lug washer, shims)\n* entity type: RPOS (aligned, on, using)\n* entity type: OPER (recheck, test)\n* entity type: TOOL (Secure, direct)\n* entity type: ID (1948791)\n* entity type: QTY (3)\n* entity type: DIM (Bearing, gear)\n* entity type: WGT (Bearings)\n* entity type: PROP (Secure, direct)\n\nNote: The extracted entities are in the format of "entity type: extracted words".'}]
#
# entity type: PART (align nuts, engine body, woodruff, lug washer, shims)
# entity type: RPOS (aligned, on, using)
# entity type: OPER (recheck, test)
# entity type: TOOL (Secure, direct)
# entity type: ID (1948791)
# entity type: QTY (3)
# entity type: DIM (Bearing, gear)
# entity type: WGT (Bearings)
# entity type: PROP (Secure, direct)
# :
# PART (align nuts: entity type
# engine body: entity type
# woodruff: entity type
# lug washer: entity type
# shims): entity type
# RPOS (aligned: entity type
# on: entity type
# using): entity type
# OPER (recheck: entity type
# test): entity type
# TOOL (Secure: entity type
# direct): entity type
# ID (1948791): entity type
# QTY (3): entity type
# DIM (Bearing: entity type
# gear): entity type
# WGT (Bearings): entity type
# PROP (Secure: entity type
# direct): entity type
#
# ['RPOS', 'ID', 'OPER', 'QTY', 'PART', 'TOOL', 'WGT', 'PROP', 'DIM']
#          entity  precision     recall   F1 score  support
# 0          RPOS   20.81448   9.465021   0.130127    486.0
# 1            ID   4.511278   9.230769   0.060606     65.0
# 2          OPER   22.95082   8.015267   0.118812    524.0
# 3           QTY        0.0        0.0        0.0     61.0
# 4          PART  59.296482  11.400966   0.191248   2070.0
# 5          TOOL   4.285714   8.333333   0.056604     72.0
# 6           WGT        0.0        0.0        0.0      2.0
# 7          PROP   1.111111   3.636364   0.017021     55.0
# 8           DIM   1.754386   2.857143   0.021739     35.0
# 0      accuracy          -          -  10.059347   3370.0
# 1     macro avg  12.747141   5.882096    0.06624   3370.0
# 2  weighted avg  43.207746  10.059347   0.157595   3370.0

# %% [markdown]
# ### not stratified, random

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_1_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PART', 'TOOL', 'RPOS', 'OPER', 'WGT', 'ID', 'DIM', 'QTY', 'PROP']
#          entity  precision     recall  F1 score  support
# 0          PART  60.235507  64.251208  0.621786   2070.0
# 1          TOOL  23.333333   9.722222  0.137255     72.0
# 2          RPOS  25.096525  13.374486  0.174497    486.0
# 3          OPER  17.681159  58.206107  0.271232    524.0
# 4           WGT        0.0        0.0       0.0      2.0
# 5            ID   3.366337  52.307692  0.063256     65.0
# 6           DIM  18.518519  28.571429  0.224719     35.0
# 7           QTY   4.731861  24.590164  0.079365     61.0
# 8          PROP    3.34728  14.545455  0.054422     55.0
# 0      accuracy          -          -  52.64095   3370.0
# 1     macro avg  17.367836   29.50764  0.180726   3370.0
# 2  weighted avg  44.263811   52.64095  0.458077   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   3.333333   3.636364   0.034783     55.0
# 1           QTY   7.741935  39.344262    0.12938     61.0
# 2           DIM  28.571429  11.428571   0.163265     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  23.347107  64.694656   0.343117    524.0
# 5          TOOL       28.0  19.444444   0.229508     72.0
# 6            ID       12.5  35.384615   0.184739     65.0
# 7          PART  58.109118  75.120773   0.655289   2070.0
# 8          RPOS  23.932584   43.82716   0.309593    486.0
# 0      accuracy          -          -  64.510386   3370.0
# 1     macro avg  20.615056  32.542316   0.227742   3370.0
# 2  weighted avg  44.105367  64.510386   0.513577   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP    4.45269  43.636364   0.080808     55.0
# 1           QTY       12.5  44.262295   0.194946     61.0
# 2           DIM   5.531915  37.142857   0.096296     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  33.796791  60.305344   0.433173    524.0
# 5          TOOL  28.169014  27.777778    0.27972     72.0
# 6            ID  21.192053  49.230769   0.296296     65.0
# 7          PART  71.282799  70.869565   0.710756   2070.0
# 8          RPOS  26.126126  71.604938   0.382838    486.0
# 0      accuracy          -          -  66.676558   3370.0
# 1     macro avg  22.561265  44.981101   0.274982   3370.0
# 2  weighted avg  54.174741  66.676558    0.57668   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall  F1 score  support
# 0          PROP   8.116883  45.454545  0.137741     55.0
# 1           QTY   13.58885  63.934426  0.224138     61.0
# 2           DIM   5.882353       40.0  0.102564     35.0
# 3           WGT        0.0        0.0       0.0      2.0
# 4          OPER  31.205036  66.221374  0.424205    524.0
# 5          TOOL  28.767123  29.166667  0.289655     72.0
# 6            ID  26.829268  33.846154   0.29932     65.0
# 7          PART  70.741758  74.637681  0.726375   2070.0
# 8          RPOS  32.336449  71.193416   0.44473    486.0
# 0      accuracy          -          -      70.0   3370.0
# 1     macro avg   24.16308  47.161585  0.294303   3370.0
# 2  weighted avg  54.539691       70.0  0.595599   3370.0

# %% [markdown]
# ### stratified, random

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   4.166667   5.454545   0.047244     55.0
# 1           QTY   7.692308  36.065574   0.126801     61.0
# 2           DIM  42.857143   8.571429   0.142857     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER   31.96347  40.076336   0.355631    524.0
# 5          TOOL      100.0   4.166667       0.08     72.0
# 6            ID   8.196721  46.153846   0.139211     65.0
# 7          PART  73.759591  69.661836   0.716522   2070.0
# 8          RPOS  35.778175  41.152263   0.382775    486.0
# 0      accuracy          -          -  56.765579   3370.0
# 1     macro avg  33.823786    27.9225   0.221227   3370.0
# 2  weighted avg  58.382964  56.765579   0.559561   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   3.667954  34.545455   0.066318     55.0
# 1           QTY  16.447368  40.983607   0.234742     61.0
# 2           DIM        0.0        0.0        0.0     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  34.384858   62.40458    0.44339    524.0
# 5          TOOL   8.823529       25.0   0.130435     72.0
# 6            ID   6.879195  63.076923   0.124054     65.0
# 7          PART  75.414365  65.942029   0.703608   2070.0
# 8          RPOS  29.135338  63.786008        0.4    486.0
# 0      accuracy          -          -  62.462908   3370.0
# 1     macro avg  19.416956  39.526511   0.233616   3370.0
# 2  weighted avg  56.549746  62.462908   0.569325   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   8.445946  45.454545    0.14245     55.0
# 1           QTY   26.88172  40.983607   0.324675     61.0
# 2           DIM   4.878049  51.428571   0.089109     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  29.737081   62.59542   0.403196    524.0
# 5          TOOL  20.547945  20.833333   0.206897     72.0
# 6            ID  13.758389  63.076923   0.225895     65.0
# 7          PART  65.384615    74.7343   0.697475   2070.0
# 8          RPOS  30.494505  68.518519   0.422053    486.0
# 0      accuracy          -          -  69.198813   3370.0
# 1     macro avg  22.236472  47.513913   0.279083   3370.0
# 2  weighted avg  50.563058  69.198813   0.569883   3370.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_1_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PART', 'TOOL', 'RPOS', 'OPER', 'WGT', 'ID', 'DIM', 'QTY', 'PROP']
#          entity  precision     recall   F1 score  support
# 0          PART  78.236131  79.710145   0.789663   2070.0
# 1          TOOL  45.333333  47.222222   0.462585     72.0
# 2          RPOS  35.560345  67.901235   0.466761    486.0
# 3          OPER  40.529101  73.091603   0.521443    524.0
# 4           WGT       50.0       50.0        0.5      2.0
# 5            ID  13.576159  63.076923   0.223433     65.0
# 6           DIM  27.692308  51.428571       0.36     35.0
# 7           QTY       12.5  55.737705   0.204204     61.0
# 8          PROP  15.384615  61.818182   0.246377     55.0
# 0      accuracy          -          -  74.925816   3370.0
# 1     macro avg  35.423555  61.109621   0.419385   3370.0
# 2  weighted avg  61.511188  74.925816   0.659383   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  14.814815  58.181818   0.236162     55.0
# 1           QTY   18.40796  60.655738   0.282443     61.0
# 2           DIM  26.388889  54.285714    0.35514     35.0
# 3           WGT       40.0      100.0   0.571429      2.0
# 4          OPER  45.373467  77.671756   0.572836    524.0
# 5          TOOL  61.290323  52.777778   0.567164     72.0
# 6            ID   23.93617  69.230769   0.355731     65.0
# 7          PART  76.923077  84.541063   0.805524   2070.0
# 8          RPOS  35.864593  80.658436   0.496517    486.0
# 0      accuracy          -          -  80.771513   3370.0
# 1     macro avg  38.111033   70.88923   0.471438   3370.0
# 2  weighted avg   62.12069  80.771513   0.687435   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  19.631902  58.181818   0.293578     55.0
# 1           QTY   17.61658  55.737705   0.267717     61.0
# 2           DIM  21.176471  51.428571        0.3     35.0
# 3           WGT  28.571429      100.0   0.444444      2.0
# 4          OPER  48.387097  74.427481   0.586466    524.0
# 5          TOOL  66.037736  48.611111       0.56     72.0
# 6            ID  23.952096  61.538462   0.344828     65.0
# 7          PART  73.277311  84.251208    0.78382   2070.0
# 8          RPOS  33.991416  81.481481   0.479709    486.0
# 0      accuracy          -          -  79.851632   3370.0
# 1     macro avg  36.960226  68.406426   0.451174   3370.0
# 2  weighted avg  60.184863  79.851632   0.673458   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  22.222222  58.181818   0.321608     55.0
# 1           QTY  21.604938  57.377049   0.313901     61.0
# 2           DIM   9.482759  31.428571   0.145695     35.0
# 3           WGT       25.0       50.0   0.333333      2.0
# 4          OPER  41.685912   68.89313   0.519424    524.0
# 5          TOOL   61.22449  41.666667   0.495868     72.0
# 6            ID  21.348315  58.461538   0.312757     65.0
# 7          PART  67.030303  80.144928   0.730033   2070.0
# 8          RPOS  30.620805  75.102881   0.435042    486.0
# 0      accuracy          -          -  75.133531   3370.0
# 1     macro avg  33.357749  57.917398   0.400851   3370.0
# 2  weighted avg  54.657472  75.133531    0.62119   3370.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   6.439394  30.909091   0.106583     55.0
# 1           QTY   13.22314  26.229508   0.175824     61.0
# 2           DIM   6.896552  28.571429   0.111111     35.0
# 3           WGT   4.166667       50.0   0.076923      2.0
# 4          OPER  36.267232  65.267176   0.466258    524.0
# 5          TOOL  26.415094  19.444444      0.224     72.0
# 6            ID   16.35514  53.846154   0.250896     65.0
# 7          PART  71.015843  73.623188    0.72296   2070.0
# 8          RPOS  23.690383  62.345679   0.343343    486.0
# 0      accuracy          -          -  67.121662   3370.0
# 1     macro avg  22.718827  45.581852   0.275322   3370.0
# 2  weighted avg  53.975019  67.121662   0.581833   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   9.615385  18.181818   0.125786     55.0
# 1           QTY  19.266055   34.42623   0.247059     61.0
# 2           DIM    6.27451  45.714286   0.110345     35.0
# 3           WGT  16.666667       50.0       0.25      2.0
# 4          OPER  35.918367  67.175573   0.468085    524.0
# 5          TOOL  39.344262  33.333333   0.360902     72.0
# 6            ID  22.222222  61.538462   0.326531     65.0
# 7          PART  67.575628  76.618357   0.718134   2070.0
# 8          RPOS  24.081633  72.839506   0.361963    486.0
# 0      accuracy          -          -  71.335312   3370.0
# 1     macro avg  26.773859  51.091952   0.329867   3370.0
# 2  weighted avg  52.415637  71.335312    0.58792   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  11.111111  29.090909   0.160804     55.0
# 1           QTY  24.561404  45.901639       0.32     61.0
# 2           DIM   4.511278  51.428571   0.082949     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  33.211009  69.083969   0.448575    524.0
# 5          TOOL  45.454545  34.722222   0.393701     72.0
# 6            ID  21.052632  55.384615   0.305085     65.0
# 7          PART  67.988065   77.05314   0.722373   2070.0
# 8          RPOS  29.474548  73.868313   0.421362    486.0
# 0      accuracy          -          -  72.373887   3370.0
# 1     macro avg  26.373844  48.503709   0.317205   3370.0
# 2  weighted avg  53.225784  72.373887   0.597802   3370.0

# %% [markdown]
# ### not stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_1_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PART', 'TOOL', 'RPOS', 'OPER', 'WGT', 'ID', 'DIM', 'QTY', 'PROP']
#          entity  precision     recall   F1 score  support
# 0          PART  77.538769  74.879227   0.761858   2070.0
# 1          TOOL  57.407407  43.055556   0.492063     72.0
# 2          RPOS  40.926641  65.432099   0.503563    486.0
# 3          OPER  38.643703   68.51145    0.49415    524.0
# 4           WGT       25.0       50.0   0.333333      2.0
# 5            ID   9.898477       60.0   0.169935     65.0
# 6           DIM  45.652174       60.0   0.518519     35.0
# 7           QTY  12.915129  57.377049   0.210843     61.0
# 8          PROP  17.894737  61.818182   0.277551     55.0
# 0      accuracy          -          -  70.860534   3370.0
# 1     macro avg   36.20856  60.119285   0.417979   3370.0
# 2  weighted avg   61.97077  70.860534   0.645142   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  20.731707  61.818182   0.310502     55.0
# 1           QTY  21.621622   65.57377   0.325203     61.0
# 2           DIM  26.744186  65.714286   0.380165     35.0
# 3           WGT       25.0      100.0        0.4      2.0
# 4          OPER  44.506726  75.763359   0.560734    524.0
# 5          TOOL  63.934426  54.166667   0.586466     72.0
# 6            ID  25.454545  64.615385   0.365217     65.0
# 7          PART  77.713523  84.396135   0.809171   2070.0
# 8          RPOS   37.31919   79.62963   0.508207    486.0
# 0      accuracy          -          -  80.445104   3370.0
# 1     macro avg  38.113992  72.408601   0.471741   3370.0
# 2  weighted avg  62.916521  80.445104    0.69222   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  23.295455  74.545455   0.354978     55.0
# 1           QTY  19.607843   65.57377   0.301887     61.0
# 2           DIM     21.875       60.0   0.320611     35.0
# 3           WGT       40.0      100.0   0.571429      2.0
# 4          OPER  46.791132  76.526718   0.580739    524.0
# 5          TOOL  58.461538  52.777778   0.554745     72.0
# 6            ID  24.561404  64.615385   0.355932     65.0
# 7          PART  74.785959  84.396135    0.79301   2070.0
# 8          RPOS  36.053812  82.716049   0.502186    486.0
# 0      accuracy          -          -  81.127596   3370.0
# 1     macro avg  38.381349  73.461254   0.481724   3370.0
# 2  weighted avg  61.120569  81.127596   0.683466   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  25.490196  70.909091      0.375     55.0
# 1           QTY       20.0  57.377049    0.29661     61.0
# 2           DIM  11.111111  51.428571   0.182741     35.0
# 3           WGT  28.571429      100.0   0.444444      2.0
# 4          OPER   43.91657  72.328244   0.546503    524.0
# 5          TOOL  62.068966       50.0   0.553846     72.0
# 6            ID  25.925926  64.615385   0.370044     65.0
# 7          PART  72.809668  81.497585    0.76909   2070.0
# 8          RPOS  32.835821  76.954733   0.460308    486.0
# 0      accuracy          -          -  77.507418   3370.0
# 1     macro avg  35.858854   69.45674   0.444287   3370.0
# 2  weighted avg  59.023337  77.507418   0.656388   3370.0

# %% [markdown]
# ### stratified, tf-idf

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   3.726708  21.818182    0.06366     55.0
# 1           QTY  17.518248  39.344262   0.242424     61.0
# 2           DIM        5.0  17.142857   0.077419     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  33.006856  64.312977   0.436246    524.0
# 5          TOOL  16.949153  13.888889   0.152672     72.0
# 6            ID  11.926606       60.0    0.19898     65.0
# 7          PART  72.222222  69.710145    0.70944   2070.0
# 8          RPOS  26.941748  68.518519    0.38676    486.0
# 0      accuracy          -          -  65.400593   3370.0
# 1     macro avg  20.810171  39.415092   0.251956   3370.0
# 2  weighted avg  54.401612  65.400593   0.572707   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  10.067114  27.272727   0.147059     55.0
# 1           QTY  14.379085  36.065574   0.205607     61.0
# 2           DIM   7.174888  45.714286   0.124031     35.0
# 3           WGT  14.285714       50.0   0.222222      2.0
# 4          OPER  35.043562  69.083969   0.464997    524.0
# 5          TOOL  29.850746  27.777778    0.28777     72.0
# 6            ID  20.183486  67.692308   0.310954     65.0
# 7          PART  68.310781  75.603865   0.717725   2070.0
# 8          RPOS  25.520111  75.720165   0.381743    486.0
# 0      accuracy          -          -  71.602374   3370.0
# 1     macro avg  24.979499  52.770075   0.318012   3370.0
# 2  weighted avg  52.623325  71.602374     0.5879   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  11.979167  41.818182   0.186235     55.0
# 1           QTY  21.481481  47.540984   0.295918     61.0
# 2           DIM   5.341246  51.428571   0.096774     35.0
# 3           WGT       20.0       50.0   0.285714      2.0
# 4          OPER  36.877395  73.473282   0.491071    524.0
# 5          TOOL  47.058824  44.444444   0.457143     72.0
# 6            ID  24.691358  61.538462   0.352423     65.0
# 7          PART  68.938127  79.661836    0.73913   2070.0
# 8          RPOS  31.880342  76.748971   0.450483    486.0
# 0      accuracy          -          -  75.667656   3370.0
# 1     macro avg  29.805327  58.517192   0.372766   3370.0
# 2  weighted avg  54.809752  75.667656   0.621463   3370.0

# %% [markdown]
# ### not stratified, tf-idf_half

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  20.915033  58.181818   0.307692     55.0
# 1           QTY  17.910448  59.016393   0.274809     61.0
# 2           DIM  30.555556  62.857143   0.411215     35.0
# 3           WGT       40.0      100.0   0.571429      2.0
# 4          OPER  42.796158  76.526718   0.548939    524.0
# 5          TOOL  59.090909  54.166667   0.565217     72.0
# 6            ID   25.65445  75.384615   0.382812     65.0
# 7          PART   78.74265   84.10628   0.813361   2070.0
# 8          RPOS  39.406346  79.218107   0.526316    486.0
# 0      accuracy          -          -  80.326409   3370.0
# 1     macro avg  39.452394  72.161971   0.489088   3370.0
# 2  weighted avg  63.468353  80.326409   0.694923   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP  18.324607  63.636364   0.284553     55.0
# 1           QTY  16.883117  63.934426   0.267123     61.0
# 2           DIM  26.436782  65.714286   0.377049     35.0
# 3           WGT       25.0      100.0        0.4      2.0
# 4          OPER  45.679012  77.671756   0.575265    524.0
# 5          TOOL  48.717949  52.777778   0.506667     72.0
# 6            ID       21.5  66.153846   0.324528     65.0
# 7          PART  74.529915  84.251208    0.79093   2070.0
# 8          RPOS   36.70412  80.658436   0.504505    486.0
# 0      accuracy          -          -  80.801187   3370.0
# 1     macro avg  34.863945  72.755344   0.447847   3370.0
# 2  weighted avg  60.524965  80.801187   0.678744   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall  F1 score  support
# 0          PROP  25.170068  67.272727  0.366337     55.0
# 1           QTY  19.101124  55.737705  0.284519     61.0
# 2           DIM  17.857143  57.142857  0.272109     35.0
# 3           WGT  33.333333      100.0       0.5      2.0
# 4          OPER  44.562648  71.946565  0.550365    524.0
# 5          TOOL  66.666667  58.333333  0.622222     72.0
# 6            ID  23.280423  67.692308  0.346457     65.0
# 7          PART  70.695505  80.531401  0.752936   2070.0
# 8          RPOS  34.688347  79.012346  0.482109    486.0
# 0      accuracy          -          -  77.35905   3370.0
# 1     macro avg  37.261695  70.852138  0.464117   3370.0
# 2  weighted avg  58.190942   77.35905  0.651816   3370.0

# %% [markdown]
# ### stratified, tf-idf_half

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall  F1 score  support
# 0          PROP   4.279279  34.545455  0.076152     55.0
# 1           QTY  11.229947   34.42623  0.169355     61.0
# 2           DIM   8.108108  17.142857  0.110092     35.0
# 3           WGT       10.0       50.0  0.166667      2.0
# 4          OPER  30.694981  60.687023  0.407692    524.0
# 5          TOOL  14.545455  11.111111  0.125984     72.0
# 6            ID   7.207207  49.230769  0.125737     65.0
# 7          PART  68.734734  67.971014  0.683507   2070.0
# 8          RPOS  22.464899  59.259259  0.325792    486.0
# 0      accuracy          -          -  62.31454   3370.0
# 1     macro avg  19.696068  42.708191  0.243442   3370.0
# 2  weighted avg  51.045377   62.31454  0.540883   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall  F1 score  support
# 0          PROP   4.529617  23.636364  0.076023     55.0
# 1           QTY  10.047847   34.42623  0.155556     61.0
# 2           DIM   7.317073  17.142857  0.102564     35.0
# 3           WGT        0.0        0.0       0.0      2.0
# 4          OPER  31.959799  60.687023  0.418697    524.0
# 5          TOOL  12.658228  13.888889   0.13245     72.0
# 6            ID   9.667674  49.230769  0.161616     65.0
# 7          PART  68.031643  70.628019  0.693055   2070.0
# 8          RPOS  24.700599  67.901235  0.362239    486.0
# 0      accuracy          -          -  65.04451   3370.0
# 1     macro avg  18.768053  37.504598  0.233578   3370.0
# 2  weighted avg  51.108268   65.04451  0.554116   3370.0

# %%
with open("formal_eva_results_llama2chat7b/assembly_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PROP', 'QTY', 'DIM', 'WGT', 'OPER', 'TOOL', 'ID', 'PART', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0          PROP   5.164319       20.0    0.08209     55.0
# 1           QTY   9.734513  36.065574    0.15331     61.0
# 2           DIM   7.575758  28.571429    0.11976     35.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  31.894934  64.885496   0.427673    524.0
# 5          TOOL  15.873016  13.888889   0.148148     72.0
# 6            ID   9.939759  50.769231   0.166247     65.0
# 7          PART  66.264522  71.642512   0.688487   2070.0
# 8          RPOS   24.60733  67.695473   0.360943    486.0
# 0      accuracy          -          -  66.409496   3370.0
# 1     macro avg  19.006017  39.279845   0.238518   3370.0
# 2  weighted avg  50.080595  66.409496    0.55318   3370.0

# %% [markdown]
# # Fabner

# %%
with open("data/immutable_data_formal/sen_fabner_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %% [markdown]
# ### zero-shot

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
print(response[10])    
response = process_response(response)   
print(response[10])    
response = process_response_zero_shot(response)   
print(response[10])    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# [{'generated_text': 'Extracted words: entity types \nfiber orientation \ntextured \nfiber-debonding \npullout phenomenon \nsurfaces \nSEM images \nsurface roughness \n\nPlease provide the extracted entities for the given input sentence.'}]
# Extracted words: entity types
# fiber orientation
# textured
# fiber-debonding
# pullout phenomenon
# surfaces
# SEM images
# surface roughness
# entity types : Extracted words
# fiber orientation : fiber orientation
# textured : textured
# fiber-debonding : fiber-debonding
# pullout phenomenon : pullout phenomenon
# surfaces : surfaces
# SEM images : SEM images
# surface roughness : surface roughness
#
# ['ENAT', 'PARA', 'CONPRI', 'PRO', 'MANP', 'BIOP', 'APPL', 'MANS', 'CHAR', 'MATE', 'MACEQ', 'FEAT']
#           entity  precision    recall  F1 score  support
# 0           ENAT   4.545455  5.769231  0.050847     52.0
# 1           PARA        8.0  4.102564  0.054237    195.0
# 2         CONPRI  13.084112  1.495726  0.026846    936.0
# 3            PRO        8.0  1.895735  0.030651    211.0
# 4           MANP  18.181818   1.40647   0.02611    711.0
# 5           BIOP        0.0       0.0       0.0      9.0
# 6           APPL   2.702703  1.111111  0.015748     90.0
# 7           MANS        0.0       0.0       0.0      4.0
# 8           CHAR        0.0       0.0       0.0    195.0
# 9           MATE  17.346939  3.136531  0.053125    542.0
# 10         MACEQ   7.462687  3.937008  0.051546    127.0
# 11          FEAT   3.448276   1.30719  0.018957    153.0
# 0       accuracy          -         -  1.984496   3225.0
# 1      macro avg   6.897666  2.013464  0.027339   3225.0
# 2   weighted avg  12.334573  1.984496   0.03195   3225.0

# %% [markdown]
# ### not stratified, random

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_1_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO   15.36643  30.805687   0.205047    211.0
# 1           PARA   13.44086  51.282051   0.212993    195.0
# 2          MACEQ   5.025126   7.874016    0.06135    127.0
# 3           MATE   32.66129  14.944649   0.205063    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS    0.19305       25.0   0.003831      4.0
# 6           CHAR   4.664723   8.205128    0.05948    195.0
# 7           MANP  23.046489  32.770745   0.270616    711.0
# 8           FEAT   2.758621   2.614379   0.026846    153.0
# 9         CONPRI  23.076923   9.935897    0.13891    936.0
# 10          ENAT   1.111111   1.923077   0.014085     52.0
# 11          APPL  12.631579  13.333333    0.12973     90.0
# 0       accuracy          -          -  19.100775   3225.0
# 1      macro avg  11.164684  16.557414   0.110662   3225.0
# 2   weighted avg  20.067296  19.100775   0.171873   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  16.689655  57.345972   0.258547    211.0
# 1           PARA       25.0  13.846154   0.178218    195.0
# 2          MACEQ        7.2  14.173228   0.095491    127.0
# 3           MATE  26.047904  48.154982   0.338083    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS        0.0        0.0        0.0      4.0
# 6           CHAR  30.456853  30.769231   0.306122    195.0
# 7           MANP  37.762238   45.56962   0.413002    711.0
# 8           FEAT   6.109822  51.633987   0.109267    153.0
# 9         CONPRI  19.725557  12.286325   0.151415    936.0
# 10          ENAT        0.0        0.0        0.0     52.0
# 11          APPL        0.0        0.0        0.0     90.0
# 0       accuracy          -          -  31.162791   3225.0
# 1      macro avg  14.082669  22.814958   0.154179   3225.0
# 2   weighted avg  23.446463  31.162791   0.246963   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  16.447368  71.090047   0.267142    211.0
# 1           PARA  19.814241  32.820513   0.247104    195.0
# 2          MACEQ   9.253731  24.409449   0.134199    127.0
# 3           MATE  23.475046  46.863469   0.312808    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS        0.0        0.0        0.0      4.0
# 6           CHAR  57.657658  32.820513   0.418301    195.0
# 7           MANP  36.162988  29.957806   0.327692    711.0
# 8           FEAT  12.559242  34.640523   0.184348    153.0
# 9         CONPRI  19.956379  19.551282   0.197518    936.0
# 10          ENAT        0.0        0.0        0.0     52.0
# 11          APPL        0.0        0.0        0.0     90.0
# 0       accuracy          -          -  31.379845   3225.0
# 1      macro avg  16.277221  24.346133   0.174093   3225.0
# 2   weighted avg  24.430615  31.379845   0.253884   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  13.545455  70.616114   0.227307    211.0
# 1           PARA  22.181818  31.282051   0.259574    195.0
# 2          MACEQ  16.190476  26.771654    0.20178    127.0
# 3           MATE  29.172511  38.376384   0.331474    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS        0.0        0.0        0.0      4.0
# 6           CHAR  57.142857  30.769231        0.4    195.0
# 7           MANP  47.377939  36.849508   0.414557    711.0
# 8           FEAT    9.70266  40.522876   0.156566    153.0
# 9         CONPRI  22.421525  16.025641   0.186916    936.0
# 10          ENAT  16.666667   5.769231   0.085714     52.0
# 11          APPL  20.833333  11.111111   0.144928     90.0
# 0       accuracy          -          -  30.976744   3225.0
# 1      macro avg  21.269603  25.674483   0.200735   3225.0
# 2   weighted avg  29.486055  30.976744   0.276906   3225.0

# %% [markdown]
# ### stratified, random

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_5_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  25.714286   4.265403   0.073171    211.0
# 1           PARA  14.007782  55.384615   0.223602    195.0
# 2          MACEQ  16.513761  14.173228   0.152542    127.0
# 3           MATE  22.026432  18.450185   0.200803    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS   0.328407       50.0   0.006525      4.0
# 6           CHAR        0.0        0.0        0.0    195.0
# 7           MANP  47.584973  37.412096   0.418898    711.0
# 8           FEAT    7.81893  24.836601   0.118936    153.0
# 9         CONPRI   19.42029  28.632479   0.231434    936.0
# 10          ENAT   8.333333  17.307692     0.1125     52.0
# 11          APPL       25.0   4.444444   0.075472     90.0
# 0       accuracy          -          -  25.488372   3225.0
# 1      macro avg   15.56235  21.242229    0.13449   3225.0
# 2   weighted avg   24.21211  25.488372   0.227155   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_10_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO        0.0        0.0        0.0    211.0
# 1           PARA   14.46384  59.487179   0.232698    195.0
# 2          MACEQ  16.923077  17.322835   0.171206    127.0
# 3           MATE  31.589147  30.073801   0.308129    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS   0.468384       50.0   0.009281      4.0
# 6           CHAR  18.543046  14.358974    0.16185    195.0
# 7           MANP  43.953488  26.582278   0.331288    711.0
# 8           FEAT   6.207827  30.065359   0.102908    153.0
# 9         CONPRI  25.504152  22.970085   0.241709    936.0
# 10          ENAT   7.758621  17.307692   0.107143     52.0
# 11          APPL  17.204301  17.777778   0.174863     90.0
# 0       accuracy          -          -  24.992248   3225.0
# 1      macro avg   15.21799  23.828832   0.153423   3225.0
# 2   weighted avg  25.963787  24.992248   0.237074   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_20_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  11.811024  78.199052   0.205224    211.0
# 1           PARA  28.181818  31.794872   0.298795    195.0
# 2          MACEQ   8.547009  15.748031   0.110803    127.0
# 3           MATE  32.923077  39.483395    0.35906    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS   0.719424       50.0   0.014184      4.0
# 6           CHAR  70.689655  21.025641   0.324111    195.0
# 7           MANP  59.082892  47.116737   0.524257    711.0
# 8           FEAT   6.908267  39.869281   0.117761    153.0
# 9         CONPRI  25.368732  18.376068   0.213135    936.0
# 10          ENAT     21.875  13.461538   0.166667     52.0
# 11          APPL  29.411765  16.666667   0.212766     90.0
# 0       accuracy          -          -  33.922481   3225.0
# 1      macro avg  24.626555   30.97844    0.21223   3225.0
# 2   weighted avg  34.511414  33.922481   0.307467   3225.0

# %% [markdown]
# ### not stratified, sentence

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_1_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall  F1 score  support
# 0            PRO  21.503132  48.815166  0.298551    211.0
# 1           PARA   16.27907  17.948718  0.170732    195.0
# 2          MACEQ  14.201183  18.897638  0.162162    127.0
# 3           MATE  31.428571  38.560886  0.346313    542.0
# 4           BIOP   7.692308  33.333333     0.125      9.0
# 5           MANS   0.184502       25.0  0.003663      4.0
# 6           CHAR  29.245283  15.897436   0.20598    195.0
# 7           MANP  39.156627  54.852321  0.456942    711.0
# 8           FEAT  12.244898  23.529412  0.161074    153.0
# 9         CONPRI   30.30303  18.162393  0.227121    936.0
# 10          ENAT  11.940299  30.769231  0.172043     52.0
# 11          APPL  11.290323  15.555556  0.130841     90.0
# 0       accuracy          -          -      32.0   3225.0
# 1      macro avg  18.789102  28.443507  0.205035   3225.0
# 2   weighted avg  28.538514       32.0  0.287977   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  20.474777  65.402844   0.311864    211.0
# 1           PARA  21.071429   30.25641   0.248421    195.0
# 2          MACEQ  16.033755   29.92126   0.208791    127.0
# 3           MATE  26.008065  47.601476   0.336375    542.0
# 4           BIOP  14.583333  77.777778   0.245614      9.0
# 5           MANS       1.25       50.0    0.02439      4.0
# 6           CHAR  61.764706  32.307692   0.424242    195.0
# 7           MANP  50.994152  61.322082   0.556833    711.0
# 8           FEAT  15.438596   28.75817   0.200913    153.0
# 9         CONPRI  32.220944   29.91453   0.310249    936.0
# 10          ENAT  27.868852  32.692308   0.300885     52.0
# 11          APPL   8.955224  13.333333   0.107143     90.0
# 0       accuracy          -          -  41.984496   3225.0
# 1      macro avg  24.721986  41.607324   0.272977   3225.0
# 2   weighted avg  33.418615  41.984496   0.356726   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  20.056101  67.772512   0.309524    211.0
# 1           PARA  20.845921  35.384615   0.262357    195.0
# 2          MACEQ  15.789474  33.070866    0.21374    127.0
# 3           MATE  27.799607  52.214022   0.362821    542.0
# 4           BIOP  10.169492  66.666667   0.176471      9.0
# 5           MANS   1.724138       25.0   0.032258      4.0
# 6           CHAR  73.033708  33.333333   0.457746    195.0
# 7           MANP  48.542601  60.900141   0.540237    711.0
# 8           FEAT  16.374269  36.601307   0.226263    153.0
# 9         CONPRI  30.395137  32.051282   0.312012    936.0
# 10          ENAT       30.0  34.615385   0.321429     52.0
# 11          APPL  13.333333       20.0       0.16     90.0
# 0       accuracy          -          -  44.465116   3225.0
# 1      macro avg  25.671982  41.467511   0.281238   3225.0
# 2   weighted avg  33.469252  44.465116    0.36376   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall  F1 score  support
# 0            PRO  18.833536  73.459716  0.299807    211.0
# 1           PARA  21.296296  35.384615  0.265896    195.0
# 2          MACEQ  18.245614  40.944882  0.252427    127.0
# 3           MATE  27.307692  52.398524  0.359039    542.0
# 4           BIOP  10.169492  66.666667  0.176471      9.0
# 5           MANS   3.278689       50.0  0.061538      4.0
# 6           CHAR  73.972603  27.692308  0.402985    195.0
# 7           MANP  54.929577  60.337553  0.575067    711.0
# 8           FEAT  14.412417   42.48366  0.215232    153.0
# 9         CONPRI  29.313725  31.944444  0.305726    936.0
# 10          ENAT   30.15873  36.538462  0.330435     52.0
# 11          APPL  19.512195  17.777778  0.186047     90.0
# 0       accuracy          -          -  44.96124   3225.0
# 1      macro avg  26.785881  44.635717  0.285889   3225.0
# 2   weighted avg  34.665408   44.96124  0.367154   3225.0

# %% [markdown]
# ### stratified, sentence

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_5_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  17.706821  57.819905   0.271111    211.0
# 1           PARA  18.066158  36.410256   0.241497    195.0
# 2          MACEQ    9.79021  22.047244   0.135593    127.0
# 3           MATE  21.871477  35.793358   0.271519    542.0
# 4           BIOP   1.298701  11.111111   0.023256      9.0
# 5           MANS   0.821918       75.0    0.01626      4.0
# 6           CHAR  48.780488   10.25641   0.169492    195.0
# 7           MANP  39.865622  50.070323    0.44389    711.0
# 8           FEAT  11.574074  16.339869   0.135501    153.0
# 9         CONPRI  22.883721  26.282051   0.244654    936.0
# 10          ENAT  10.169492  11.538462   0.108108     52.0
# 11          APPL       11.2  15.555556   0.130233     90.0
# 0       accuracy          -          -  33.674419   3225.0
# 1      macro avg  17.835723  30.685379   0.182593   3225.0
# 2   weighted avg  25.722535  33.674419    0.27432   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_10_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  17.262639  66.350711   0.273973    211.0
# 1           PARA  18.591549  33.846154       0.24    195.0
# 2          MACEQ  11.684783  33.858268   0.173737    127.0
# 3           MATE  25.810056  42.619926   0.321503    542.0
# 4           BIOP   3.225806  33.333333   0.058824      9.0
# 5           MANS   0.558659       25.0   0.010929      4.0
# 6           CHAR  70.967742  22.564103   0.342412    195.0
# 7           MANP  45.108005  49.929677   0.473965    711.0
# 8           FEAT  10.945274   28.75817   0.158559    153.0
# 9         CONPRI  23.495702  26.282051   0.248109    936.0
# 10          ENAT  12.903226   7.692308   0.096386     52.0
# 11          APPL  13.592233  15.555556   0.145078     90.0
# 0       accuracy          -          -  36.930233   3225.0
# 1      macro avg  21.178806  32.149188   0.211956   3225.0
# 2   weighted avg  29.222768  36.930233    0.30382   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_20_sentence.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  16.666667  69.194313   0.268629    211.0
# 1           PARA  23.333333  46.666667   0.311111    195.0
# 2          MACEQ  14.685315  33.070866    0.20339    127.0
# 3           MATE  30.269058  49.815498   0.376569    542.0
# 4           BIOP   3.311258  55.555556     0.0625      9.0
# 5           MANS   1.052632       25.0   0.020202      4.0
# 6           CHAR       80.0  16.410256    0.27234    195.0
# 7           MANP  55.033557   57.66526   0.563187    711.0
# 8           FEAT  12.121212  44.444444   0.190476    153.0
# 9         CONPRI  26.320755  29.807692   0.279559    936.0
# 10          ENAT  17.460317  21.153846   0.191304     52.0
# 11          APPL  11.111111  15.555556    0.12963     90.0
# 0       accuracy          -          -  42.449612   3225.0
# 1      macro avg  24.280435  38.694996   0.239075   3225.0
# 2   weighted avg  33.953213  42.449612   0.345389   3225.0

# %% [markdown]
# ### not stratified, tfidf

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_1_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  23.076923  55.450237   0.325905    211.0
# 1           PARA  23.144105  27.179487       0.25    195.0
# 2          MACEQ   17.46988  22.834646   0.197952    127.0
# 3           MATE  32.142857  41.512915   0.362319    542.0
# 4           BIOP   6.666667  33.333333   0.111111      9.0
# 5           MANS   0.338983       50.0   0.006734      4.0
# 6           CHAR  47.328244  31.794872   0.380368    195.0
# 7           MANP       36.5  51.336146   0.426651    711.0
# 8           FEAT  12.734082  22.222222   0.161905    153.0
# 9         CONPRI  30.224525  18.696581   0.231023    936.0
# 10          ENAT       11.0  21.153846   0.144737     52.0
# 11          APPL  17.322835  24.444444   0.202765     90.0
# 0       accuracy          -          -  34.046512   3225.0
# 1      macro avg  21.495758  33.329894   0.233456   3225.0
# 2   weighted avg  29.963976  34.046512   0.305229   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  21.889055  69.194313   0.332574    211.0
# 1           PARA  25.704225  37.435897   0.304802    195.0
# 2          MACEQ  19.262295  37.007874   0.253369    127.0
# 3           MATE  32.694611  50.369004   0.396514    542.0
# 4           BIOP   8.196721  55.555556   0.142857      9.0
# 5           MANS    0.75188       25.0   0.014599      4.0
# 6           CHAR  62.222222  43.076923   0.509091    195.0
# 7           MANP  52.466368  65.822785   0.583905    711.0
# 8           FEAT  18.243243  35.294118   0.240535    153.0
# 9         CONPRI  31.995662  31.517094   0.317546    936.0
# 10          ENAT  19.587629  36.538462   0.255034     52.0
# 11          APPL  15.584416  26.666667   0.196721     90.0
# 0       accuracy          -          -  46.170543   3225.0
# 1      macro avg  25.716527  42.789891   0.295629   3225.0
# 2   weighted avg  35.495105  46.170543   0.389911   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  24.368499  77.725118   0.371041    211.0
# 1           PARA  28.220859  47.179487   0.353167    195.0
# 2          MACEQ   21.73913  47.244094   0.297767    127.0
# 3           MATE  33.297062  56.457565   0.418891    542.0
# 4           BIOP   8.450704  66.666667       0.15      9.0
# 5           MANS   1.351351       25.0   0.025641      4.0
# 6           CHAR  65.151515  44.102564   0.525994    195.0
# 7           MANP   51.25149    60.4782   0.554839    711.0
# 8           FEAT  20.116618  45.098039   0.278226    153.0
# 9         CONPRI  32.437442  37.393162   0.347395    936.0
# 10          ENAT  21.052632  38.461538   0.272109     52.0
# 11          APPL  17.687075  28.888889   0.219409     90.0
# 0       accuracy          -          -  49.922481   3225.0
# 1      macro avg  27.093698  47.891277   0.317873   3225.0
# 2   weighted avg  36.218411  49.922481   0.406868   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  20.338983  73.933649   0.319018    211.0
# 1           PARA  25.212465  45.641026   0.324818    195.0
# 2          MACEQ  21.641791  45.669291   0.293671    127.0
# 3           MATE   31.00616  55.719557   0.398417    542.0
# 4           BIOP   4.255319  44.444444    0.07767      9.0
# 5           MANS   2.857143       50.0   0.054054      4.0
# 6           CHAR  75.961538  40.512821   0.528428    195.0
# 7           MANP  55.569462  62.447257   0.588079    711.0
# 8           FEAT  16.313559  50.326797     0.2464    153.0
# 9         CONPRI  32.492997  37.179487   0.346786    936.0
# 10          ENAT  19.753086  30.769231   0.240602     52.0
# 11          APPL   23.71134  25.555556   0.245989     90.0
# 0       accuracy          -          -  49.550388   3225.0
# 1      macro avg  27.426154  46.849926   0.305328   3225.0
# 2   weighted avg  36.962641  49.550388   0.404005   3225.0

# %% [markdown]
# ### stratified, tfidf

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_5_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  17.761989  47.393365   0.258398    211.0
# 1           PARA  16.883117  26.666667   0.206759    195.0
# 2          MACEQ  10.240964  13.385827   0.116041    127.0
# 3           MATE  25.077399  44.833948   0.321641    542.0
# 4           BIOP   2.439024  22.222222   0.043956      9.0
# 5           MANS        0.0        0.0        0.0      4.0
# 6           CHAR  13.157895   2.564103   0.042918    195.0
# 7           MANP  36.926606  45.288326   0.406822    711.0
# 8           FEAT    9.71564  26.797386   0.142609    153.0
# 9         CONPRI  25.727069   24.57265   0.251366    936.0
# 10          ENAT        0.0        0.0        0.0     52.0
# 11          APPL   2.564103   3.333333   0.028986     90.0
# 0       accuracy          -          -  31.472868   3225.0
# 1      macro avg  13.374484  21.421486   0.151625   3225.0
# 2   weighted avg  23.743534  31.472868    0.26097   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_10_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO      18.25  69.194313   0.288823    211.0
# 1           PARA  27.333333  42.051282   0.331313    195.0
# 2          MACEQ   8.646617  18.110236   0.117048    127.0
# 3           MATE  24.045802  46.494465   0.316981    542.0
# 4           BIOP        0.0        0.0        0.0      9.0
# 5           MANS   2.162162      100.0   0.042328      4.0
# 6           CHAR  65.517241  19.487179   0.300395    195.0
# 7           MANP  42.923434  52.039381   0.470439    711.0
# 8           FEAT   9.591837  30.718954    0.14619    153.0
# 9         CONPRI  25.616292  25.534188   0.255752    936.0
# 10          ENAT  15.555556  13.461538    0.14433     52.0
# 11          APPL  14.393939  21.111111   0.171171     90.0
# 0       accuracy          -          -  38.046512   3225.0
# 1      macro avg  21.169684  36.516887   0.215398   3225.0
# 2   weighted avg  29.197988  38.046512    0.30701   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_20_tfidf.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall  F1 score  support
# 0            PRO  16.230937  70.616114   0.26395    211.0
# 1           PARA  23.323615  41.025641  0.297398    195.0
# 2          MACEQ  12.349398  32.283465  0.178649    127.0
# 3           MATE  28.876404  47.416974  0.358939    542.0
# 4           BIOP   1.156069  22.222222  0.021978      9.0
# 5           MANS   2.272727       75.0  0.044118      4.0
# 6           CHAR  71.014493  25.128205  0.371212    195.0
# 7           MANP  54.843305  54.149086   0.54494    711.0
# 8           FEAT   7.507987  30.718954  0.120668    153.0
# 9         CONPRI  26.449644  27.777778  0.270974    936.0
# 10          ENAT  18.965517  21.153846       0.2     52.0
# 11          APPL  21.428571  16.666667    0.1875     90.0
# 0       accuracy          -          -  40.27907   3225.0
# 1      macro avg  23.701556  38.679913   0.23836   3225.0
# 2   weighted avg  33.139068   40.27907   0.33814   3225.0

# %% [markdown]
# ### not stratified, tfidf_half

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  20.356612   64.92891   0.309955    211.0
# 1           PARA  24.822695  35.897436   0.293501    195.0
# 2          MACEQ  20.379147  33.858268   0.254438    127.0
# 3           MATE  30.482456  51.291513   0.382393    542.0
# 4           BIOP   9.836066  66.666667   0.171429      9.0
# 5           MANS   0.666667       25.0   0.012987      4.0
# 6           CHAR  70.175439  41.025641   0.517799    195.0
# 7           MANP   48.82904  58.649789   0.532907    711.0
# 8           FEAT  17.391304  39.215686   0.240964    153.0
# 9         CONPRI  30.741627  27.457265   0.290068    936.0
# 10          ENAT  22.972973  32.692308   0.269841     52.0
# 11          APPL  12.337662  21.111111   0.155738     90.0
# 0       accuracy          -          -  42.945736   3225.0
# 1      macro avg  25.749307  41.482883   0.286002   3225.0
# 2   weighted avg    34.2568  42.945736   0.365918   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  21.264368   70.14218   0.326351    211.0
# 1           PARA       24.0  36.923077   0.290909    195.0
# 2          MACEQ  22.374429  38.582677   0.283237    127.0
# 3           MATE  28.967495  55.904059   0.381612    542.0
# 4           BIOP   3.846154  22.222222   0.065574      9.0
# 5           MANS        0.0        0.0        0.0      4.0
# 6           CHAR  61.607143  35.384615   0.449511    195.0
# 7           MANP  49.878049  57.524613   0.534291    711.0
# 8           FEAT  16.790123  44.444444   0.243728    153.0
# 9         CONPRI  31.761006  32.371795   0.320635    936.0
# 10          ENAT  19.117647       25.0   0.216667     52.0
# 11          APPL  13.333333  22.222222   0.166667     90.0
# 0       accuracy          -          -  45.147287   3225.0
# 1      macro avg  24.411646  36.726825   0.273265   3225.0
# 2   weighted avg  34.019016  45.147287   0.372152   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_not_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  18.181818  72.037915   0.290353    211.0
# 1           PARA  28.971963  47.692308   0.360465    195.0
# 2          MACEQ  25.327511  45.669291   0.325843    127.0
# 3           MATE  27.565392  50.553506   0.356771    542.0
# 4           BIOP   6.666667  66.666667   0.121212      9.0
# 5           MANS   1.886792       50.0   0.036364      4.0
# 6           CHAR  76.842105  37.435897   0.503448    195.0
# 7           MANP   53.61596    60.4782   0.568407    711.0
# 8           FEAT  12.801484  45.098039   0.199422    153.0
# 9         CONPRI  31.262136  34.401709   0.327569    936.0
# 10          ENAT  19.402985       25.0   0.218487     52.0
# 11          APPL  18.965517  24.444444   0.213592     90.0
# 0       accuracy          -          -  46.945736   3225.0
# 1      macro avg  26.790861  46.623165   0.293494   3225.0
# 2   weighted avg  35.581853  46.945736   0.383738   3225.0

# %% [markdown]
# ### stratified, tfidf_half

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_5_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  14.261168  39.336493   0.209332    211.0
# 1           PARA  14.705882  15.384615   0.150376    195.0
# 2          MACEQ  10.952381  18.110236   0.136499    127.0
# 3           MATE  17.517675  41.143911    0.24573    542.0
# 4           BIOP   3.030303  44.444444   0.056738      9.0
# 5           MANS   0.289017       25.0   0.005714      4.0
# 6           CHAR  17.021277   8.205128   0.110727    195.0
# 7           MANP  30.232558  31.082982   0.306519    711.0
# 8           FEAT   5.590062  11.764706   0.075789    153.0
# 9         CONPRI  20.091324  14.102564   0.165725    936.0
# 10          ENAT   3.658537   5.769231   0.044776     52.0
# 11          APPL   11.47541  15.555556   0.132075     90.0
# 0       accuracy          -          -  23.813953   3225.0
# 1      macro avg  12.402133  22.491656   0.136667   3225.0
# 2   weighted avg  19.376435  23.813953   0.200001   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_10_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  15.620828  55.450237    0.24375    211.0
# 1           PARA  15.175097       20.0   0.172566    195.0
# 2          MACEQ  12.169312  18.110236    0.14557    127.0
# 3           MATE  18.867925  46.125461   0.267809    542.0
# 4           BIOP   1.408451  11.111111      0.025      9.0
# 5           MANS   0.591716       25.0   0.011561      4.0
# 6           CHAR  28.767123  10.769231   0.156716    195.0
# 7           MANP  36.684073    39.5218   0.380501    711.0
# 8           FEAT   5.681818   9.803922   0.071942    153.0
# 9         CONPRI  19.889503  15.384615   0.173494    936.0
# 10          ENAT   6.153846   7.692308   0.068376     52.0
# 11          APPL   8.053691  13.333333   0.100418     90.0
# 0       accuracy          -          -  28.155039   3225.0
# 1      macro avg  14.088615  22.691855   0.151475   3225.0
# 2   weighted avg  21.787532  28.155039   0.228242   3225.0

# %%
with open("formal_eva_results_llama2chat7b/fabner_stratified_input_30_example_20_tfidf_half.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['PRO', 'PARA', 'MACEQ', 'MATE', 'BIOP', 'MANS', 'CHAR', 'MANP', 'FEAT', 'CONPRI', 'ENAT', 'APPL']
#           entity  precision     recall   F1 score  support
# 0            PRO  14.393939  63.033175   0.234361    211.0
# 1           PARA  15.248227  22.051282   0.180294    195.0
# 2          MACEQ   9.502262  16.535433    0.12069    127.0
# 3           MATE  20.344545  45.756458   0.281658    542.0
# 4           BIOP   4.347826  55.555556   0.080645      9.0
# 5           MANS   0.675676       25.0   0.013158      4.0
# 6           CHAR  52.631579  15.384615   0.238095    195.0
# 7           MANP  45.710059  43.459916   0.445566    711.0
# 8           FEAT   6.026786  17.647059    0.08985    153.0
# 9         CONPRI  22.421053   22.75641   0.225875    936.0
# 10          ENAT   8.196721   9.615385   0.088496     52.0
# 11          APPL   5.263158   4.444444   0.048193     90.0
# 0       accuracy          -          -  32.217054   3225.0
# 1      macro avg  17.063486  28.436644   0.170573   3225.0
# 2   weighted avg  26.002176  32.217054   0.263784   3225.0

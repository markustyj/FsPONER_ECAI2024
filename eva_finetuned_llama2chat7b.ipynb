# %%
import pickle
import nltk
nltk.download('punkt')

from gpt_ner_api_codes.prompts_all import *
from gpt_ner_api_codes.demonstration_samples_generation import *
# %reload_ext autoreload
# %autoreload 2

import tqdm
def nop(it, *a, **k):
    return it
tqdm.tqdm = nop
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\z004r5cc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def process_response(response):    
    processed_response = []
    for item in response:
        #dem = item[0]["generated_text"]
        #dem = dem.replace("* ", "")
        #dem = dem.split("Note: ")[0]
        #print("############################### not processed" +  item)
        dem = item
        dem = dem.split("Extracted entities of the above sentence:")[-1]
        dem = dem.split("\n\n")[0]
        #print("############################### processed" +  dem)
        processed_response.append ( dem)
    return processed_response

# %% [markdown]
# # Thin-film technology dataset

# %%
with open("data/immutable_data_formal/sen_thf_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_thf_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %%
with open("formal_eva_results_finetuned_llama2chat7b/thf_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(len(response), response[0])    
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['Effect', 'PhysicsFlow', 'Location', 'EnergyFlow', 'Value', 'Consequence', 'Shape', 'ScientificConcept', 'InfoFlow', 'System', 'Component', 'Material', 'Measure', 'AnnotatorNotes', 'Function', 'State', 'Attribution']
#                entity  precision     recall   F1 score  support
# 0              Effect  73.205742   58.62069   0.651064    261.0
# 1         PhysicsFlow  91.304348       75.0   0.823529     28.0
# 2            Location  87.941788  89.240506   0.885864    474.0
# 3          EnergyFlow  75.531915   74.34555    0.74934    382.0
# 4               Value  84.782609       65.0   0.735849     60.0
# 5         Consequence       40.0  18.181818       0.25     22.0
# 6               Shape  72.316384  67.015707   0.695652    191.0
# 7   ScientificConcept   56.20915  47.252747   0.513433    182.0
# 8            InfoFlow  88.888889   89.88764   0.893855     89.0
# 9              System  86.931818  62.962963    0.73031    243.0
# 10          Component  89.689781  89.363636   0.895264   2200.0
# 11           Material  85.618729  81.012658    0.83252    316.0
# 12            Measure  37.209302  42.105263   0.395062     38.0
# 13     AnnotatorNotes        0.0        0.0        0.0      3.0
# 14           Function  69.942197  77.070064   0.733333    314.0
# 15              State      100.0  33.333333        0.5      6.0
# 16        Attribution  74.009901  80.376344   0.770619    372.0
# 0            accuracy          -          -  80.138969   5181.0
# 1           macro avg  71.387209  61.809936   0.650335   5181.0
# 2        weighted avg  82.440906  80.138969   0.810601   5181.0

# %% [markdown]
# # Assembly instruction

# %%
with open("data/immutable_data_formal/sen_assembly_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_assembly_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %%
def process_response(response):    
    processed_response = []
    for item in response:
        dem = item[0]["generated_text"]
        #dem = dem.replace("* ", "")
        #dem = dem.split("Note: ")[0]
        #print("############################### not processed" +  item)
        #print(dem)
        dem = dem.split("Extracted entities of the input sentence: \n")[-1]
        dem = dem.split("\n\n")[0]
        #print("############################### processed" +  dem)
        processed_response.append ( dem)
    return processed_response

# %%
with open("formal_eva_results_finetuned_llama2chat7b/assembly_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(len(response), response[0])    
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['QTY', 'ID', 'TOOL', 'WGT', 'OPER', 'DIM', 'PART', 'PROP', 'RPOS']
#          entity  precision     recall   F1 score  support
# 0           QTY  82.608696  31.147541   0.452381     61.0
# 1            ID  94.594595  53.846154   0.686275     65.0
# 2          TOOL  64.705882  15.277778   0.247191     72.0
# 3           WGT        0.0        0.0        0.0      2.0
# 4          OPER  80.149813  40.839695   0.541087    524.0
# 5           DIM  57.142857  11.428571   0.190476     35.0
# 6          PART  88.727273  47.149758   0.615773   2070.0
# 7          PROP  65.217391  27.272727   0.384615     55.0
# 8          RPOS   85.39823  39.711934   0.542135    486.0
# 0      accuracy          -          -  43.531157   3370.0
# 1     macro avg  68.727193  29.630462   0.406659   3370.0
# 2  weighted avg  85.638295  43.531157   0.575513   3370.0

# %% [markdown]
# # FabNER manufacturing

# %%
with open("data/immutable_data_formal/sen_fabner_input_30.txt", "rb") as data:   #Pickling
    sentences_input = pickle.load(data)  
with open("data/immutable_data_formal/dem_fabner_input_30.txt", "rb") as data:   #Pickling
    demonstrations_input_solutions = pickle.load(data)

# %%
with open("formal_eva_results_finetuned_llama2chat7b/fabner_not_stratified_input_30_example_0_random.txt", "rb") as data:   #Pickling
    response = pickle.load(data) 
#print(len(response), response[0])    
response = process_response(response)    
transformed_output = change_output_format_to_tokens_tags(sentences_input, response)
transformed_solution = change_output_format_to_tokens_tags(sentences_input, demonstrations_input_solutions)
get_evaluation_without_o(transformed_solution = transformed_solution, transformed_output = transformed_output)
# Out:
# ['MANP', 'CHAR', 'PRO', 'FEAT', 'CONPRI', 'PARA', 'ENAT', 'MATE', 'BIOP', 'MANS', 'MACEQ', 'APPL']
#           entity  precision     recall   F1 score  support
# 0           MANP  90.056818  44.585091   0.596425    711.0
# 1           CHAR  93.277311  56.923077   0.707006    195.0
# 2            PRO  92.682927  36.018957   0.518771    211.0
# 3           FEAT  88.405797  39.869281    0.54955    153.0
# 4         CONPRI  81.909548   34.82906   0.488756    936.0
# 5           PARA  83.544304  33.846154   0.481752    195.0
# 6           ENAT  81.818182  34.615385   0.486486     52.0
# 7           MATE  89.237668  36.715867   0.520261    542.0
# 8           BIOP       50.0  22.222222   0.307692      9.0
# 9           MANS  66.666667       50.0   0.571429      4.0
# 10         MACEQ  81.967213  39.370079   0.531915    127.0
# 11          APPL  95.238095  44.444444   0.606061     90.0
# 0       accuracy          -          -  39.317829   3225.0
# 1      macro avg  82.900377  39.453301   0.530509   3225.0
# 2   weighted avg  87.001373  39.317829   0.539943   3225.0
